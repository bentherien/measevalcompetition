# %%
from __future__ import unicode_literals, print_function
import pandas as pd
import os.path
from nltk.tokenize import word_tokenize
import nltk
import json
import spacy
import plac
spacy.prefer_gpu()
nlp = spacy.load("en_core_web_sm")

TRIALPATH = "data/trial"
TRAINPATH = "data/train"

class exerpt:
    def __init__(self, name, txt, ann, tsv, grobid):
        self.name = name
        self.txt = txt
        self.ann = ann
        self.tsv = tsv
        self.grobid = grobid
        self.context = False
        self.posTag = False
        self.doc = nlp(self.txt)
        
    def getContext(self, count = 3):
        if self.context == False: 
            beforeContext = []
            afterContext = []
            self.context = True
            for start,end in zip(self.tsv["startOffset"].values, self.tsv["endOffset"].values ):#self.tsv.iterrows():
                a = getIndexSeperated(exerpt.txt[0],end,count = count)
                b = getIndexSeperated(exerpt.txt[0],start,count = count,forward = False)
                beforeContext.append(self.txt[0][b:start])
                afterContext.append(self.txt[0][end:a])
            self.tsv.insert(3,"beforeContext", beforeContext)
            self.tsv.insert(3,"afterContext", afterContext)
            
    def getPosTag(self):
        if self.context and self.posTag == False: 
            bTag = []
            aTag = []
            self.posTag = True
            for before, after in zip(self.tsv["beforeContext"].values,self.tsv["afterContext"].values):
                bTag.append(nltk.pos_tag(word_tokenize(before)))
                aTag.append(nltk.pos_tag(word_tokenize(after)))
            self.tsv.insert(3,"beforeTag", bTag)
            self.tsv.insert(3,"afterTag", aTag)
            


def readTXTByLine(filepath):
    ftemp = open(filepath, "r", encoding = "utf-8")
    raw = str(ftemp.read())
    ftemp.close()
    return raw

data = {}
for fn in os.listdir(os.path.join(TRIALPATH,"txt")):
        if fn.endswith('.txt'):
            data[fn[:-4]] = exerpt(
                fn[:-4],
                readTXTByLine(os.path.join(TRIALPATH, "txt", fn[:-4] + ".txt")),
                readTXTByLine(os.path.join(TRIALPATH, "ann", fn[:-4] + ".ann")),
                pd.read_csv(os.path.join(TRIALPATH, "tsv", fn[:-4] + ".tsv"), "\t", header = 0 ),
                json.load(open(os.path.join(TRIALPATH, "grobid", l + ".grobid")))
            )
            
for fn in [x for x in os.listdir(os.path.join(TRAINPATH,"text")) if x[:-4]+".tsv" in os.listdir(os.path.join(TRAINPATH,"tsv"))]:
        if fn.endswith('.txt'):
            data[fn[:-4]] = exerpt(
                fn[:-4],
                readTXTByLine(os.path.join(TRAINPATH, "text", fn[:-4] + ".txt")),
                "none",
                pd.read_csv(os.path.join(TRAINPATH, "tsv", fn[:-4] + ".tsv"), "\t", header = 0 ),
                "none"
            )

# %%
len(data)
# Out:
# 278

# %%
from spacy import displacy
import os
from pathlib import Path
options = {"fine_grained" : True,
            "collapse_punct": True,
          "collapse_phrases": False, 
          "compact" : True,
          "word_spacing" : 25,
          "offset_x" : 50,
          "arrow_stroke" : 1,
          "arrow_spacing" : 6,
          "distance" : 90,
          "arrow_width": 4.5,
          "font" : "Times"}

"""
The following code generates dependency parses and saves them to a dependency parses folder
It is also possible to do this and have spacy output it to a server port... 
"""
for exerpt in data.values(): 
    svg = displacy.render(exerpt.doc, jupyter = False, style = "dep", minify = True, options = options)
    file_name = exerpt.name + ".svg"
    output_path = Path(os.path.join("./","data/trial/dep", file_name))
    output_path.open("w", encoding="utf-8").write(svg)

# %%
"""A simple example of extracting relations between phrases and entities using
spaCy's named entity recognizer and the dependency parse. Here, we extract
money and currency values (entities labelled as MONEY) and then check the
dependency tree to find the noun phrase they are referring to – for example:
$9.4 million --> Net income.

Compatible with: spaCy v2.0.0+
Last tested with: v2.2.1
"""




TEXTS = [
    "Net income was $9.4 million compared to the prior year of $2.7 million.",
    "Revenue exceeded twelve billion dollars, with a loss of $1b.",
]


def main(model="en_core_web_sm"):
    nlp = spacy.load(model)
    print("Loaded model '%s'" % model)
    print("Processing %d texts" % len(TEXTS))

    for text in TEXTS:
        doc = nlp(text)
        relations = extract_currency_relations(doc)
        for r1, r2 in relations:
            print("{:<10}\t{}\t{}".format(r1.text, r2.ent_type_, r2.text))


def filter_spans(spans):
    # Filter a sequence of spans so they don't contain overlaps
    # For spaCy 2.1.4+: this function is available as spacy.util.filter_spans()
    get_sort_key = lambda span: (span.end - span.start, -span.start)
    sorted_spans = sorted(spans, key=get_sort_key, reverse=True)
    result = []
    seen_tokens = set()
    for span in sorted_spans:
        # Check for end - 1 here because boundaries are inclusive
        if span.start not in seen_tokens and span.end - 1 not in seen_tokens:
            result.append(span)
        seen_tokens.update(range(span.start, span.end))
    result = sorted(result, key=lambda span: span.start)
    return result

skips = {}
skipKind = {}
def extract_currency_relations(doc):
    # Merge entities and noun chunks into one token
    spans = list(doc.ents) + list(doc.noun_chunks)
    spans = filter_spans(spans)
    with doc.retokenize() as retokenizer:
        for span in spans:
            retokenizer.merge(span)

    relations = []
    tps = ["CARDINAL", "MONEY", "ORDINAL", "PERCENT", "DATE", "TIME", "QUANTITY"]
    for identifiedEnt in filter(lambda w: w.ent_type_ in tps, doc):
        if identifiedEnt.dep_ in ("attr", "dobj"):
            subject = [w for w in identifiedEnt.head.lefts if w.dep_ == "nsubj"]
            if subject:
                subject = subject[0]
                relations.append((subject, identifiedEnt))
        elif identifiedEnt.dep_ == "pobj" and identifiedEnt.head.dep_ == "prep":
            relations.append((identifiedEnt.head.head, identifiedEnt))
        else:
            print("skipped: ", identifiedEnt.dep_,  identifiedEnt.pos_, identifiedEnt)
            try:
                skips[identifiedEnt.dep_] += 1
                skipKind[identifiedEnt.dep_].append(identifiedEnt)
            except KeyError: 
                skips[identifiedEnt.dep_] = 1
                skipKind[identifiedEnt.dep_] = [identifiedEnt]
    return relations

nlp = spacy.load("en_core_web_sm")

# %%
for ent in data.values():
    print(ent.name)
    relations = extract_currency_relations(ent.doc)
    for r1, r2 in relations:
        print("{:<10}\t{}\t{}".format(r1.text, r2.ent_type_, r2.text))
    print()
# Out:
# S0012821X12004384-1302
# skipped:  dep NUM 6
# skipped:  conj NUM 8)
# skipped:  nummod X 4
# skipped:  conj NUM 2617.35
# skipped:  conj NUM 2617.44
# skipped:  conj NUM 2614.73
# skipped:  nsubj NOUN 2614.71 m
# skipped:  appos X 5
# skipped:  appos NUM 2619.60
# skipped:  conj NUM 2614.73
# skipped:  nsubj NUM 8)
# skipped:  nummod NUM 1
# skipped:  nsubj NUM 8)
# skipped:  nummod NUM 1
# skipped:  appos NUM 2619.60
# skipped:  conj NUM 2614.71
# skipped:  nummod NUM 1
# skipped:  dep NUM 2005
# skipped:  ROOT NUM Figs. 3, 6–9
# from      	CARDINAL	2619.60
# Some      	CARDINAL	3
# we        	CARDINAL	5a
#
# S0012821X12004384-1405
# skipped:  dep NUM 1992
# skipped:  dep NUM 2005
# skipped:  dep NUM 7
# skipped:  nummod NUM 10
# overview  	DATE	2005
# ranging   	PERCENT	0% to 80%
#
# S0012821X12004384-1415
# skipped:  nummod NUM 1
# skipped:  nsubj NOUN 7p
# skipped:  npadvmod NUM 1994
# skipped:  npadvmod NUM 2005
# (DA1      	DATE	2632 to 2618 m, Fig
#
# S0012821X12004384-1594
# skipped:  nummod NUM 9
# skipped:  npadvmod X 2006b
# skipped:  dep NUM 2001
# skipped:  appos NUM 2002
#
# S0012821X12004384-1599
# skipped:  nsubj NUM 2009
# skipped:  npadvmod NUM 2009
# skipped:  nummod NUM 1
# skipped:  appos NUM 2011
# skipped:  npadvmod NUM 2006
# Our results	CARDINAL	9
#
# S0012821X13002185-1061
# skipped:  appos NUM 2005
# skipped:  appos NUM 1992
# skipped:  prep ADP between 60% and 100%
# skipped:  npadvmod NOUN today
# skipped:  appos NUM 2005
# skipped:  dep NUM 2008
# skipped:  dep NUM 2001
# skipped:  appos NUM 2003
# skipped:  dep NUM 2011
# skipped:  appos NUM 2009
# skipped:  appos NUM 1999
# skipped:  appos NUM 2006
# driven    	DATE	Oi1
#
# S0012821X13002185-1200
# skipped:  dep NUM 2010
# skipped:  npadvmod NUM 2009
# skipped:  prep ADP between 50 and 100
# skipped:  dep NUM 2010
# skipped:  dep NUM 2011
# skipped:  appos NUM 2003
# skipped:  appos NUM 2003
#
# S0012821X13002185-1217
# skipped:  dep NUM 2007
# skipped:  npadvmod NUM 2005
# skipped:  conj NOUN up to 1 week
# skipped:  npadvmod NUM 2006
# skipped:  npadvmod NUM 2007
# skipped:  npadvmod NUM 2SD
# 0.2 M NaOH	CARDINAL	100
# Ragueneau et al.	QUANTITY	40 min
# Δm∼3500   	PERCENT	5% and 95%
#
# S0012821X13002185-1231
# skipped:  dep NUM 2013
# skipped:  appos NOUN a significantly smaller 30ε
# skipped:  dep NUM 1997
# skipped:  dep NUM 2012
# skipped:  nummod NUM 5
# skipped:  conj NUM 385
# skipped:  ROOT NUM 5a
# skipped:  ROOT X 5c
# skipped:  nummod NUM between 2 and 20
# skipped:  npadvmod NUM 2a
# skipped:  dep NUM 2011c
# skipped:  dep NUM 6
# skipped:  dep NUM 2
# skipped:  conj NUM 5
# converge  	CARDINAL	an apparent 30ε
#
# S0012821X13002185-835
# skipped:  dep NUM 2007
# skipped:  dep NOUN 2011a
# skipped:  dep NUM 2011c
# skipped:  dep NUM 2004
# skipped:  dep NUM 2012
# skipped:  appos NUM 2012
#
# S0012821X13007309-1482
# skipped:  appos NUM 1972
# skipped:  appos NUM 1988
# skipped:  nsubj NUM 40Ar/39Ar
# skipped:  dep NUM 1993
# skipped:  dep NUM 2000
# skipped:  appos NUM 2005
# skipped:  appos NUM 2004
# skipped:  dep NUM 2004
# skipped:  dep NUM 2006
# skipped:  npadvmod NUM 1970
# skipped:  dep NUM 2000
# skipped:  nummod NUM 86
# skipped:  appos NUM 2001
# skipped:  appos NUM 1972
# skipped:  dep NUM 2000
# skipped:  appos NUM 2005
# four bentonite units	QUANTITY	1 to 20 cm
#
# S0012821X13007309-1509
# skipped:  npadvmod NUM 4.3 m
# skipped:  nummod X 2
# skipped:  dep NUM 2006
# skipped:  dep NUM 2004
# skipped:  dep NUM 2006
# Shale interbeds	DATE	the upper half
#
# S0012821X13007309-1605
# skipped:  dep NUM 2011
# skipped:  ROOT NUM 1
# skipped:  dep NUM 2009
# skipped:  dep NUM 2011
# skipped:  dep NUM 2006
# skipped:  dep NUM 2011
# skipped:  nummod X 2
# skipped:  dep NUM 2011
# skipped:  npadvmod PROPN 2d
#
# S0012821X13007309-1989
# skipped:  appos NUM 2000
# skipped:  appos NOUN a basalt 187Os/188Os
# skipped:  dep NUM 2001
# skipped:  npadvmod NUM 1986
# skipped:  ROOT NUM 9.2
# skipped:  conj NUM 9.10
# skipped:  appos NUM 1991
# skipped:  appos NUM 2008
# skipped:  appos NUM 1998
# skipped:  dep NUM 2008
# skipped:  appos NOUN 25%
# skipped:  npadvmod NUM 2008
# a basalt 187Os/188Os	CARDINAL	0.13
# range     	QUANTITY	1 to 30 ppt
# the Os contribution	CARDINAL	20
#
# S0016236113008041-3031
# skipped:  appos NUM 14
# skipped:  prep ADP B over eight
# skipped:  prep ADP over eight
#
# S0016236113008041-3112
# skipped:  nummod NUM 29
# skipped:  appos NUM 23
# skipped:  meta NUM 3
# skipped:  nummod NUM 29
# skipped:  appos NUM 23
#
# S0016236113008041-3153
# skipped:  nsubj NUM 5
# skipped:  nummod NOUN 13 kg
#
# S0016236113008041-3171
# skipped:  nsubj NUM 6
# a bed inventory	QUANTITY	4.5 kg
# values    	CARDINAL	22
# increased 	QUANTITY	13 kg
# recorded  	QUANTITY	6 kg
# 6 kg      	QUANTITY	4.5 kg
# then a decrease	QUANTITY	6 kg to 13 kg
#
# S0016236113008041-3186
# skipped:  nsubj NUM 7
# skipped:  nummod NUM 4.5
# skipped:  nummod NUM 6
# skipped:  npadvmod NOUN 13 kg
# increasing	CARDINAL	0.06
# from      	CARDINAL	0.42
#
# S0016236113008041-3207
# skipped:  appos NUM 26
# occurs    	PERCENT	90–95%
#
# S0016236113008041-3269
# skipped:  nsubj NUM 9
# skipped:  amod ADJ close to 10
# being     	CARDINAL	0 to 1000
# concentration	CARDINAL	SO2
# increasing	CARDINAL	9.4
# from      	CARDINAL	14.1
#
# S0016236113008041-3290
# skipped:  nsubj NUM 10
# the highest concentrations	CARDINAL	0.63
#
# S0016236113008041-890
# skipped:  conj NOUN 6 kg and
# skipped:  conj NOUN 13 kg
# bed inventories	QUANTITY	4.5 kg
#
# S0016236113008041-913
# Effect    	CARDINAL	SO2
#
# S0016236113008041-967
# skipped:  appos NOUN 6 kg and
# skipped:  compound NOUN 13 kg
# Calculated	QUANTITY	4.5 kg
#
# S0019103511004994-1382
# skipped:  nummod NUM 14
# skipped:  advmod ADJ as low as
# skipped:  npadvmod NOUN 25 km
# skipped:  nummod NUM 27
# skipped:  pobj NUM at least two
# keV       	CARDINAL	21
#
# S0019103511004994-1511
# skipped:  prep ADP between about 20
# skipped:  conj NOUN several tens
# skipped:  dep NUM 1
# skipped:  nummod NUM 16
# skipped:  appos PART 5.65 s
# skipped:  conj NOUN 0.66 s
# skipped:  conj NOUN 86 s
# rotates   	QUANTITY	86 s
# rotating  	DATE	the beginning of 2005
# an angle  	CARDINAL	77.45
#
# S0019103511004994-1565
# skipped:  ROOT X 2
# skipped:  ROOT NUM 2
# skipped:  nsubj NUM 3
# shown     	DATE	Fig.
# the right-hand side	DATE	Fig.
# Only the measurements	CARDINAL	flybys E0
#
# S0019103512002801-1342
# skipped:  punct NUM 1RRh
# skipped:  appos NOUN 764 km
# skipped:  appos NOUN = 60,268 km
# skipped:  dep NUM 2010
# skipped:  dep NUM 2012
# skipped:  dep NUM 2008
# skipped:  dep NUM 2008
# a distance	CARDINAL	about 8.74Rs
#
# S0019103512002801-1496
# skipped:  nummod NUM 2008
#
# S0019103512002801-1608
# skipped:  dep NUM 2010
# skipped:  ROOT NUM 2010
# a factor  	CARDINAL	two
# lower     	CARDINAL	the one
#
# S0019103512002801-1824
# skipped:  dep NUM 2012
# The relative strength	PERCENT	between 6% and 13%
# compared  	PERCENT	6–8%
#
# S0019103512002801-1849
# skipped:  dep NUM 10
# shown     	DATE	Fig.
#
# S0019103512002801-1927
# skipped:  appos NUM 2000
#
# S0019103512003533-3299
# skipped:  appos NUM 2006
# skipped:  npadvmod NUM 2004
# skipped:  appos NUM 2008
# skipped:  appos NUM 1983
# skipped:  ROOT NUM 2006
# heating efficiencies	PERCENT	50%
#
# S0019103512003533-3348
# skipped:  ROOT NUM 2006
# Our time integration step	CARDINAL	5 s
#
# S0019103512003533-4685
# skipped:  nummod NUM 78
# skipped:  conj PROPN H2O+
# skipped:  conj PROPN H3O+
#
# S0019103512003533-4971
# skipped:  ROOT NUM 6
# skipped:  nummod NUM 3
#
# S0019103512003533-5031
# skipped:  nsubj NUM 6
# skipped:  dep NUM 1983
# skipped:  npadvmod NUM 2012
# skipped:  ROOT NUM 6
# skipped:  npadvmod NUM 2007
# an exospheric temperature	CARDINAL	29.5
# a value   	CARDINAL	488
#
# S0019103512003533-5072
# skipped:  nsubj NUM 8
# skipped:  ROOT NUM 2004
# skipped:  dep NUM 2
# peak velocities	CARDINAL	82
# m s−1     	CARDINAL	78
#
# S0019103512003533-5251
# skipped:  dep NUM 2007
# skipped:  appos NUM 2012
# skipped:  ROOT NUM 2011
# skipped:  meta NUM 2012
# skipped:  nsubj PROPN H3
# skipped:  meta NUM 2011
# auroral oval	CARDINAL	(563–624
# up        	CARDINAL	650
#
# S0019103512003533-5598
# skipped:  dep NUM 2
# averaged  	CARDINAL	74
# find      	CARDINAL	90
# the same latitude band	DATE	the northern (winter
#
# S0019103512003995-1807
# skipped:  ROOT NUM 2002
# skipped:  dep NUM 2001
# skipped:  ROOT NUM 2008a
# skipped:  dep NUM 2007
# skipped:  nummod NUM 300–800
# skipped:  dep NUM 2010
#
# S0019103512003995-1910
# skipped:  meta NUM 2000
# skipped:  prep ADP between 1947 and 1999
# skipped:  prep ADP between 1% and 37%
# skipped:  appos NOUN 27 days
# skipped:  npadvmod NUM 2008
# skipped:  appos NUM 2007
# skipped:  conj NUM 2008
# skipped:  appos NUM 2010
# took      	DATE	a month and a half
#
# S0019103512003995-2760
# skipped:  nsubj NUM 7
# skipped:  dep NUM 2010
# skipped:  dep NUM 2005
# skipped:  appos NUM 2010
#
# S0019103512003995-3548
# skipped:  appos NUM 2003
# skipped:  appos NUM 2004
# skipped:  appos NUM 2007
# skipped:  appos NUM 2008
# skipped:  appos NUM 2010
# skipped:  dep NUM 2011
# skipped:  npadvmod NUM 2010
#
# S0019103512004009-3488
# skipped:  nsubj NUM 2008a
# skipped:  nsubj NOUN (2011a
#
# S0019103512004009-3825
# skipped:  dep NUM 1983
# skipped:  nummod NUM 0.3
# skipped:  nummod NUM 0.5
# skipped:  advcl NUM 1
# A net heating efficiency	PERCENT	50%
# located   	QUANTITY	1.5Rp
# varies    	CARDINAL	0.1
# from      	CARDINAL	1
# shifts    	CARDINAL	1.9Rp
#
# S0019103512004009-3962
# skipped:  nsubj NUM 2010a
# skipped:  pcomp NUM 0.5
# skipped:  appos NUM 2008
#
# S0019103512004009-4007
# skipped:  dep NUM 2009
# skipped:  nsubj NUM 4
# skipped:  nummod NUM 2
# skipped:  dep NUM 2009
# skipped:  appos NUM 2007
# a constant photoelectron heating efficiency	PERCENT	93%
# an electron mixing ratio	CARDINAL	0.1
# based     	CARDINAL	C1
#
# S0019103512004009-4492
# skipped:  meta NUM 11
# skipped:  compound NOUN 7.2 km
#
# S0019103512004009-5019
# skipped:  ROOT NUM 2009
# skipped:  ROOT NUM 2009
# skipped:  nsubj NUM 10
#
# S0019103512004009-5507
# skipped:  nsubj X 2010a
# skipped:  npadvmod NUM 2007
# skipped:  appos NUM 2008
# skipped:  nsubj X 2010a
# skipped:  appos NUM 2003
# skipped:  npadvmod NUM 2008
#
# S0019103513005058-1737
#
# S0019103513005058-3094
# skipped:  npadvmod NOUN 0.1%
# skipped:  nummod NUM 1.0–1.7
# skipped:  nummod NUM 0.2–0.4
#
# S0019103513005058-4210
# skipped:  dep NUM 2009
# skipped:  dep NUM 2014
# skipped:  npadvmod NUM 2010
# an average depth	CARDINAL	2 m
# nitrate   	CARDINAL	∼1:1000
#
# S0021979713004438-1415
# controlled	CARDINAL	25
#
# S0021979713004438-1907
# skipped:  ROOT NUM 2
# skipped:  dep NUM 2
#
# S0021979713004438-1969
# skipped:  nummod NUM 10
# skipped:  punct NUM Fig. 4
# skipped:  ROOT PROPN 4b
# skipped:  ROOT PROPN 4a
# skipped:  nummod NUM 1
# skipped:  nsubj PROPN 4c
# skipped:  nsubjpass NOUN 4b
# the buffer solution	CARDINAL	4a
#
# S0021979713004438-2148
# skipped:  nsubj NUM 8
# skipped:  appos NUM 6a
# skipped:  appos PROPN 8a
# skipped:  nummod NUM 1536
# skipped:  ROOT PROPN 8b
# skipped:  pobj NUM 1485
# skipped:  nummod NUM 1260
# skipped:  nsubj PROPN 8b
# skipped:  nsubj PROPN 8b
#
# S0022000014000026-17824
# skipped:  nummod NUM 1
#
# S0022000014000026-18167
# skipped:  appos NUM 49
# skipped:  appos NUM 25,14
# skipped:  nsubj NUM 48
# skipped:  appos NUM 26,27
# skipped:  appos NOUN 10%
# skipped:  appos X 1
# skipped:  appos NUM 41
# skipped:  advmod ADV First
# skipped:  advmod ADV Second
# skipped:  ROOT NUM 13
# the stated complexity	CARDINAL	48
# reduce    	CARDINAL	5
# formalized	CARDINAL	13
# is        	CARDINAL	one
#
# S0022399913003358-1044
# skipped:  nsubj NOUN around 40%
# skipped:  appos NUM 36
# skipped:  appos NUM 38
# skipped:  appos NUM 39,40
# skipped:  npadvmod NUM 41
# skipped:  npadvmod NUM 11
# around 40%	DATE	55–74 year olds
# the majority	CARDINAL	37
# the absolute level	CARDINAL	42
#
# S0022459611006116-1160
# skipped:  appos NOUN 99.9%
# skipped:  appos NUM 1
# skipped:  appos X 2
# skipped:  conj NOUN 3MgF2→2Mg3NF3(2)Mg3N2+MgF2→2Mg2NF
# stoichiometric amounts	CARDINAL	synthesised Mg3N2
#
# S0022459611006116-1195
# skipped:  oprd NUM 24
# carried   	CARDINAL	5≤2θ/
# a scan time	QUANTITY	50 min

# %%
skipKind
# Out:
# {'dep': [6,
#   2005,
#   1992,
#   2005,
#   7,
#   2001,
#   2008,
#   2001,
#   2011,
#   2010,
#   2010,
#   2011,
#   2007,
#   2013,
#   1997,
#   2012,
#   2011c,
#   6,
#   2,
#   2007,
#   2011a,
#   2011c,
#   2004,
#   2012,
#   1993,
#   2000,
#   2004,
#   2006,
#   2000,
#   2000,
#   2006,
#   2004,
#   2006,
#   2011,
#   2009,
#   2011,
#   2006,
#   2011,
#   2011,
#   2001,
#   2008,
#   1,
#   2010,
#   2012,
#   2008,
#   2008,
#   2010,
#   2012,
#   10,
#   1983,
#   2,
#   2007,
#   2,
#   2001,
#   2007,
#   2010,
#   2010,
#   2005,
#   2011,
#   1983,
#   2009,
#   2009,
#   2009,
#   2014,
#   2],
#  'conj': [8),
#   2617.35,
#   2617.44,
#   2614.73,
#   2614.73,
#   2614.71,
#   up to 1 week,
#   385,
#   5,
#   9.10,
#   6 kg and,
#   13 kg,
#   several tens,
#   0.66 s,
#   86 s,
#   H2O+,
#   H3O+,
#   2008,
#   3MgF2→2Mg3NF3(2)Mg3N2+MgF2→2Mg2NF],
#  'nummod': [4,
#   1,
#   1,
#   1,
#   10,
#   1,
#   9,
#   1,
#   5,
#   between 2 and 20,
#   86,
#   2,
#   2,
#   29,
#   29,
#   13 kg,
#   4.5,
#   6,
#   14,
#   27,
#   16,
#   2008,
#   78,
#   3,
#   300–800,
#   0.3,
#   0.5,
#   2,
#   1.0–1.7,
#   0.2–0.4,
#   10,
#   1,
#   1536,
#   1260,
#   1],
#  'nsubj': [2614.71 m,
#   8),
#   8),
#   7p,
#   2009,
#   40Ar/39Ar,
#   5,
#   6,
#   7,
#   9,
#   10,
#   3,
#   6,
#   8,
#   H3,
#   7,
#   2008a,
#   (2011a,
#   2010a,
#   4,
#   10,
#   2010a,
#   2010a,
#   4c,
#   8,
#   8b,
#   8b,
#   48,
#   around 40%],
#  'appos': [5,
#   2619.60,
#   2619.60,
#   2002,
#   2011,
#   2005,
#   1992,
#   2005,
#   2003,
#   2009,
#   1999,
#   2006,
#   2003,
#   2003,
#   a significantly smaller 30ε,
#   2012,
#   1972,
#   1988,
#   2005,
#   2004,
#   2001,
#   1972,
#   2005,
#   2000,
#   a basalt 187Os/188Os,
#   1991,
#   2008,
#   1998,
#   25%,
#   14,
#   23,
#   23,
#   26,
#   6 kg and,
#   5.65 s,
#   764 km,
#   = 60,268 km,
#   2000,
#   2006,
#   2008,
#   1983,
#   2012,
#   27 days,
#   2007,
#   2010,
#   2010,
#   2003,
#   2004,
#   2007,
#   2008,
#   2010,
#   2008,
#   2007,
#   2008,
#   2003,
#   6a,
#   8a,
#   49,
#   25,14,
#   26,27,
#   10%,
#   1,
#   41,
#   36,
#   38,
#   39,40,
#   99.9%,
#   1,
#   2],
#  'ROOT': [Figs. 3, 6–9,
#   5a,
#   5c,
#   1,
#   9.2,
#   2,
#   2,
#   2010,
#   2006,
#   2006,
#   6,
#   6,
#   2004,
#   2011,
#   2002,
#   2008a,
#   2009,
#   2009,
#   2,
#   4b,
#   4a,
#   8b,
#   13],
#  'npadvmod': [1994,
#   2005,
#   2006b,
#   2009,
#   2006,
#   today,
#   2009,
#   2005,
#   2006,
#   2007,
#   2SD,
#   2a,
#   1970,
#   4.3 m,
#   2d,
#   1986,
#   2008,
#   13 kg,
#   25 km,
#   2004,
#   2012,
#   2007,
#   2008,
#   2010,
#   2007,
#   2008,
#   0.1%,
#   2010,
#   41,
#   11],
#  'prep': [between 60% and 100%,
#   between 50 and 100,
#   B over eight,
#   over eight,
#   between about 20,
#   between 1947 and 1999,
#   between 1% and 37%],
#  'meta': [3, 2012, 2011, 2000, 11],
#  'amod': [close to 10],
#  'compound': [13 kg, 7.2 km],
#  'advmod': [as low as, First, Second],
#  'pobj': [at least two, 1485],
#  'punct': [1RRh, Fig. 4],
#  'advcl': [1],
#  'pcomp': [0.5],
#  'nsubjpass': [4b],
#  'oprd': [24]}

# %%
skips
# Out:
# {'dep': 65,
#  'conj': 18,
#  'nummod': 35,
#  'nsubj': 29,
#  'appos': 69,
#  'ROOT': 23,
#  'npadvmod': 30,
#  'prep': 7,
#  'meta': 5,
#  'amod': 1,
#  'advmod': 3,
#  'pobj': 2,
#  'punct': 2,
#  'advcl': 1,
#  'pcomp': 1,
#  'compound': 1,
#  'nsubjpass': 1,
#  'oprd': 1}

# %%
data["S0019103512003533-3348"].doc.ents
# Out:
# (Müller-Wodarg et al., 2006, 10°, 5 s)

# %%
list(data["S0019103512003533-3348"].doc.noun_chunks)
# Out:
# [The STIM GCM,
#  the transport,
#  winds,
#  molecular and turbulent diffusion,
#  key neutral species,
#  H,
#  H2,
#  He,
#  CH4,
#  H2O,
#  the procedures,
#  Müller-Wodarg et al.,
#  The global spherical grid,
#  flexible resolution,
#  simulations,
#  this study,
#  we,
#  latitude,
#  longitude,
#  2°,
#  10°,
#  a vertical resolution,
#  0.4 scale heights,
#  Our time integration step,
#  5 s,
#  we,
#  the code,
#  500 Saturn rotations,
#  steady state]

# %%
list(filter(lambda w: w.ent_type_ , data["S0019103512003533-3348"].doc))
# Out:
# [Müller-Wodarg et al., 2006, 10°, 5 s]

# %%
for w in list(data["S0019103512003533-3348"].doc): 
    print(w.ent_type_)
# Out:
# ORG
#
# DATE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# PRODUCT
#
#
#
#
#
#
#
#
#
#
# CARDINAL
