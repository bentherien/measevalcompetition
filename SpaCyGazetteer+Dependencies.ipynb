# %% [markdown]
# This notebook contains code for loading in all competition texts and annotations, and converting these to gate readable format

# %%
#imports
import pandas as pd
import os.path
from nltk.tokenize import word_tokenize
import nltk
import json

TRIALPATH = "data/trial"
TRAINPATH = "data/train"
LATEST_tsv = None

#setup SpaCy
import spacy
import en_core_web_lg
spacy.prefer_gpu()
nlp = en_core_web_lg.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4b44b664788f> in <module>
#      14 import en_core_web_lg
#      15 spacy.prefer_gpu()
# ---> 16 nlp = en_core_web_lg.load()
#
# C:\software_install\lib\site-packages\en_core_web_lg\__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\util.py in load_model_from_init_py(init_file, **overrides)
#     194     if not model_path.exists():
#     195         raise IOError(Errors.E052.format(path=path2str(data_path)))
# --> 196     return load_model_from_path(data_path, meta, **overrides)
#     197
#     198
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\util.py in load_model_from_path(model_path, meta, **overrides)
#     177             component = nlp.create_pipe(name, config=config)
#     178             nlp.add_pipe(component, name=name)
# --> 179     return nlp.from_disk(model_path)
#     180
#     181
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\language.py in from_disk(self, path, exclude, disable)
#     834             # Convert to list here in case exclude is (default) tuple
#     835             exclude = list(exclude) + ["vocab"]
# --> 836         util.from_disk(path, deserializers, exclude)
#     837         self._path = path
#     838         return self
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\util.py in from_disk(path, readers, exclude)
#     634         # Split to support file names like meta.json
#     635         if key.split(".")[0] not in exclude:
# --> 636             reader(path / key)
#     637     return path
#     638
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\language.py in <lambda>(p)
#     818         deserializers["meta.json"] = lambda p: self.meta.update(srsly.read_json(p))
#     819         deserializers["vocab"] = lambda p: self.vocab.from_disk(
# --> 820             p
#     821         ) and _fix_pretrained_vectors_name(self)
#     822         deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(
#
# vocab.pyx in spacy.vocab.Vocab.from_disk()
#
# C:\software_install\lib\pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1201             self._raise_closed()
#    1202         return io.open(self, mode, buffering, encoding, errors, newline,
# -> 1203                        opener=self._opener)
#    1204
#    1205     def read_bytes(self):
#
# C:\software_install\lib\pathlib.py in _opener(self, name, flags, mode)
#    1056     def _opener(self, name, flags, mode=0o666):
#    1057         # A stub for the opener argument to built-in open()
# -> 1058         return self._accessor.open(self, flags, mode)
#    1059
#    1060     def _raw_open(self, flags, mode=0o777):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\software_install\\lib\\site-packages\\en_core_web_lg\\en_core_web_lg-2.3.1\\vocab\\lexemes.bin'

# %%
#add pipeline component
from spacy.tokens import Doc
import math
Doc.set_extension("meAnnots", default = "def", force = True)
# Doc.set_extension("me-measuredEntity", default = "def", force = True)
# Doc.set_extension("me-quantityM", default = "def", force = True)
# Doc.set_extension("me-quantityC", default = "def", force = True)
# Doc.set_extension("me-measuredProperty", default = "def", force = True)
# Doc.set_extension("me-qualifier", default = "def", force = True)

def findOffset(offset, text):
    '''
    Corrects annotations whose offsets are not correct
    '''
    try:
        #find correct start offset
        if(text[offset] != " " and text[offset+1] != " "):
            return offset
            #no change
        elif(text[offset] != " " and text[offset+1] == " "):
            if(text[offset-1] == " "):
            #case where the word is one char
                return offset
                #no change
            else:
                return offset+2
                #skip ahead 2
        elif(text[offset] == " "):
            return offset + 1
        else:
            print("error, unhandled case in findOffset()")
            print("offset", offset)
            print("text", text)
            return offset
    except IndexError: 
        return offset

def getSentences(omin,omax,doc):
    sents = []
    for sent in doc.sents:
        if sent.end_char > omin and sent.start_char < omax:
            sents.append(sent)
            
    return sents
            

def annotationCreation(doc):
    doc._.meAnnots = {}
    count = 0
    lookup = {tok.idx : tok.i for tok in doc}
    annotminmax={}
    for index, row in LATEST_tsv.iterrows():
        if(row["annotType"] == "Quantity"):
            count+=1
            if count > 1:
                #set sentence values for each
                 doc._.meAnnots[f"Annotation{count-1}"]["sentences"] = getSentences(annotminmax[f"offset{count-1}min"],annotminmax[f"offset{count-1}max"],doc)
        
        #get min and max offsets
        try:
            annotminmax[f"offset{count}max"] = max(annotminmax[f"offset{count}max"],row["endOffset"])
        except KeyError:
             annotminmax[f"offset{count}max"] = row["endOffset"]
                
        try:
            annotminmax[f"offset{count}min"] = min(annotminmax[f"offset{count}min"],row["startOffset"])
        except KeyError:
             annotminmax[f"offset{count}min"] = row["startOffset"]
            
        
        #doc._.meAnnots[f"Annotation{count}"]
        
        #check for creating a new dict
        try:
            if(type(doc._.meAnnots[f"Annotation{count}"]) == type(dict)):
                continue
        except KeyError:
            print("added new dict")
            doc._.meAnnots[f"Annotation{count}"] = {}
        
        tempSpan = None
        
        try:
            tempSpan = doc[lookup[findOffset(row["startOffset"],doc.text)]:lookup[findOffset(row["endOffset"],doc.text)]]
            print(tempSpan)
        except KeyError:
            print("FindOffset method has created a key error")
            
        doc._.meAnnots[f"Annotation{count}"][row["annotType"]] = tempSpan
      
    doc._.meAnnots[f"Annotation{count}"]["sentences"] = getSentences(annotminmax[f"offset{count}min"],annotminmax[f"offset{count}max"],doc)
        
    return doc
                  
                  
                  
                  
                  
nlp.add_pipe(annotationCreation, last=True)

# %% [markdown]
# Rule-based Pipeline component for retrieving Quantities.
#
# Rules:
#     1. any CD followed by a unit that has a nouns POS
#     2. any cardinal, money, ordinal, percent, date, time or quantity followed by a unit that has a noun POS
#     3. any token that is LIKE_NUM followed by a unit that has a noun POS

# %%
#add pipeline component 
from spacy.matcher import Matcher
from spacy.tokens import Doc
Doc.set_extension("unit", default = "def", force = True)

def customMatcher(nlp):
    matchList = open("gazetteers/combined_measurements.lst","r",encoding="utf-8").read().split("\n")
    matcher = Matcher(nlp.vocab)
    pattern = []
    for word in matchList: 
        pattern.append([{"TAG": {"REGEX": "^[CD]"}},{"LOWER": word.lower(),"TAG": {"REGEX": "^[NN|NNP|NNPS|NNS]"}}])
        pattern.append([{"ENT_TYPE": {"IN": ["CARDINAL", "MONEY", "ORDINAL", "PERCENT", "DATE", "TIME", "QUANTITY"]},
                        "TAG":{"REGEX": "^[DT]"},"op": "!"},{"LOWER": word.lower(),"TAG": {"REGEX": "^[NN|NNP|NNPS|NNS]"}}])
        pattern.append([{"LIKE_NUM": True},{"LOWER": word.lower(),"TAG": {"REGEX": "^[NN|NNP|NNPS|NNS]"}}])
        #pattern.append([{"LOWER": word.lower(),"TAG": {"REGEX": "^[NN|NNP|NNPS|NNS]"}}])
        
    matcher.add("Unit", None, *pattern)
        
    return matcher
    

def gazetteer(doc):
    matcher = customMatcher(nlp)
    matches = matcher(doc)
    doc._.unit = []
    for match_id, start, end in matches:
        tempSpan = doc[start:end]
        doc._.unit.append({'start': tempSpan.start_char, 'end': tempSpan.end_char, 'label': 'UNIT', 'text' : doc[start:end]})
    return doc
        
        
        
nlp.add_pipe(gazetteer, last=True)

# %%
class exerpt:
    """
    Class exerpt
    Description: a simple class to contain data for the measeval competition

    self.name : the measeval given name associated to the document
    self.txt : the raw text of the document
    self.ann : the brat annotations of the document(deprecated)
    self.tsv : a pandas dataframe containing all the tab seperated value data
    self.grobid : grobid quantities json output for quantity detection
    self.doc : The spacy doc generated from processing on this particular document
    """
    
    def __init__(self, name, txt, ann, tsv, grobid):
        self.name = name
        self.txt = txt
        self.ann = ann
        self.tsv = tsv
        self.grobid = grobid
        self.context = False
        self.posTag = False
        global LATEST_tsv
        LATEST_tsv = self.tsv
        self.doc = nlp(self.txt)
        
    def getContext(self, count = 3):
        if self.context == False: 
            beforeContext = []
            afterContext = []
            self.context = True
            for start,end in zip(self.tsv["startOffset"].values, self.tsv["endOffset"].values ):#self.tsv.iterrows():
                a = getIndexSeperated(exerpt.txt[0],end,count = count)
                b = getIndexSeperated(exerpt.txt[0],start,count = count,forward = False)
                beforeContext.append(self.txt[0][b:start])
                afterContext.append(self.txt[0][end:a])
            self.tsv.insert(3,"beforeContext", beforeContext)
            self.tsv.insert(3,"afterContext", afterContext)
            
    def getPosTag(self):
        if self.context and self.posTag == False: 
            bTag = []
            aTag = []
            self.posTag = True
            for before, after in zip(self.tsv["beforeContext"].values,self.tsv["afterContext"].values):
                bTag.append(nltk.pos_tag(word_tokenize(before)))
                aTag.append(nltk.pos_tag(word_tokenize(after)))
            self.tsv.insert(3,"beforeTag", bTag)
            self.tsv.insert(3,"afterTag", aTag)

# %%
#
#TEST ONE
#

def readTXTByLine(filepath):
    ftemp = open(filepath, "r", encoding = "utf-8")
    raw = str(ftemp.read())
    ftemp.close()
    return raw

data = {}
#load all trial data
for fn in os.listdir(os.path.join(TRIALPATH,"txt")):
        if fn.endswith('.txt'):
            data[fn[:-4]] = exerpt(
                fn[:-4],
                readTXTByLine(os.path.join(TRIALPATH, "txt", fn[:-4] + ".txt")),
                readTXTByLine(os.path.join(TRIALPATH, "ann", fn[:-4] + ".ann")),
                pd.read_csv(os.path.join(TRIALPATH, "tsv", fn[:-4] + ".tsv"), "\t", header = 0 ),
                json.load(open(os.path.join(TRIALPATH, "grobid", fn[:-4] + ".grobid")))
            )
        break

# %%
import time
t1 = time.time()
def readTXTByLine(filepath):
    ftemp = open(filepath, "r", encoding = "utf-8")
    raw = str(ftemp.read())
    ftemp.close()
    return raw

data = {}

#load all trial data
for fn in os.listdir(os.path.join(TRIALPATH,"txt")):
        if fn.endswith('.txt'):
            data[fn[:-4]] = exerpt(
                fn[:-4],
                readTXTByLine(os.path.join(TRIALPATH, "txt", fn[:-4] + ".txt")),
                readTXTByLine(os.path.join(TRIALPATH, "ann", fn[:-4] + ".ann")),
                pd.read_csv(os.path.join(TRIALPATH, "tsv", fn[:-4] + ".tsv"), "\t", header = 0 ),
                json.load(open(os.path.join(TRIALPATH, "grobid", fn[:-4] + ".grobid")))
            )

#load all train data
for fn in [x for x in os.listdir(os.path.join(TRAINPATH,"text")) if x[:-4]+".tsv" in os.listdir(os.path.join(TRAINPATH,"tsv"))]:
        if fn.endswith('.txt'):
            data[fn[:-4]] = exerpt(
                fn[:-4],
                readTXTByLine(os.path.join(TRAINPATH, "text", fn[:-4] + ".txt")),
                "none",
                pd.read_csv(os.path.join(TRAINPATH, "tsv", fn[:-4] + ".tsv"), "\t", header = 0 ),
                json.load(open(os.path.join(TRAINPATH, "grobid", fn[:-4] + ".grobid"))))
            
t2 = time.time()
print(t2-t1, "Seconds elapsed")
print((t2-t1)/60, "Minutes elapsed")

# %%
count = 0 
for doc in data.values():
    for unit in doc.doc._.unit:
        count+=1
print(count)

# %%
import networkx as nx
def getGraphPathsShortest(sentences, quantity, measuredProperty, reverse):
    nonePassed = False
    
    if(type(sentences) == type(None)):
        print("sentences passed to getGraphPaths() as None")
        nonePassed = True
        
    if(type(quantity) == type(None)):
        print("quantity passed to getGraphPaths() as None")
        nonePassed = True
        
    if(type(measuredProperty) == type(None)):
        print("measuredProperty passed to getGraphPaths() as None")
        nonePassed = True
        
    if(nonePassed):
        return None
        
    if len(sentences) != 1:
        #cant handle more than one sentece so break
        print("more than one sentence")
        return None
    
    edges = []
    
    for sent in sentences:
        for token in sent:
            for child in token.children:
                edges.append(((token.text,token.i,token.dep_),
                              (child.text,child.i,child.dep_)))
             
    paths = {}
    graph = nx.Graph(edges)
    for src in quantity:
        for trg in measuredProperty:
            source = (src.text, src.i, src.dep_)
            target = (trg.text, trg.i, trg.dep_)
            shortestPath = nx.shortest_path(graph, source=source, target=target)
            print(nx.shortest_path_length(graph, source=source, target=target))
            print(shortestPath)
            paths[len(shortestPath)] = nx.shortest_path(graph, source=source, target=target)
    
    
    for x in sorted(list(paths.keys()),reverse=reverse):
        return paths[x][1:]     
    return paths


def getGraphPaths(sentences, quantity, measuredProperty, reverse=False, pos=False):
    nonePassed = False
    
    if(type(sentences) == type(None)):
        print("sentences passed to getGraphPaths() as None")
        nonePassed = True
        
    if(type(quantity) == type(None)):
        print("quantity passed to getGraphPaths() as None")
        nonePassed = True
        
    if(type(measuredProperty) == type(None)):
        print("measuredProperty passed to getGraphPaths() as None")
        nonePassed = True
        
    if(nonePassed):
        return None
        
    if len(sentences) != 1:
        #cant handle more than one sentece so break
        print("more than one sentence")
        return None
    
    edges = []
    
    for sent in sentences:
        for token in sent:
            for child in token.children:
                edges.append(((token.text,token.i,token.dep_),
                              (child.text,child.i,child.dep_)))
             
    paths = []
    graph = nx.Graph(edges)
    unique = {}
    for src in quantity:
        for trg in measuredProperty:
            source = (src.text, src.i, src.dep_)
            target = (trg.text, trg.i, trg.dep_)
            shortestPath = nx.shortest_path(graph, source=source, target=target)
            print(nx.shortest_path_length(graph, source=source, target=target))
            print(shortestPath)
            
            temp = nx.shortest_path(graph, source=source, target=target)
            if pos == True:
                temp.insert(0,(0,0,str(src.pos_)))
                paths.append(temp) 
                
            unique[src.pos_+temp[1][2]] = temp
            
    return list(unique.values())

# %%
count = 0 
accumPOS = []
accumNOPOS = []
prop = "MeasuredProperty"
tp = "Shortest"
for e in data.values():
    #print(e.name)
    doc = e.doc
    for annot in doc._.meAnnots.values():
        get = True
        
        try:
            tempSent = annot["sentences"]
        except KeyError:
            print("no Sentence found")
            get = False
            
        try:
            tempQuantity = annot["Quantity"]
        except KeyError:
            print("no Quantity found")
            get = False
            
        try:
            tempMeasuredProperty = annot["MeasuredProperty"]
        except KeyError:
            print("no MeasuredProperty found")
            get = False
        
        longest = True
        if tp == "Shortest":
            longest = False
            
        if(get):
            count+=1
            temp = getGraphPaths(tempSent, tempQuantity, tempMeasuredProperty, longest,True)
            temp1 = getGraphPaths(tempSent, tempQuantity, tempMeasuredProperty, longest,False)
            if temp != None:
                accumPOS.append((temp,(e.name,tempQuantity.text,tempMeasuredProperty.text)))
                accumNOPOS.append((temp1,(e.name,tempQuantity.text,tempMeasuredProperty.text)))

# %%
def getFreq(accum):
    d = {} 
    for y in accum:
        for x in y[0]:
            temp = "" 
            for t in x:
                try:
                    temp += t[2]+","
                except TypeError:
                    print(t)     
            try:
                d[temp[:-1]][0] += 1
                d[temp[:-1]][1].append(y[1])
            except KeyError: 
                d[temp[:-1]] = [1,[y[1]]]
    return {k: v for k, v in sorted(d.items(), key=lambda item: item[1],reverse=True)}
                
freqPos = getFreq(accumPOS)
freq = getFreq(accumNOPOS)

# %%
freqPos #NUM,nummod,pobj,prep,pobj
# Out:
# {'NUM,nummod,pobj,prep,pobj': [27,
#   [('S0016236113008041-913', '1000 ppm', 'SO2 concentrations'),
#    ('S0019103511004994-1511', '77.45°', 'points at an angle'),
#    ('S0019103512003533-3348', '2°', 'latitude'),
#    ('S0019103512003533-5072', 'around 1300 m s−1', 'peak velocities'),
#    ('S0019103512003995-1807', '300–800 nm.', 'wavelengths'),
#    ('S0006322312001096-1177', '73%,', 'response'),
#    ('S0006322312001096-1253', '65 years.', 'before the age'),
#    ('S0019103511004994-1399', '3.95 Saturn radii RS', 'distance'),
#    ('S0032386113009889-2123', 'about 70 MPa,', 'applied uniaxial stress'),
#    ('S0032386113009889-2123', '210 MPa', 'applied hydrostatic stress'),
#    ('S0921818113002245-1571', '8 m', 'depth'),
#    ('S0921818113002245-1571', 'approximately 11.8 m', 'depth'),
#    ('S0921818113002245-1571', 'between 11.8 m and 11.5 m', 'depth'),
#    ('S0921818113002245-1752', '5.16 m.', 'depth'),
#    ('S0925443913003037-654', '2.5 years', 'age'),
#    ('S0927024813002420-1032', '80 vol%', 'C60'),
#    ('S0927024813002420-975', '300±15 °C.', 'temperature'),
#    ('S0927024813002961-1334', '650–750 W/m2', 'irradiance range'),
#    ('S1359645413009816-2243', '1.5 nm', 'nominal resolution'),
#    ('S1359645413009816-2243', '5 K/min,', 'heating rate'),
#    ('S1359645413009816-2243',
#     'about 30 K/min',
#     'rapid cooling to ambient temperature at a rate'),
#    ('S1388248113001951-339', '12 mA g− 1', 'rate'),
#    ('S1873506113001116-1369', 'After 8 days', 'spinner flask'),
#    ('S2211124712002884-1110',
#     '5–6 days',
#     'grown as embryoid bodies (EBs) in suspension'),
#    ('S2213158213000582-1327', '5 mm per side', 'voxels'),
#    ('S2213671113000738-430', '3 months', 'after transplantation'),
#    ('S2213671113001306-1520', '30 degrees', 'visual field')]],
#  'NOUN,pobj,prep,pobj': [27,
#   [('S0016236113008041-3153', '<2 ppm', 'concentrations'),
#    ('S0016236113008041-913', '1000 ppm', 'SO2 concentrations'),
#    ('S0019103511004994-1511', '77.45°', 'points at an angle'),
#    ('S0019103512003533-3348', '2°', 'latitude'),
#    ('S0019103512003995-1807', '300–800 nm.', 'wavelengths'),
#    ('S0019103513005058-3094', '∼2 m', 'depth'),
#    ('S0019103513005058-4210', '2 m', 'depth'),
#    ('S0006322312001096-1177', '73%,', 'response'),
#    ('S0006322312001096-1253', '65 years.', 'before the age'),
#    ('S0019103511004994-1399', '3.95 Saturn radii RS', 'distance'),
#    ('S0019103513005058-4158', '0.51–0.85 m.', '1/e mixing depth'),
#    ('S0032386113009889-2123', 'about 70 MPa,', 'applied uniaxial stress'),
#    ('S0032386113009889-2123', '210 MPa', 'applied hydrostatic stress'),
#    ('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters'),
#    ('S0921818113002245-1571', '8 m', 'depth'),
#    ('S0921818113002245-1571', 'approximately 11.8 m', 'depth'),
#    ('S0921818113002245-1571', 'between 11.8 m and 11.5 m', 'depth'),
#    ('S0925443913003037-654', '2.5 years', 'age'),
#    ('S0927024813002420-975', '300±15 °C.', 'temperature'),
#    ('S1359645413009816-2243', '1.5 nm', 'nominal resolution'),
#    ('S1359645413009816-2243', '5 K/min,', 'heating rate'),
#    ('S1359645413009816-2243',
#     'about 30 K/min',
#     'rapid cooling to ambient temperature at a rate'),
#    ('S175058361300203X-1542', '±70 m/s', 'Vp'),
#    ('S1873506113001116-1369', 'After 8 days', 'spinner flask'),
#    ('S2211124712002884-1110',
#     '5–6 days',
#     'grown as embryoid bodies (EBs) in suspension'),
#    ('S2213671113000738-430', '3 months', 'after transplantation'),
#    ('S2213671113001306-1520', '30 degrees', 'visual field')]],
#  'PUNCT,punct,ROOT,nsubj': [12,
#   [('S0016236113008041-3031', 'from ∼50 ppm to ∼150 ppm.', 'Ti'),
#    ('S0006322312001096-1221', '1.24,', 'odds ratios'),
#    ('S0019103512004009-3976',
#     'increases from 2.6 km s−1 to 25 km s−1.',
#     'velocity'),
#    ('S0019103512004009-5033', 'near 1.4Rp.', 'transition'),
#    ('S0019103512004009-5033', '2–3Rp.', 'transition'),
#    ('S0019103512004009-5033', '3.4Rp,', 'transition'),
#    ('S0021979713004438-1401', '69 ± 3°,', 'contact angle'),
#    ('S0032063312003054-1990', '12 min,', 'time interval'),
#    ('S016412121300188X-4545', 'range from 11.4% to 2.4%.', 'sizes'),
#    ('S0378383912000130-3601', '1:10.', 'slope'),
#    ('S1750583613004192-1267', '40%,', 'lower limit'),
#    ('S2213671113000921-1279', 'greater than 70%.', 'gene targeting rates')]],
#  'NOUN,compound,pobj': [12,
#   [('S0012821X12004384-1415', 'on average 5%', 'peridinoid cysts'),
#    ('S0012821X13002185-1217', '0.2 M', 'NaOH'),
#    ('S0006322312001096-1194', '10%', 'increment'),
#    ('S0006322312001096-1221', '10%', 'increase'),
#    ('S0012821X12004384-1284', '>250 μm', 'size fractions'),
#    ('S0019103512004009-5033', '30 nbar', 'level'),
#    ('S0025322712001600-2406', 'better than 5%', 'weight'),
#    ('S0025322712001600-2406', '95%', 'confidence level'),
#    ('S0167577X14001256-389', '4 nm', 'width'),
#    ('S0167880913001229-1225', '0–10 cm', 'depth'),
#    ('S0167880913001229-1304', '0–10 cm', 'depth'),
#    ('S0167880913001229-1304', '0–40 cm', 'depth')]],
#  'NUM,nummod,pobj': [11,
#   [('S0012821X13002185-1217', '0.2 M', 'NaOH'),
#    ('S0019103512003995-1910', 'one', 'solar rotation'),
#    ('S0012821X12004384-1221', 'between 200 and >1000 m', 'depth'),
#    ('S0012821X12004384-1284', '>250 μm', 'size fractions'),
#    ('S0019103513005058-3917', 'zero', 'deposition velocity'),
#    ('S0032063312003054-2501', '689', 'events'),
#    ('S0167880913001229-1225', '0–10 cm', 'depth'),
#    ('S0167880913001229-1304', '0–10 cm', 'depth'),
#    ('S0378383911001669-1634', '1:10', 'slope'),
#    ('S2213158213000582-1327', '96', 'cortical gray-matter regions'),
#    ('S2213671113001306-1520', '30-degrees', 'visual-field setting')]],
#  'NOUN,pobj,prep,ROOT': [10,
#   [('S0021979713004438-1907', '10 min', 'interrupted'),
#    ('S0006322312001096-1190', '−4°C', 'refrigerated'),
#    ('S0038071712001010-1044', '84 days', 'lasted'),
#    ('S0169433213008933-689', '240 s', 'processed'),
#    ('S0927024813001955-679', 'after 200 days', 'maintained'),
#    ('S0927775713009606-1074', '5–40 nm range', 'characterised'),
#    ('S1388248113001951-339', '4.0 V', 'charged'),
#    ('S1873506114000075-1132', '48 h', 'changed'),
#    ('S2211124712002884-1110', 'after 3–4 weeks,', 'dissociated'),
#    ('S2211124712002884-1110', 'after 2-4 weeks', 'used')]],
#  'NOUN,pobj,prep,dobj': [10,
#   [('S0019103512002801-1927', '0.1–0.2 s−1', 'linear growth rate'),
#    ('S0019103512003995-3548', 'about 8250 K', 'temperature'),
#    ('S0019103512004009-4007',
#     '93%',
#     'constant photoelectron heating efficiency'),
#    ('S0019103512004009-5019', '20 eV', 'energy'),
#    ('S0012821X12004384-1221', '>0.5 km', 'paleodepths'),
#    ('S0019103513005058-3917', '0.02 cm s−1', 'deposition velocity'),
#    ('S0167819113001051-1247',
#     'from 50% to around 80%.',
#     'improve the usability'),
#    ('S0168945213001805-4775', '−8 °C', 'stable tolerance'),
#    ('S0927775713009606-1216', '0.1°', 'step size'),
#    ('S0927775713009606-1361', '0.097 nm', 'ionic radius')]],
#  'NUM,nummod,pobj,prep,ROOT': [9,
#   [('S0021979713004438-1907', '10 min', 'interrupted'),
#    ('S0038071712001010-1044', '84 days', 'lasted'),
#    ('S0169433213008933-689', '240 s', 'processed'),
#    ('S0927024813001955-679', 'after 200 days', 'maintained'),
#    ('S1388248113001951-339', '4.0 V', 'charged'),
#    ('S1873506113001116-710', 'after 48 h', 'Light microscope image'),
#    ('S1873506114000075-1132', '48 h', 'changed'),
#    ('S2211124712002884-1110', 'after 3–4 weeks,', 'dissociated'),
#    ('S2211124712002884-1110', 'after 2-4 weeks', 'used')]],
#  'NUM,nummod,attr,ROOT,nsubj': [9,
#   [('S0016236113008041-3171', '<0.1 ppm', 'flue gas concentrations'),
#    ('S0021979713004438-1969', '3.91 nm', 'Rq value'),
#    ('S0006322312001096-1197', '80%', 'sensitivity'),
#    ('S0021979713004438-1401', '69 ± 3°,', 'contact angle'),
#    ('S0032063312003054-1990', '12 min,', 'time interval'),
#    ('S0032063312003054-2264', 'around 100 km,', 'gyroradius'),
#    ('S0167610513001001-739', '7.83 m s−1', 'speed'),
#    ('S030881461301604X-1002', '100 mg/L', 'concentrations'),
#    ('S2213671113000921-1279', 'greater than 70%.', 'gene targeting rates')]],
#  'NUM,nummod,compound,pobj': [9,
#   [('S0012821X12004384-1415', 'on average 5%', 'peridinoid cysts'),
#    ('S0006322312001096-1194', '10%', 'increment'),
#    ('S0006322312001096-1221', '10%', 'increase'),
#    ('S0019103512003995-1767', '1083 nm', 'line'),
#    ('S0019103512004009-5033', '30 nbar', 'level'),
#    ('S0025322712001600-2406', 'better than 5%', 'weight'),
#    ('S0025322712001600-2406', '95%', 'confidence level'),
#    ('S0167577X14001256-389', '4 nm', 'width'),
#    ('S0167880913001229-1304', '0–40 cm', 'depth')]],
#  'NUM,nummod,pobj,prep,dobj': [8,
#   [('S0019103512003995-3548', 'about 8250 K', 'temperature'),
#    ('S0019103512004009-4007',
#     '93%',
#     'constant photoelectron heating efficiency'),
#    ('S0019103512004009-5019', '20 eV', 'energy'),
#    ('S0012821X12004384-1221', '>0.5 km', 'paleodepths'),
#    ('S0019103513005058-4349', 'six orders of magnitude', 'deposition rate'),
#    ('S0167819113001051-1247',
#     'from 50% to around 80%.',
#     'improve the usability'),
#    ('S0927775713009606-1216', '0.1°', 'step size'),
#    ('S0927775713009606-1361', '0.097 nm', 'ionic radius')]],
#  'NUM,nummod,pobj,prep,conj': [7,
#   [('S0019103512003533-3299', '50%,', 'heating efficiencies'),
#    ('S0006322312001096-1190', 'within 72 hours.', 'assayed'),
#    ('S0019103512001388-3081', 'December 16', 'declined'),
#    ('S0019103513005058-4098', 'from 211 K to 284 K', 'increased'),
#    ('S0167577X14001256-517', '55 K.', 'specimen temperature'),
#    ('S0378383912000130-3601', '62 mm', 'level'),
#    ('S2213671113000738-738', '6 months', 'withdrawn')]],
#  'NOUN,compound,pobj,prep,pobj': [7,
#   [('S0019103512002801-1849', '1%', 'level of Erk'),
#    ('S0019103512003533-5072', 'around 1300 m s−1', 'peak velocities'),
#    ('S0019103513005058-3094', '∼2 m', 'depth'),
#    ('S0019103511004994-1399', '3.95 Saturn radii RS', 'distance'),
#    ('S0031405612000728-1621', '7 month', 'course'),
#    ('S0927024813002420-975', '300±15 °C.', 'temperature'),
#    ('S095741741101342X-726', '85/15%', 'good/bad observations')]],
#  'NOUN,attr,ROOT,nsubj': [7,
#   [('S0016236113008041-3171', '<0.1 ppm', 'flue gas concentrations'),
#    ('S0021979713004438-1969', '3.91 nm', 'Rq value'),
#    ('S0006322312001096-1197', '80%', 'sensitivity'),
#    ('S0021979713004438-1401', '69 ± 3°,', 'contact angle'),
#    ('S0032063312003054-1990', '12 min,', 'time interval'),
#    ('S0032063312003054-2264', 'around 100 km,', 'gyroradius'),
#    ('S2213671113000921-1279', 'greater than 70%.', 'gene targeting rates')]],
#  'NOUN,pobj,prep,conj': [6,
#   [('S0019103512003533-3299', '50%,', 'heating efficiencies'),
#    ('S0019103512003533-3348', '0.4 scale heights.', 'vertical resolution'),
#    ('S0006322312001096-1190', 'within 72 hours.', 'assayed'),
#    ('S0019103513005058-4098', 'from 211 K to 284 K', 'increased'),
#    ('S0378383912000130-3601', '62 mm', 'level'),
#    ('S2213671113000738-738', '6 months', 'withdrawn')]],
#  'NOUN,appos,pobj': [6,
#   [('S0012821X13007309-1989', '25%)', 'from the LIP'),
#    ('S0019103513005058-3094', '0.1%', 'time-average volcanic flux'),
#    ('S0022000014000026-17824', 'μs)', 'skew'),
#    ('S0006322312001096-1197', '73%)', 'sensitivity'),
#    ('S0927024813002420-975',
#     '20–25 monomer units,',
#     'effective conjugation length'),
#    ('S0927775713009606-1361', '0.19–0.21 nm)', 'distances')]],
#  'NUM,nummod,pobj,prep,nsubjpass': [5,
#   [('S0032386113005454-2308', '3.19 ± 0.10 GPa', 'tensile modulus'),
#    ('S0167610512002292-3305', '35 m/s', 'wind speed'),
#    ('S0378383912000130-3601', '62 mm', 'level'),
#    ('S0921818113002245-859', 'approximately 19 m', 'deepest point'),
#    ('S1873506113001116-978', '10 passages', 'cultured')]],
#  'NOUN,pobj,prep,nsubjpass': [5,
#   [('S0032386113005454-2308', '3.19 ± 0.10 GPa', 'tensile modulus'),
#    ('S0167610512002292-3305', '35 m/s', 'wind speed'),
#    ('S0378383912000130-3601', '62 mm', 'level'),
#    ('S0921818113002245-859', 'approximately 19 m', 'deepest point'),
#    ('S1873506113001116-978', '10 passages', 'cultured')]],
#  'ADP,prep,ROOT': [5,
#   [('S0019103512001388-1070', 'two days before', 'taken'),
#    ('S0927024813001955-679', 'after 200 days', 'maintained'),
#    ('S1873506113001116-710', 'after 48 h', 'Light microscope image'),
#    ('S2211124712002884-1110', 'after 3–4 weeks,', 'dissociated'),
#    ('S2211124712002884-1110', 'after 2-4 weeks', 'used')]],
#  'NUM,pobj,prep,pobj': [5,
#   [('S0016236113008041-3269', '0,', 'concentrations'),
#    ('S0016236113008041-3290', '0.63', 'concentrations'),
#    ('S0019103512002801-1342', '8.74Rs', 'distance'),
#    ('S0019103512003533-5072', 'around 1300 m s−1', 'peak velocities'),
#    ('S0006322312001096-1278', '65,', 'age')]],
#  'PROPN,nmod,pobj,prep,pobj': [5,
#   [('S0016236113008041-3153', '<2 ppm', 'concentrations'),
#    ('S0927024813002961-1334', '650–750 W/m2', 'irradiance range'),
#    ('S1359645413009816-2243', '5 K/min,', 'heating rate'),
#    ('S1359645413009816-2243',
#     'about 30 K/min',
#     'rapid cooling to ambient temperature at a rate'),
#    ('S175058361300203X-1542', '±70 m/s', 'Vp')]],
#  'PUNCT,punct,ROOT,prep,pobj': [5,
#   [('S0006322312001096-1177', '73%,', 'response'),
#    ('S0006322312001096-1275', 'range 66% to 88%)', 'response'),
#    ('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters'),
#    ('S0927024813002420-975', '300±15 °C.', 'temperature'),
#    ('S0927775713009606-1074', '1 (w/w),', 'ratio')]],
#  'ADP,prep,pobj,prep,pobj': [4,
#   [('S0960148113002048-3775', 'above 0.003 Hz,', 'frequencies'),
#    ('S175058361300203X-1542', 'range of 34–38 °C', 'temperatures'),
#    ('S1873506113001116-1369', 'After 8 days', 'spinner flask'),
#    ('S2213158213000582-1327', '5 mm per side', 'voxels')]],
#  'SYM,punct,pobj,prep,pobj': [4,
#   [('S0927024813002961-1334', '650–750 W/m2', 'irradiance range'),
#    ('S1359645413009816-2243', '5 K/min,', 'heating rate'),
#    ('S1359645413009816-2243',
#     'about 30 K/min',
#     'rapid cooling to ambient temperature at a rate'),
#    ('S175058361300203X-1542', '±70 m/s', 'Vp')]],
#  'NOUN,pobj,prep,pobj,prep,pobj': [4,
#   [('S0032063312003054-2264', '400 km.', 'horizontal size'),
#    ('S0927024813001955-576', '1 h.', 'post-annealed'),
#    ('S175058361300203X-1542', 'range of 34–38 °C', 'temperatures'),
#    ('S2213158213000582-1327', '5 mm per side', 'voxels')]],
#  'NUM,nummod,pobj,prep,appos': [4,
#   [('S0019103513005058-1737', '1 g cm−3,', 'soil density'),
#    ('S0167577X14001256-517', '0.5–0.6 nJ,', 'laser energy'),
#    ('S0167577X14001256-517', '250 kHz,', 'laser-pulse repetition rate'),
#    ('S0167577X14001256-517', '4–7 kV,', 'DC bias voltage')]],
#  'PROPN,pobj,prep,dobj': [4,
#   [('S0019103512002801-1927', '5–10 s,', 'growth time'),
#    ('S0019103512003533-3306', 'above ∼500 K.', 'temperatures'),
#    ('S0168945213001805-4775', '−8 °C', 'stable tolerance'),
#    ('S0927024813001955-679', '3.4+0.1 cm2/Vs,', 'electron mobility')]],
#  'NOUN,conj,pobj,prep,pobj': [4,
#   [('S0016236113008041-3290', '0.51 ppm', 'concentrations'),
#    ('S0016236113008041-913', '2000 ppm,', 'SO2 concentrations'),
#    ('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters'),
#    ('S0921818113002245-1571', 'between 11.8 m and 11.5 m', 'depth')]],
#  'PUNCT,punct,pobj,prep,pobj': [4,
#   [('S0016236113008041-3269', '0,', 'concentrations'),
#    ('S0016236113008041-913', '2000 ppm,', 'SO2 concentrations'),
#    ('S0032386113009889-2123', 'about 70 MPa,', 'applied uniaxial stress'),
#    ('S1359645413009816-2243', '5 K/min,', 'heating rate')]],
#  'PUNCT,punct,pobj': [4,
#   [('S0012821X13007309-1989', '25%)', 'from the LIP'),
#    ('S0022000014000026-17824', 'μs)', 'skew'),
#    ('S0006322312001096-1197', '73%)', 'sensitivity'),
#    ('S0927775713009606-1361', '0.19–0.21 nm)', 'distances')]],
#  'PROPN,pobj,prep,pobj': [4,
#   [('S0012821X13002185-1231', '∼–1‰', 'apparent 30ε'),
#    ('S0927024813002961-1334', '650–750 W/m2', 'irradiance range'),
#    ('S0960148113002048-3775', '0.01–0.03 Hz,', 'frequencies'),
#    ('S1388248113001951-339', '12 mA g− 1', 'rate')]],
#  'ADP,prep,pobj': [4,
#   [('S0012821X12004384-1415', 'on average 5%', 'peridinoid cysts'),
#    ('S0012821X12004384-1221', 'between 200 and >1000 m', 'depth'),
#    ('S0031405612000728-1621', 'over a 7-month', 'period'),
#    ('S0921818113002245-1571', 'between 11.8 m and 11.5 m', 'depth')]],
#  'NOUN,pobj,prep,ccomp': [4,
#   [('S0012821X12004384-1178', '5–8 °C', 'rise'),
#    ('S0167577X13006393-787', 'before 1200 °C', 'occurs'),
#    ('S0167880913001229-1021', '12.4%', 'decreased'),
#    ('S1750583613004192-714', '3 years.', 'migrated')]],
#  'NUM,attr,ROOT,nsubj': [4,
#   [('S0006322312001096-1194', '1.34', 'odds ratios'),
#    ('S0006322312001096-1221', '1.40', 'odds ratios'),
#    ('S0167610513001001-739', '7.83 m s−1', 'speed'),
#    ('S0378383912000130-3601', '1:10.', 'slope')]],
#  'NOUN,compound,pobj,prep,ROOT': [4,
#   [('S0006322312001096-1190', '−4°C', 'refrigerated'),
#    ('S0032386113005454-2008', 'about −100 °C', 'toughened'),
#    ('S0927775713009606-1074', '5–40 nm range', 'characterised'),
#    ('S1873506113001116-710', 'after 48 h', 'Light microscope image')]],
#  'ADJ,amod,amod': [3,
#   [('S2211124712002884-903', '67-year-', 'old'),
#    ('S2211124712002884-903', '64-year-', 'old'),
#    ('S2211124712002884-903', '64-year', 'old')]],
#  'PUNCT,punct,pobj,appos': [3,
#   [('S0167577X14001256-517', '250 kHz,', 'laser-pulse repetition rate'),
#    ('S0167577X14001256-517', '4–7 kV,', 'DC bias voltage'),
#    ('S0927775713009606-1074', '> 10 nm;', 'pore diameters')]],
#  'NUM,nummod,pobj,prep,ROOT,prep,pobj': [3,
#   [('S0165587612003680-953',
#     'more than 90%',
#     'biofilms have been identified on human middle ear mucosa'),
#    ('S0925443913001385-1638',
#     '30%',
#     "steady state level of MRPL12 in the subject's fibroblasts"),
#    ('S0927024813001955-576', 'one week', 'storage in the dark')]],
#  'NOUN,pobj,prep,ROOT,prep,pobj': [3,
#   [('S0165587612003680-953',
#     'more than 90%',
#     'biofilms have been identified on human middle ear mucosa'),
#    ('S0925443913001385-1638',
#     '30%',
#     "steady state level of MRPL12 in the subject's fibroblasts"),
#    ('S0927024813001955-576', 'one week', 'storage in the dark')]],
#  'PUNCT,punct,ROOT': [3,
#   [('S016412121300188X-5066', 'from 78% to 95%,', 'improves'),
#    ('S1750583613004192-714', '1999,', 'first appeared'),
#    ('S2211124712002884-1110', 'after 3–4 weeks,', 'dissociated')]],
#  'NUM,nummod,pobj,prep,nsubj': [3,
#   [('S016412121300188X-4392', '1/', 'precision'),
#    ('S1387700313001822-661', '215–225 nm', 'negative band'),
#    ('S2213671113000738-445', '48 hr', 'Incubation')]],
#  'NUM,nummod,dobj,ROOT': [3,
#   [('S016412121300188X-4069', '9438 lines of code', 'contains'),
#    ('S0378383912000130-3601', 'two beach materials', 'involved'),
#    ('S2213671113000908-979', '12 hr', 'visually inspected')]],
#  'NOUN,dobj,ROOT': [3,
#   [('S016412121300188X-4069', '9438 lines of code', 'contains'),
#    ('S0378383912000130-3601', 'two beach materials', 'involved'),
#    ('S2213671113000908-979', '12 hr', 'visually inspected')]],
#  'NUM,nummod,pobj,prep,pobj,prep,pobj': [3,
#   [('S0032063312003054-2264', '400 km.', 'horizontal size'),
#    ('S0927024813001955-576', '1 h.', 'post-annealed'),
#    ('S0960148113002048-3775', 'above 0.003 Hz,', 'frequencies')]],
#  'PUNCT,punct,ROOT,nsubjpass': [3,
#   [('S0021979713004438-1415', '25 ± 0.02 °C,', 'temperature'),
#    ('S0032386113005454-2865', '0.296 μm.', 'mean diameter'),
#    ('S2213671113001306-1520', '4.2 mm.', 'corneal curvature settings')]],
#  'NOUN,compound,dobj': [3,
#   [('S0019103513005058-3154', '⩽1.6%', 'perchlorate'),
#    ('S0927024813002961-1051', 'up to 25%', 'variation'),
#    ('S2213671113001306-910', '0.2 μm', 'distance')]],
#  'NOUN,pobj,prep,appos': [3,
#   [('S0019103513005058-1737', '1 g cm−3,', 'soil density'),
#    ('S0019103513005058-4098', '∼35%', 'increase'),
#    ('S0167577X14001256-517', '250 kHz,', 'laser-pulse repetition rate')]],
#  'NUM,pobj,prep,ROOT,nsubj': [3,
#   [('S0019103512004009-3976',
#     'increases from 2.6 km s−1 to 25 km s−1.',
#     'velocity'),
#    ('S0019103512004009-5033', 'near 1.4Rp.', 'transition'),
#    ('S0019103512004009-5033', '2–3Rp.', 'transition')]],
#  'NOUN,pobj,prep,pobj,prep,dobj': [3,
#   [('S0019103512004009-2821',
#     '7000 K',
#     'mean (pressure averaged) temperature'),
#    ('S0019103513005058-4349', 'six orders of magnitude', 'deposition rate'),
#    ('S175058361300203X-1483', '20–25%', 'effective porosities')]],
#  'NOUN,attr,xcomp,ROOT,nsubjpass': [3,
#   [('S0019103512003995-1910', '∼10–11 days', 'rotation period'),
#    ('S0032386113005454-2601', '63 MPa', 'lowest value'),
#    ('S0032386113005454-2865', '0.296 μm.', 'mean diameter')]],
#  'NUM,nummod,compound,pobj,prep,conj': [3,
#   [('S0019103512003533-3348', '0.4 scale heights.', 'vertical resolution'),
#    ('S0006322312001096-1190', '2 hours', 'taken'),
#    ('S0927024813002420-1032', '70 nm', 'thickness')]],
#  'NOUN,compound,pobj,prep,conj': [3,
#   [('S0019103512003533-3348', '0.4 scale heights.', 'vertical resolution'),
#    ('S0006322312001096-1190', '2 hours', 'taken'),
#    ('S0927024813002420-1032', '70 nm', 'thickness')]],
#  'NUM,nummod,compound,pobj,prep,pobj': [3,
#   [('S0019103512002801-1849', '1%', 'level of Erk'),
#    ('S0031405612000728-1621', '7 month', 'course'),
#    ('S095741741101342X-726', '85/15%', 'good/bad observations')]],
#  'PROPN,pobj,prep,conj': [3,
#   [('S0019103512001388-3081', 'December 16', 'declined'),
#    ('S0019103513005058-4098', 'from 211 K to 284 K', 'increased'),
#    ('S0167577X14001256-517', '55 K.', 'specimen temperature')]],
#  'NUM,nummod,pobj,prep': [3,
#   [('S0019103511004994-1511',
#     '86 s, nominally.',
#     'rotates about the −y-axis of the spacecraft within'),
#    ('S0012821X12004384-1284', '24 h', 'were refluxed for'),
#    ('S2213671113001306-1520', '60 μm', 'distance between')]],
#  'NUM,nummod,conj,pobj,prep,pobj': [3,
#   [('S0016236113008041-3290', '0.51 ppm', 'concentrations'),
#    ('S0016236113008041-913', '2000 ppm,', 'SO2 concentrations'),
#    ('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters')]],
#  'NUM,compound,pobj,prep,pobj': [3,
#   [('S0016236113008041-3153', '<2 ppm', 'concentrations'),
#    ('S0019103513005058-4210', '2 m', 'depth'),
#    ('S0019103513005058-4158', '0.51–0.85 m.', '1/e mixing depth')]],
#  'PUNCT,punct,dobj': [3,
#   [('S0012821X13007309-1989', 'to 600 ppt;', 'Os abundances'),
#    ('S0012821X13007309-1989', '100 ppt)', 'Os abundances'),
#    ('S0019103512002801-1927', '5–10 s,', 'growth time')]],
#  'NUM,nummod,pobj,prep,pobj,prep,dobj': [3,
#   [('S0012821X13007309-1989', '30 ppt', 'Os abundance'),
#    ('S0019103512004009-2821',
#     '7000 K',
#     'mean (pressure averaged) temperature'),
#    ('S175058361300203X-1483', '20–25%', 'effective porosities')]],
#  'NUM,nummod,appos,pobj': [3,
#   [('S0012821X13007309-1989', '25%)', 'from the LIP'),
#    ('S0019103513005058-3094', '0.1%', 'time-average volcanic flux'),
#    ('S0006322312001096-1197', '73%)', 'sensitivity')]],
#  'NUM,pobj,prep,appos': [3,
#   [('S0012821X13007309-1989', '0.13', '187Os/188Os'),
#    ('S0006322312001096-1221', '1.14', 'odds ratio'),
#    ('S0167577X14001256-517', '0.5–0.6 nJ,', 'laser energy')]],
#  'NOUN,npadvmod,amod': [3,
#   [('S0012821X13007309-1482', '17.7 m', 'thick'),
#    ('S0927024813001955-576', '125 nm', 'thick'),
#    ('S2211124712002884-1110', 'Ten-day', 'old')]],
#  'NOUN,compound,pobj,prep,ROOT,punct': [3,
#   [('S0006322312001096-626', '10%', 'Increase)'),
#    ('S0019103513005058-4158', '∼2 m.', 'depth,'),
#    ('S0032386113005454-2865', '−109 °C,', 'cavitated,')]],
#  'PUNCT,punct,ROOT,dobj': [3,
#   [('S0006322312001096-1177', 'approximately every 5 years:', 'taken place'),
#    ('S0012821X12004384-1284', '±<0.1.', 'precision'),
#    ('S0032063312003054-2483',
#     'between ∼01:25:00 UT and 01:25:40 UT,',
#     'acceleration')]],
#  'NUM,nummod,appos,appos': [3,
#   [('S0006322312001096-1177', '6967', 'n'),
#    ('S0927775713009606-1074', '> 0.5 cm3 g−1)', 'Vmeso'),
#    ('S0927775713009606-1074', '> 170 m2 g−1', 'SBET')]],
#  'NUM,nummod,attr,conj,ROOT': [2,
#   [('S2213158213000582-1340', '95.81%', 'average percent variance explained'),
#    ('S2213158213000582-1340',
#     '96.24%',
#     'average percent variance explained')]],
#  'NOUN,attr,conj,ROOT': [2,
#   [('S2213158213000582-1340', '95.81%', 'average percent variance explained'),
#    ('S2213158213000582-1340',
#     '96.24%',
#     'average percent variance explained')]],
#  'NUM,nummod,conj,attr,conj,ROOT': [2,
#   [('S2213158213000582-1340', '94.38%', 'average percent variance explained'),
#    ('S2213158213000582-1340',
#     '93.17%',
#     'average percent variance explained')]],
#  'NOUN,conj,attr,conj,ROOT': [2,
#   [('S2213158213000582-1340', '94.38%', 'average percent variance explained'),
#    ('S2213158213000582-1340',
#     '93.17%',
#     'average percent variance explained')]],
#  'NUM,nummod,dobj': [2,
#   [('S2213158213000582-1340', '30–130 ms', 'examined activity'),
#    ('S2213671113001306-910', '0.2 μm', 'distance')]],
#  'PUNCT,punct,amod': [2,
#   [('S2211124712002884-903', '67-year-', 'old'),
#    ('S2211124712002884-903', '64-year-', 'old')]],
#  'NUM,nummod,nsubj,conj,acomp,prep,pobj': [2,
#   [('S1873506114000075-1242',
#     'approximately 88 ± 1.1%',
#     'AFP-positive on D13'),
#    ('S1873506114000075-1242',
#     'approximately 29 ± 0.9%',
#     'ALB-positive on D20')]],
#  'NOUN,nsubj,conj,acomp,prep,pobj': [2,
#   [('S1873506114000075-1242',
#     'approximately 88 ± 1.1%',
#     'AFP-positive on D13'),
#    ('S1873506114000075-1242',
#     'approximately 29 ± 0.9%',
#     'ALB-positive on D20')]],
#  'NOUN,pobj,prep,nsubj': [2,
#   [('S1387700313001822-661', '215–225 nm', 'negative band'),
#    ('S2213671113000738-445', '48 hr', 'Incubation')]],
#  'NUM,nummod,pobj,prep,ROOT,nsubj,acl': [2,
#   [('S0960148113004989-3327', '22%', 'averaged power extracted'),
#    ('S0960148113004989-3327',
#     '48.4 MW to 59.0 MW',
#     'averaged power extracted')]],
#  'NUM,nummod,pobj,prep,advcl': [2,
#   [('S0950705113001895-23699', 'from 10% to 100%', 'increases'),
#    ('S2213671113000908-640', '25 days', 'differentiated')]],
#  'NOUN,pobj,prep,advcl': [2,
#   [('S0950705113001895-23699', 'from 10% to 100%', 'increases'),
#    ('S2213671113000908-640', '25 days', 'differentiated')]],
#  'PROPN,appos,appos': [2,
#   [('S0927775713009606-1074', '> 0.5 cm3 g−1)', 'Vmeso'),
#    ('S0927775713009606-1074', '> 170 m2 g−1', 'SBET')]],
#  'NUM,nummod,npadvmod,amod': [2,
#   [('S0927024813001955-576', '125 nm', 'thick'),
#    ('S2211124712002884-1110', 'Ten-day', 'old')]],
#  'CCONJ,cc,pobj,prep,pobj': [2,
#   [('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters'),
#    ('S0921818113002245-1571', 'between 11.8 m and 11.5 m', 'depth')]],
#  'NUM,nummod,pobj,punct,dep': [2,
#   [('S0378383911001669-1088', '0.072 m', 'x'),
#    ('S0378383912000130-3745', '1980 mm,', 'x')]],
#  'NOUN,pobj,punct,dep': [2,
#   [('S0378383911001669-1088', '0.072 m', 'x'),
#    ('S0378383912000130-3745', '1980 mm,', 'x')]],
#  'PUNCT,punct,parataxis': [2,
#   [('S0378112713005288-2062', '1 kg)', 'weigh'),
#    ('S0378112713005288-2062', '1 kg)', 'weigh')]],
#  'PROPN,attr,ROOT,nsubj': [2,
#   [('S030881461301604X-1002', '100 mg/L', 'concentrations'),
#    ('S0927024813003036-2011', '≤1.5×1012 cm−3', 'bulk iron concentrations')]],
#  'NUM,nummod,pobj,prep,ccomp': [2,
#   [('S0167880913001229-1021', '12.4%', 'decreased'),
#    ('S1750583613004192-714', '3 years.', 'migrated')]],
#  'ADV,advmod,nummod,pobj,prep,pobj': [2,
#   [('S0032386113009889-2123', 'about 70 MPa,', 'applied uniaxial stress'),
#    ('S1359645413009816-2243',
#     'about 30 K/min',
#     'rapid cooling to ambient temperature at a rate')]],
#  'NUM,nummod,attr,xcomp,ROOT,nsubjpass': [2,
#   [('S0032386113005454-2601', '63 MPa', 'lowest value'),
#    ('S0032386113005454-2865', '0.296 μm.', 'mean diameter')]],
#  'NUM,nummod,nsubjpass': [2,
#   [('S0022459611006116-1160', '1:1', 'ratios'),
#    ('S0032063312003054-2501', '37', 'events')]],
#  'NUM,nummod,appos,prep,pobj': [2,
#   [('S0022399913003358-943', '50%', 'with chronic tinnitus'),
#    ('S2213158213000582-1327', '48', 'regions in each hemisphere')]],
#  'ADP,prep,pobj,prep,dobj': [2,
#   [('S0019103513005058-4349', 'six orders of magnitude', 'deposition rate'),
#    ('S0032063312003054-2483',
#     'between ∼01:25:00 UT and 01:25:40 UT,',
#     'acceleration')]],
#  'NOUN,compound,pobj,prep,dobj': [2,
#   [('S0019103513005058-3917', '0.02 cm s−1', 'deposition velocity'),
#    ('S0168945213001805-4775', '−8 °C', 'stable tolerance')]],
#  'NUM,nummod,pobj,prep,advcl,nsubj': [2,
#   [('S0019103512004009-5507', 'near 1 μbar,', 'base'),
#    ('S0016236113008041-3161', '<2 ppm,', 'concentrations')]],
#  'NOUN,pobj,prep,advcl,nsubj': [2,
#   [('S0019103512004009-5507', 'near 1 μbar,', 'base'),
#    ('S0016236113008041-3161', '<2 ppm,', 'concentrations')]],
#  'PUNCT,punct,conj,nsubj': [2,
#   [('S0019103512004009-5507', '8250 K,', 'mean temperature'),
#    ('S0019103512004009-3976', '30 km s−1.', 'velocity')]],
#  'ADP,prep,prep,ROOT,nsubj': [2,
#   [('S0019103512004009-3976',
#     'increases from 2.6 km s−1 to 25 km s−1.',
#     'velocity'),
#    ('S016412121300188X-4545', 'range from 11.4% to 2.4%.', 'sizes')]],
#  'NOUN,pobj,prep,prep,ROOT,nsubj': [2,
#   [('S0019103512004009-3976',
#     'increases from 2.6 km s−1 to 25 km s−1.',
#     'velocity'),
#    ('S016412121300188X-4545', 'range from 11.4% to 2.4%.', 'sizes')]],
#  'PUNCT,punct,ROOT,conj': [2,
#   [('S0019103512003533-3348', '0.4 scale heights.', 'vertical resolution'),
#    ('S0006322312001096-1190', 'within 72 hours.', 'assayed')]],
#  'ADP,prep,dobj': [2,
#   [('S0019103512003533-3306', 'above ∼500 K.', 'temperatures'),
#    ('S0167819113001051-1247',
#     'from 50% to around 80%.',
#     'improve the usability')]],
#  'PROPN,appos,pobj': [2,
#   [('S0019103512002801-1496', '∼5.7 s', 'rate channel time resolution'),
#    ('S0019103512002801-1849', 'keV', 'level of Erk')]],
#  'PUNCT,punct,pobj,prep,nsubjpass': [2,
#   [('S0019103511004994-1565',
#     '56–100 keV)',
#     'measured differential intensity'),
#    ('S0167610512002292-3305', '126 km/h)', 'wind speed')]],
#  'NUM,nummod,pobj,prep,conj,prep,pobj': [2,
#   [('S0019103511004994-1511',
#     'between about 20 keV and several tens of MeV.',
#     'energy range'),
#    ('S1550413113004920-1509',
#     'before 9 months',
#     'diagnosed with permanent diabetes')]],
#  'PROPN,compound,pobj,prep,pobj': [2,
#   [('S0019103511004994-1399', '3.95 Saturn radii RS', 'distance'),
#    ('S1388248113001951-339', '12 mA g− 1', 'rate')]],
#  'NUM,nummod,npadvmod,ROOT,prep,pobj': [2,
#   [('S0019103511004994-1382', '14 times,', 'flew close by the moon'),
#    ('S0019103511004994-1399', '14 times', 'flown by Enceladus')]],
#  'NOUN,npadvmod,ROOT,prep,pobj': [2,
#   [('S0019103511004994-1382', '14 times,', 'flew close by the moon'),
#    ('S0019103511004994-1399', '14 times', 'flown by Enceladus')]],
#  'NOUN,npadvmod,advcl,prep,pobj': [2,
#   [('S0016236113008041-3269', '2000 ppm', 'concentrations'),
#    ('S0012821X12004384-1232', '>0.5 km)', 'deep')]],
#  'NUM,nummod,pobj,prep,pobj,prep,ROOT,nsubjpass': [2,
#   [('S0016236113008041-3186', '<0.1 ppm', 'flue gas concentrations'),
#    ('S0378383911001669-1634', 'approximately 0.1 mg/l', 'Fluorescent dye')]],
#  'NOUN,pobj,prep,pobj,prep,ROOT,nsubjpass': [2,
#   [('S0016236113008041-3186', '<0.1 ppm', 'flue gas concentrations'),
#    ('S0378383911001669-1634', 'approximately 0.1 mg/l', 'Fluorescent dye')]],
#  'PUNCT,punct,ccomp,nsubj': [2,
#   [('S0012821X13007309-1989', '∼0.8,', '187Os/188Os'),
#    ('S0960148113005727-904', '5–13% per year,', 'load factors')]],
#  'NUM,nummod,appos,dobj': [2,
#   [('S0012821X13007309-1989', 'to 600 ppt;', 'Os abundances'),
#    ('S0012821X13007309-1989', '100 ppt)', 'Os abundances')]],
#  'PROPN,pobj,prep,pobj,prep,dobj': [2,
#   [('S0012821X13007309-1989', '30 ppt', 'Os abundance'),
#    ('S0032063312003054-2483',
#     'between ∼01:25:00 UT and 01:25:40 UT,',
#     'acceleration')]],
#  'NOUN,pobj,prep,pobj,prep,conj,dobj': [2,
#   [('S0012821X13007309-1989', '10 ppq', 'Os abundance'),
#    ('S0019103512003995-2737', 'less than ∼10 times', 'energy inputs')]],
#  'NOUN,npadvmod,prep,pobj': [2,
#   [('S0012821X13007309-1509', '4.3 m', 'below the CTB'),
#    ('S2211124713006475-841', 'weeks', 'after transplantation')]],
#  'PROPN,compound,pobj,prep,ROOT': [2,
#   [('S0012821X13002185-994', '∼31.5 Ma,', 'peaked'),
#    ('S0032386113005454-2008', 'about −100 °C', 'toughened')]],
#  'PROPN,pobj,prep,ROOT': [2,
#   [('S0012821X13002185-994', '∼31.5 Ma,', 'peaked'),
#    ('S0032386113005454-2008', 'about −100 °C', 'toughened')]],
#  'PUNCT,punct,nsubj': [2,
#   [('S0012821X13002185-1231', 'r2=0.92,', 'correlation'),
#    ('S0012821X12004384-1640', '54 oN)', 'paleolatitude')]],
#  'NUM,nummod,compound,dobj,prep,pobj': [2,
#   [('S0012821X13002185-1231', '40%', 'differences in the abundance'),
#    ('S0925443913003037-1397', 'approximately 54%', 'level')]],
#  'NOUN,compound,dobj,prep,pobj': [2,
#   [('S0012821X13002185-1231', '40%', 'differences in the abundance'),
#    ('S0925443913003037-1397', 'approximately 54%', 'level')]],
#  'PROPN,pobj,prep,pobj,prep,pobj': [2,
#   [('S0012821X13002185-1061', '∼400 ka,', 'emplacement of an ice volume'),
#    ('S0960148113002048-3775', 'above 0.003 Hz,', 'frequencies')]],
#  'NUM,nummod,nsubj': [2,
#   [('S0012821X12004384-1640', '54 oN)', 'paleolatitude'),
#    ('S0012821X13002185-994', '1.5‰', 'decline')]],
#  'ADJ,amod,pobj': [2,
#   [('S0012821X12004384-1415', 'on average 5%', 'peridinoid cysts'),
#    ('S0016236113008041-3186', 'greater than 0.1 ppm.', 'concentrations')]],
#  'NUM,pobj,prep,ROOT': [2,
#   [('S0012821X12004384-1265', '1/100th', 'Each slide was produced'),
#    ('S1750583613004192-714', '1999,', 'first appeared')]],
#  'NUM,nummod,compound,pobj,prep,ccomp': [2,
#   [('S0012821X12004384-1178', '5–8 °C', 'rise'),
#    ('S0167577X13006393-787', 'before 1200 °C', 'occurs')]],
#  'NOUN,compound,pobj,prep,ccomp': [2,
#   [('S0012821X12004384-1178', '5–8 °C', 'rise'),
#    ('S0167577X13006393-787', 'before 1200 °C', 'occurs')]],
#  'NUM,nummod,dobj,acl': [2,
#   [('S0012821X12004384-1178', '170 ka', 'lasting'),
#    ('S0019103513005058-4302', 'over 3 byr', 'accumulated')]],
#  'NOUN,dobj,acl': [2,
#   [('S0012821X12004384-1178', '170 ka', 'lasting'),
#    ('S0019103513005058-4302', 'over 3 byr', 'accumulated')]],
#  'NUM,nummod,nsubj,ROOT,punct': [2,
#   [('S0006322312001096-1230', '5.4%', 'used antidepressant medication,'),
#    ('S0378112713005288-1948',
#     '20%',
#     'variation between the different site types.')]],
#  'NOUN,nsubj,ROOT,punct': [2,
#   [('S0006322312001096-1230', '5.4%', 'used antidepressant medication,'),
#    ('S0378112713005288-1948',
#     '20%',
#     'variation between the different site types.')]],
#  'NUM,nummod,nsubj,ROOT,dobj': [2,
#   [('S0006322312001096-1230', '47.4%', 'also had CES-D depressive symptoms'),
#    ('S0006322312001096-1230', '59.9%', 'also had GHQ symptoms')]],
#  'NOUN,nsubj,ROOT,dobj': [2,
#   [('S0006322312001096-1230', '47.4%', 'also had CES-D depressive symptoms'),
#    ('S0006322312001096-1230', '59.9%', 'also had GHQ symptoms')]],
#  'NUM,nummod,nmod,pobj': [2,
#   [('S0006322312001096-1221', '10%', 'absolute increase'),
#    ('S0012821X12004384-952', '<30%', 'wood/plant tissue')]],
#  'NOUN,nmod,pobj': [2,
#   [('S0006322312001096-1221', '10%', 'absolute increase'),
#    ('S0012821X12004384-952', '<30%', 'wood/plant tissue')]],
#  'NOUN,pobj,prep,ccomp,dobj': [2,
#   [('S0006322312001096-1205', 'past 14 days', 'taken any medication'),
#    ('S0168945213001805-4454', '42–48%', 'increased net photosynthesis')]],
#  'NUM,nummod,appos,nummod': [2,
#   [('S0006322312001096-1202', '1–2 days,', '1'),
#    ('S0006322312001096-1202', '3–4 days,', '2')]],
#  'NOUN,appos,nummod': [2,
#   [('S0006322312001096-1202', '1–2 days,', '1'),
#    ('S0006322312001096-1202', '3–4 days,', '2')]],
#  'NUM,pobj,prep,nsubj': [2,
#   [('S0006322312001096-1197', '5 or more', 'score'),
#    ('S016412121300188X-4392', '1.00', 'precision')]],
#  'NUM,pobj,prep,advcl': [2,
#   [('S0006322312001096-1197', '1 or 0', 'scored'),
#    ('S1389128612002496-6138', 'from 0.25 Mbps to 0.01 Mbps', 'decreases')]],
#  'NUM,conj,attr,ROOT,nsubj': [2,
#   [('S0006322312001096-1194', '2.14', 'odds ratios'),
#    ('S0006322312001096-1221', '1.24,', 'odds ratios')]],
#  'NUM,compound,pobj,prep,ROOT': [2,
#   [('S0006322312001096-1190', '−4°C', 'refrigerated'),
#    ('S0019103512003995-2737', '109–1010 kg s−1', 'loss rates')]],
#  'ADP,prep,conj': [2,
#   [('S0006322312001096-1190', 'within 72 hours.', 'assayed'),
#    ('S0019103513005058-4098', 'from 211 K to 284 K', 'increased')]],
#  'NUM,nummod,npadvmod,prep,ROOT': [2,
#   [('S0006322312001096-1190', 'at least 5 hours', 'taken'),
#    ('S0019103512001388-1070', 'two days before', 'taken')]],
#  'NOUN,npadvmod,prep,ROOT': [2,
#   [('S0006322312001096-1190', 'at least 5 hours', 'taken'),
#    ('S0019103512001388-1070', 'two days before', 'taken')]],
#  'NUM,nummod,dep,dep': [2,
#   [('S0006322312001096-1177', '8815', 'n'),
#    ('S0006322312001096-1177', '6761', 'n')]],
#  'NUM,pobj,prep,ccomp,punct': [1,
#   [('S2213671113001306-910', '25,000×;', 'magnification;')]],
#  'PUNCT,punct,ROOT,ccomp,punct': [1,
#   [('S2213671113001306-910', '25,000×;', 'magnification;')]],
#  'NUM,nummod,nmod,dobj': [1, [('S2213671113001306-910', '2 μm', 'distance')]],
#  'NOUN,nmod,nmod,dobj': [1, [('S2213671113001306-910', '2 μm', 'distance')]],
#  'NUM,nummod,pobj,prep,acl,conj,ccomp,ccomp,punct': [1,
#   [('S2213671113001306-910', '10,500×', 'magnification;')]],
#  'NOUN,compound,pobj,prep': [1,
#   [('S2213671113001306-1520', '60 μm', 'distance between')]],
#  'NUM,nummod,pobj,prep,ROOT,nsubjpass': [1,
#   [('S2213671113001306-1520', '4.2 mm.', 'corneal curvature settings')]],
#  'NOUN,pobj,prep,ROOT,nsubjpass': [1,
#   [('S2213671113001306-1520', '4.2 mm.', 'corneal curvature settings')]],
#  'NUM,nummod,dobj,prep,pobj': [1,
#   [('S2213671113001306-1520', '20 × 20 degrees', 'visual field')]],
#  'NOUN,pobj,prep,acl,pobj,prep,pobj,prep,ROOT,dobj,prep,pobj': [1,
#   [('S2213671113001306-1520', '20 × 20 degrees', 'visual field')]],
#  'NOUN,dobj,prep,pobj': [1,
#   [('S2213671113001306-1520', '20 × 20 degrees', 'visual field')]],
#  'ADP,prep,ROOT,nsubj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     'over more than 20 passages.',
#     'percentage of GFP-positive (GFP+) cells')]],
#  'ADJ,amod,nummod,pobj,prep,ROOT,nsubj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     'over more than 20 passages.',
#     'percentage of GFP-positive (GFP+) cells')]],
#  'SCONJ,quantmod,nummod,pobj,prep,ROOT,nsubj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     'over more than 20 passages.',
#     'percentage of GFP-positive (GFP+) cells')]],
#  'NUM,nummod,pobj,prep,ROOT,nsubj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     'over more than 20 passages.',
#     'percentage of GFP-positive (GFP+) cells')]],
#  'NOUN,pobj,prep,ROOT,nsubj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     'over more than 20 passages.',
#     'percentage of GFP-positive (GFP+) cells')]],
#  'PUNCT,punct,ROOT,nsubj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     'over more than 20 passages.',
#     'percentage of GFP-positive (GFP+) cells')]],
#  'NUM,nummod,appos,appos,pobj,prep,ROOT,xcomp,dobj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     '72%)',
#     'found to carry the GFP-Neo cassette in the SOX2 locus')]],
#  'NOUN,appos,appos,pobj,prep,ROOT,xcomp,dobj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     '72%)',
#     'found to carry the GFP-Neo cassette in the SOX2 locus')]],
#  'PUNCT,punct,pobj,prep,ROOT,xcomp,dobj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     '72%)',
#     'found to carry the GFP-Neo cassette in the SOX2 locus')]],
#  'NUM,nummod,nsubj,ccomp,dobj': [1,
#   [('S2213671113000921-994', '100%', 'expressed SOX2 protein')]],
#  'NOUN,nsubj,ccomp,dobj': [1,
#   [('S2213671113000921-994', '100%', 'expressed SOX2 protein')]],
#  'ADJ,amod,nummod,attr,ROOT,nsubj': [1,
#   [('S2213671113000921-1279', 'greater than 70%.', 'gene targeting rates')]],
#  'SCONJ,quantmod,nummod,attr,ROOT,nsubj': [1,
#   [('S2213671113000921-1279', 'greater than 70%.', 'gene targeting rates')]],
#  'NUM,nummod,pobj,prep,pobj,conj': [1,
#   [('S2213671113000908-810', '80%', 'coexpresses CXCR4 and SOX17')]],
#  'NOUN,pobj,prep,pobj,conj': [1,
#   [('S2213671113000908-810', '80%', 'coexpresses CXCR4 and SOX17')]],
#  'NUM,nummod,npadvmod,prep,acl,prep,pobj': [1,
#   [('S2213671113000738-738',
#     '3.5–4 months',
#     'accumulated in the allografts')]],
#  'NOUN,npadvmod,prep,acl,prep,pobj': [1,
#   [('S2213671113000738-738',
#     '3.5–4 months',
#     'accumulated in the allografts')]],
#  'NUM,nummod,attr,conj,ccomp,nsubj': [1,
#   [('S2213671113000738-738', '1/10', 'expression of MHC-I')]],
#  'ADP,prep,acl,dobj': [1,
#   [('S2213671113000738-647', 'within 12 weeks', 'generate teratomas')]],
#  'NUM,nummod,pobj,prep,acl,dobj': [1,
#   [('S2213671113000738-647', 'within 12 weeks', 'generate teratomas')]],
#  'NOUN,pobj,prep,acl,dobj': [1,
#   [('S2213671113000738-647', 'within 12 weeks', 'generate teratomas')]],
#  'NUM,nummod,appos,appos,ROOT,punct': [1,
#   [('S2213671113000738-435', '50 μm', 'Scale bars:')]],
#  'NOUN,appos,appos,ROOT,punct': [1,
#   [('S2213671113000738-435', '50 μm', 'Scale bars:')]],
#  'NUM,nummod,appos,ROOT,punct': [1,
#   [('S2213671113000738-435', '200 μm', 'Scale bars:')]],
#  'NOUN,appos,ROOT,punct': [1,
#   [('S2213671113000738-435', '200 μm', 'Scale bars:')]],
#  'NUM,nummod,conj,appos,appos,ROOT,punct': [1,
#   [('S2213671113000738-435', '100 μm', 'Scale bars:')]],
#  'NOUN,conj,appos,appos,ROOT,punct': [1,
#   [('S2213671113000738-435', '100 μm', 'Scale bars:')]],
#  'PROPN,det,appos,dobj': [1,
#   [('S2213158213000582-1340', '30–130 ms', 'examined activity')]],
#  'NUM,nummod,conj,punct': [1,
#   [('S2213158213000582-1327', '21', 'sub-cortical regions,')]],
#  'NUM,nummod,npadvmod,prep,ROOT,xcomp': [1,
#   [('S2211124713006475-1195', 'Two days', 'dispersed')]],
#  'NOUN,npadvmod,prep,ROOT,xcomp': [1,
#   [('S2211124713006475-1195', 'Two days', 'dispersed')]],
#  'SYM,punct,prep,nummod,pobj,prep,ROOT': [1,
#   [('S2211124712002884-1110', 'after 2-4 weeks', 'used')]],
#  'NUM,prep,nummod,pobj,prep,ROOT': [1,
#   [('S2211124712002884-1110', 'after 2-4 weeks', 'used')]],
#  'PUNCT,punct,npadvmod,amod': [1,
#   [('S2211124712002884-1110', 'Ten-day', 'old')]],
#  'NUM,nummod,nmod,appos,pobj,appos,conj': [1,
#   [('S2211124712002884-1060', '100 U/ml', 'penicillin/streptomycin')]],
#  'NOUN,nmod,appos,pobj,appos,conj': [1,
#   [('S2211124712002884-1060', '100 U/ml', 'penicillin/streptomycin')]],
#  'SYM,punct,appos,pobj,appos,conj': [1,
#   [('S2211124712002884-1060', '100 U/ml', 'penicillin/streptomycin')]],
#  'NOUN,appos,pobj,appos,conj': [1,
#   [('S2211124712002884-1060', '100 U/ml', 'penicillin/streptomycin')]],
#  'NUM,nummod,nmod,pobj,punct': [1,
#   [('S2211124712002884-1060', '10%', 'fetal bovine serum,')]],
#  'NOUN,nmod,pobj,punct': [1,
#   [('S2211124712002884-1060', '10%', 'fetal bovine serum,')]],
#  'ADV,advmod,nummod,nsubj,conj,acomp,prep,pobj': [1,
#   [('S1873506114000075-1242',
#     'approximately 88 ± 1.1%',
#     'AFP-positive on D13')]],
#  'NUM,advmod,nummod,nsubj,conj,acomp,prep,pobj': [1,
#   [('S1873506114000075-1242',
#     'approximately 88 ± 1.1%',
#     'AFP-positive on D13')]],
#  'ADV,advmod,nummod,nsubj,ccomp,prep,pobj': [1,
#   [('S1873506114000075-1242',
#     'approximately 78 ± 0.6%',
#     'Sox17-positive on D5')]],
#  'NUM,nummod,nsubj,ccomp,prep,pobj': [1,
#   [('S1873506114000075-1242',
#     'approximately 78 ± 0.6%',
#     'Sox17-positive on D5')]],
#  'NUM,cc,nummod,nsubj,ccomp,prep,pobj': [1,
#   [('S1873506114000075-1242',
#     'approximately 78 ± 0.6%',
#     'Sox17-positive on D5')]],
#  'NOUN,nsubj,ccomp,prep,pobj': [1,
#   [('S1873506114000075-1242',
#     'approximately 78 ± 0.6%',
#     'Sox17-positive on D5')]],
#  'ADV,advmod,conj,pobj,prep,acomp,conj,conj,acomp,prep,pobj': [1,
#   [('S1873506114000075-1242',
#     'approximately 29 ± 0.9%',
#     'ALB-positive on D20')]],
#  'NUM,conj,pobj,prep,acomp,conj,conj,acomp,prep,pobj': [1,
#   [('S1873506114000075-1242',
#     'approximately 29 ± 0.9%',
#     'ALB-positive on D20')]],
#  'NUM,cc,acomp,conj,conj,acomp,prep,pobj': [1,
#   [('S1873506114000075-1242',
#     'approximately 29 ± 0.9%',
#     'ALB-positive on D20')]],
#  'NUM,nummod,pobj,prep,acl,prep,pobj': [1,
#   [('S1873506113001116-710',
#     '13 passages',
#     'expanded in static suspension culture')]],
#  'NOUN,pobj,prep,acl,prep,pobj': [1,
#   [('S1873506113001116-710',
#     '13 passages',
#     'expanded in static suspension culture')]],
#  'NUM,nummod,pobj,agent,pcomp,prep,ROOT,punct': [1,
#   [('S1873506113001116-1369',
#     '4 days',
#     'gelatin-coated tissue culture plates in differentiation medium,')]],
#  'NOUN,pobj,agent,pcomp,prep,ROOT,punct': [1,
#   [('S1873506113001116-1369',
#     '4 days',
#     'gelatin-coated tissue culture plates in differentiation medium,')]],
#  'ADV,advmod,nummod,npadvmod,ccomp': [1,
#   [('S1750583613004192-714', 'approximately 220 m', 'migrated')]],
#  'NUM,nummod,npadvmod,ccomp': [1,
#   [('S1750583613004192-714', 'approximately 220 m', 'migrated')]],
#  'NOUN,npadvmod,ccomp': [1,
#   [('S1750583613004192-714', 'approximately 220 m', 'migrated')]],
#  'NUM,nummod,pobj,prep,pobj,amod': [1,
#   [('S1750583613004192-714', '5 Mt', 'injected')]],
#  'PROPN,pobj,prep,pobj,amod': [1,
#   [('S1750583613004192-714', '5 Mt', 'injected')]],
#  'PUNCT,punct,ROOT,advcl,ccomp': [1,
#   [('S1750583613004192-714', '3 years.', 'migrated')]],
#  'NUM,nummod,compound,nsubj,advcl,dobj': [1,
#   [('S1750583613004192-1267', '80%', 'upper limit')]],
#  'NOUN,compound,nsubj,advcl,dobj': [1,
#   [('S1750583613004192-1267', '80%', 'upper limit')]],
#  'NUM,nummod,compound,nsubj': [1,
#   [('S1750583613004192-1267', '80%', 'gas saturation')]],
#  'NOUN,compound,nsubj': [1,
#   [('S1750583613004192-1267', '80%', 'gas saturation')]],
#  'NUM,nummod,pobj,prep,acomp,ROOT,nsubj': [1,
#   [('S1750583613004192-1267', '40%,', 'lower limit')]],
#  'NOUN,pobj,prep,acomp,ROOT,nsubj': [1,
#   [('S1750583613004192-1267', '40%,', 'lower limit')]],
#  'ADJ,amod,nummod,pobj,prep,ROOT,nsubj,prep,pobj,conj': [1,
#   [('S175058361300203X-1556',
#     'less than 1%',
#     'Seismic amplitude differences between the 38 °C and 34 °C scenarios')]],
#  'SCONJ,quantmod,nummod,pobj,prep,ROOT,nsubj,prep,pobj,conj': [1,
#   [('S175058361300203X-1556',
#     'less than 1%',
#     'Seismic amplitude differences between the 38 °C and 34 °C scenarios')]],
#  'NUM,nummod,pobj,prep,ROOT,nsubj,prep,pobj,conj': [1,
#   [('S175058361300203X-1556',
#     'less than 1%',
#     'Seismic amplitude differences between the 38 °C and 34 °C scenarios')]],
#  'NOUN,pobj,prep,ROOT,nsubj,prep,pobj,conj': [1,
#   [('S175058361300203X-1556',
#     'less than 1%',
#     'Seismic amplitude differences between the 38 °C and 34 °C scenarios')]],
#  'PROPN,nummod,compound,appos': [1,
#   [('S175058361300203X-1542', '±5%', 'error')]],
#  'NOUN,compound,appos': [1, [('S175058361300203X-1542', '±5%', 'error')]],
#  'NUM,amod,compound,pobj,prep,pobj,prep,pobj': [1,
#   [('S175058361300203X-1542', 'range of 34–38 °C', 'temperatures')]],
#  'NOUN,compound,pobj,prep,pobj,prep,pobj': [1,
#   [('S175058361300203X-1542', 'range of 34–38 °C', 'temperatures')]],
#  'ADJ,amod,nummod,attr,ROOT,nsubj,prep,pobj,prep,pobj': [1,
#   [('S175058361300203X-1542', 'less than 5 m/s.', 'Vp')]],
#  'SCONJ,quantmod,nummod,attr,ROOT,nsubj,prep,pobj,prep,pobj': [1,
#   [('S175058361300203X-1542', 'less than 5 m/s.', 'Vp')]],
#  'NUM,nummod,attr,ROOT,nsubj,prep,pobj,prep,pobj': [1,
#   [('S175058361300203X-1542', 'less than 5 m/s.', 'Vp')]],
#  'NOUN,nmod,attr,ROOT,nsubj,prep,pobj,prep,pobj': [1,
#   [('S175058361300203X-1542', 'less than 5 m/s.', 'Vp')]],
#  'SYM,punct,attr,ROOT,nsubj,prep,pobj,prep,pobj': [1,
#   [('S175058361300203X-1542', 'less than 5 m/s.', 'Vp')]],
#  'NOUN,attr,ROOT,nsubj,prep,pobj,prep,pobj': [1,
#   [('S175058361300203X-1542', 'less than 5 m/s.', 'Vp')]],
#  'PUNCT,punct,ROOT,nsubj,prep,pobj,prep,pobj': [1,
#   [('S175058361300203X-1542', 'less than 5 m/s.', 'Vp')]],
#  'NUM,nummod,appos,pobj,compound': [1,
#   [('S175058361300203X-1542', '34 and 38 °C', 'temperature')]],
#  'CCONJ,cc,nummod,appos,pobj,compound': [1,
#   [('S175058361300203X-1542', '34 and 38 °C', 'temperature')]],
#  'NUM,conj,nummod,appos,pobj,compound': [1,
#   [('S175058361300203X-1542', '34 and 38 °C', 'temperature')]],
#  'NOUN,conj,nummod,appos,pobj,compound': [1,
#   [('S175058361300203X-1542', '34 and 38 °C', 'temperature')]],
#  'NOUN,appos,pobj,compound': [1,
#   [('S175058361300203X-1542', '34 and 38 °C', 'temperature')]],
#  'ADP,prep,conj,prep,pobj': [1,
# ...
#  'NUM,nummod,dobj,pcomp,dobj': [1,
#   [('S0016236113008041-3269', '135 ppm', 'concentrations')]],
#  'NOUN,dobj,pcomp,dobj': [1,
#   [('S0016236113008041-3269', '135 ppm', 'concentrations')]],
#  'NUM,conj,pobj,prep,pobj': [1,
#   [('S0016236113008041-3269', '1000', 'concentrations')]],
#  'NUM,nummod,pobj,prep,ROOT,nsubj,punct': [1,
#   [('S0016236113008041-3207',
#     '90–95%',
#     'Substitution via cation exchange for Ca2+')]],
#  'NOUN,pobj,prep,ROOT,nsubj,punct': [1,
#   [('S0016236113008041-3207',
#     '90–95%',
#     'Substitution via cation exchange for Ca2+')]],
#  'SCONJ,prep,amod,pobj': [1,
#   [('S0016236113008041-3186', 'greater than 0.1 ppm.', 'concentrations')]],
#  'NUM,nummod,pobj,prep,amod,pobj': [1,
#   [('S0016236113008041-3186', 'greater than 0.1 ppm.', 'concentrations')]],
#  'NOUN,pobj,prep,amod,pobj': [1,
#   [('S0016236113008041-3186', 'greater than 0.1 ppm.', 'concentrations')]],
#  'PUNCT,punct,ROOT,dobj,prep,pobj,relcl,prep,pobj': [1,
#   [('S0016236113008041-3186', 'greater than 0.1 ppm.', 'concentrations')]],
#  'X,nmod,nummod,pobj,prep,pobj,prep,ROOT,nsubjpass': [1,
#   [('S0016236113008041-3186', '<0.1 ppm', 'flue gas concentrations')]],
#  'NUM,nummod,pobj,prep,prep,pcomp,nsubj': [1,
#   [('S0016236113008041-3186', '0.74 ppm', 'concentration')]],
#  'NOUN,pobj,prep,prep,pcomp,nsubj': [1,
#   [('S0016236113008041-3186', '0.74 ppm', 'concentration')]],
#  'NUM,pobj,prep,prep,pcomp,nsubj': [1,
#   [('S0016236113008041-3186', '0.42', 'concentration')]],
#  'NUM,pobj,prep,pcomp,nsubj': [1,
#   [('S0016236113008041-3186', '0.06', 'concentration')]],
#  'X,dep,ROOT,nsubj': [1,
#   [('S0016236113008041-3171', '<0.1 ppm', 'flue gas concentrations')]],
#  'X,nmod,pobj,prep,advcl,nsubj': [1,
#   [('S0016236113008041-3161', '<2 ppm,', 'concentrations')]],
#  'PUNCT,punct,ROOT,advcl,nsubj': [1,
#   [('S0016236113008041-3161', '<2 ppm,', 'concentrations')]],
#  'NUM,nummod,compound,pobj,amod': [1,
#   [('S0016236113008041-3112', '10%', 'HNO3')]],
#  'NOUN,compound,pobj,amod': [1, [('S0016236113008041-3112', '10%', 'HNO3')]],
#  'PROPN,amod,appos,pobj,prep,nsubj,nmod,punct': [1,
#   [('S0016236113008041-3031', '∼15 ppm)', 'Cu,')]],
#  'NOUN,appos,pobj,prep,nsubj,nmod,punct': [1,
#   [('S0016236113008041-3031', '∼15 ppm)', 'Cu,')]],
#  'PUNCT,punct,pobj,prep,nsubj,nmod,punct': [1,
#   [('S0016236113008041-3031', '∼15 ppm)', 'Cu,')]],
#  'ADP,prep,pobj,prep,ccomp,advcl,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼50 ppm to ∼150 ppm.', 'Ti')]],
#  'PROPN,compound,pobj,prep,pobj,prep,ccomp,advcl,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼50 ppm to ∼150 ppm.', 'Ti')]],
#  'NOUN,pobj,prep,pobj,prep,ccomp,advcl,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼50 ppm to ∼150 ppm.', 'Ti')]],
#  'ADP,aux,advcl,ccomp,advcl,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼50 ppm to ∼150 ppm.', 'Ti')]],
#  'NOUN,advcl,ccomp,advcl,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼50 ppm to ∼150 ppm.', 'Ti')]],
#  'NOUN,dobj,advcl,ccomp,advcl,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼50 ppm to ∼150 ppm.', 'Ti')]],
#  'ADP,prep,pobj,prep,attr,conj,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼250 to ∼550 ppm', 'Na')]],
#  'PROPN,pobj,prep,attr,conj,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼250 to ∼550 ppm', 'Na')]],
#  'PROPN,amod,pobj,prep,pobj,prep,attr,conj,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼250 to ∼550 ppm', 'Na')]],
#  'NOUN,pobj,prep,pobj,prep,attr,conj,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼250 to ∼550 ppm', 'Na')]],
#  'ADP,conj,prep,attr,conj,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼200 to 400 ppm', 'Na')]],
#  'PROPN,pobj,conj,prep,attr,conj,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼200 to 400 ppm', 'Na')]],
#  'ADP,prep,conj,prep,attr,conj,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼200 to 400 ppm', 'Na')]],
#  'NUM,nummod,pobj,prep,conj,prep,attr,conj,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼200 to 400 ppm', 'Na')]],
#  'NOUN,pobj,prep,conj,prep,attr,conj,ROOT,nsubj': [1,
#   [('S0016236113008041-3031', 'from ∼200 to 400 ppm', 'Na')]],
#  'ADP,prep,conj,ROOT,nsubj,nmod,punct': [1,
#   [('S0016236113008041-3031', 'from ∼20 ppm to ∼180 ppm.', 'Cu,')]],
#  'NOUN,det,pobj,prep,conj,ROOT,nsubj,nmod,punct': [1,
#   [('S0016236113008041-3031', 'from ∼20 ppm to ∼180 ppm.', 'Cu,')]],
#  'NOUN,pobj,prep,conj,ROOT,nsubj,nmod,punct': [1,
#   [('S0016236113008041-3031', 'from ∼20 ppm to ∼180 ppm.', 'Cu,')]],
#  'ADP,aux,compound,npadvmod,conj,ROOT,nsubj,nmod,punct': [1,
#   [('S0016236113008041-3031', 'from ∼20 ppm to ∼180 ppm.', 'Cu,')]],
#  'PROPN,compound,npadvmod,conj,ROOT,nsubj,nmod,punct': [1,
#   [('S0016236113008041-3031', 'from ∼20 ppm to ∼180 ppm.', 'Cu,')]],
#  'NOUN,npadvmod,conj,ROOT,nsubj,nmod,punct': [1,
#   [('S0016236113008041-3031', 'from ∼20 ppm to ∼180 ppm.', 'Cu,')]],
#  'PUNCT,punct,ROOT,nsubj,nmod,punct': [1,
#   [('S0016236113008041-3031', 'from ∼20 ppm to ∼180 ppm.', 'Cu,')]],
#  'NUM,nummod,nsubjpass,ccomp,punct': [1,
#   [('S0016236113008041-3012',
#     '82%',
#     'elemental Hg was emitted in the exhaust gas,')]],
#  'NOUN,nsubjpass,ccomp,punct': [1,
#   [('S0016236113008041-3012',
#     '82%',
#     'elemental Hg was emitted in the exhaust gas,')]],
#  'PROPN,acomp,ccomp,nsubj': [1,
#   [('S0012821X13007309-1989', '∼0.8,', '187Os/188Os')]],
#  'ADP,quantmod,nummod,appos,dobj': [1,
#   [('S0012821X13007309-1989', 'to 600 ppt;', 'Os abundances')]],
#  'NOUN,appos,dobj': [1,
#   [('S0012821X13007309-1989', 'to 600 ppt;', 'Os abundances')]],
#  'NUM,nummod,nmod,dobj,prep,pobj': [1,
#   [('S0012821X13007309-1989', '75%', 'from the LIP')]],
#  'NOUN,nmod,dobj,prep,pobj': [1,
#   [('S0012821X13007309-1989', '75%', 'from the LIP')]],
#  'PROPN,appos,dobj': [1,
#   [('S0012821X13007309-1989', '100 ppt)', 'Os abundances')]],
#  'NUM,nummod,pobj,prep,pobj,prep,conj,dobj': [1,
#   [('S0012821X13007309-1989', '10 ppq', 'Os abundance')]],
#  'NUM,quantmod,nummod,pobj,prep,ROOT,ccomp,dobj': [1,
#   [('S0012821X13007309-1989', '1 to 30 ppt', 'Os abundances')]],
#  'ADP,quantmod,nummod,pobj,prep,ROOT,ccomp,dobj': [1,
#   [('S0012821X13007309-1989', '1 to 30 ppt', 'Os abundances')]],
#  'NUM,nummod,pobj,prep,ROOT,ccomp,dobj': [1,
#   [('S0012821X13007309-1989', '1 to 30 ppt', 'Os abundances')]],
#  'NOUN,pobj,prep,ROOT,ccomp,dobj': [1,
#   [('S0012821X13007309-1989', '1 to 30 ppt', 'Os abundances')]],
#  'NOUN,prep,dobj,advmod,prep,pobj,punct': [1,
#   [('S0012821X13007309-1691',
#     '∼−25.9 to −26.5‰.',
#     'narrow variation in background values prior to OAE 2,')]],
#  'ADP,prep,prep,dobj,advmod,prep,pobj,punct': [1,
#   [('S0012821X13007309-1691',
#     '∼−25.9 to −26.5‰.',
#     'narrow variation in background values prior to OAE 2,')]],
#  'NOUN,pobj,prep,prep,dobj,advmod,prep,pobj,punct': [1,
#   [('S0012821X13007309-1691',
#     '∼−25.9 to −26.5‰.',
#     'narrow variation in background values prior to OAE 2,')]],
#  'PROPN,conj,attr,punct': [1,
#   [('S0012821X13007309-1691', '−27.2 to −23.1‰,', 'shift,')]],
#  'ADP,aux,relcl,conj,attr,punct': [1,
#   [('S0012821X13007309-1691', '−27.2 to −23.1‰,', 'shift,')]],
#  'NUM,relcl,conj,attr,punct': [1,
#   [('S0012821X13007309-1691', '−27.2 to −23.1‰,', 'shift,')]],
#  'PUNCT,punct,attr,punct': [1,
#   [('S0012821X13007309-1691', '−27.2 to −23.1‰,', 'shift,')]],
#  'ADP,prep,advcl,ROOT,attr,punct': [1,
#   [('S0012821X13007309-1691', 'within <0.5 m', 'shift,')]],
#  'X,quantmod,pobj,prep,advcl,ROOT,attr,punct': [1,
#   [('S0012821X13007309-1691', 'within <0.5 m', 'shift,')]],
#  'NUM,compound,pobj,prep,advcl,ROOT,attr,punct': [1,
#   [('S0012821X13007309-1691', 'within <0.5 m', 'shift,')]],
#  'NOUN,pobj,prep,advcl,ROOT,attr,punct': [1,
#   [('S0012821X13007309-1691', 'within <0.5 m', 'shift,')]],
#  'ADP,advmod,npadvmod,prep,pobj,compound': [1,
#   [('S0012821X13007309-1691', 'Up to 20 m', 'beneath the Bonarelli')]],
#  'PART,quantmod,npadvmod,prep,pobj,compound': [1,
#   [('S0012821X13007309-1691', 'Up to 20 m', 'beneath the Bonarelli')]],
#  'NUM,compound,npadvmod,prep,pobj,compound': [1,
#   [('S0012821X13007309-1691', 'Up to 20 m', 'beneath the Bonarelli')]],
#  'NOUN,npadvmod,prep,pobj,compound': [1,
#   [('S0012821X13007309-1691', 'Up to 20 m', 'beneath the Bonarelli')]],
#  'NUM,compound,attr,punct': [1, [('S0012821X13007309-1691', '4‰', 'shift,')]],
#  'NUM,compound,nummod,attr,amod': [1,
#   [('S0012821X13007309-1691', '1 m', 'thick')]],
#  'NOUN,nummod,attr,amod': [1, [('S0012821X13007309-1691', '1 m', 'thick')]],
#  'NOUN,dep,nmod,nsubj,amod': [1,
#   [('S0012821X13007309-1605', '∼20 m', 'thick')]],
#  'PROPN,nmod,nsubj,amod': [1, [('S0012821X13007309-1605', '∼20 m', 'thick')]],
#  'NOUN,appos,pobj,prep,nsubj,advcl,prep,pobj': [1,
#   [('S0012821X13007309-1605', 'n=4)', 'came from Vergons')]],
#  'PUNCT,punct,pobj,prep,nsubj,advcl,prep,pobj': [1,
#   [('S0012821X13007309-1605', 'n=4)', 'came from Vergons')]],
#  'PROPN,pobj,prep,advmod,pobj': [1,
#   [('S0012821X13007309-1509', '∼−27‰', 'gradual fall')]],
#  'PROPN,pobj,prep,pobj,prep,pobj,nmod': [1,
#   [('S0012821X13007309-1509', '∼−27‰', 'VPDB δ13Corg')]],
#  'NUM,nummod,npadvmod,prep,pobj': [1,
#   [('S0012821X13007309-1509', '4.3 m', 'below the CTB')]],
#  'NUM,nummod,pobj,det,pobj': [1,
#   [('S0012821X13007309-1509', '2–3‰', 'positive shift')]],
#  'NUM,nummod,pobj,amod': [1, [('S0012821X13007309-1482', '17.7 m', 'thick')]],
#  'PUNCT,punct,pobj,prep,ROOT': [1,
#   [('S0012821X13002185-994', '∼31.5 Ma,', 'peaked')]],
#  'ADP,quantmod,nummod,pobj,prep,relcl,appos': [1,
#   [('S0012821X13002185-994', 'up to 40%', 'siliceous walled autotrophs')]],
#  'PART,quantmod,nummod,pobj,prep,relcl,appos': [1,
#   [('S0012821X13002185-994', 'up to 40%', 'siliceous walled autotrophs')]],
#  'NUM,nummod,pobj,prep,relcl,appos': [1,
#   [('S0012821X13002185-994', 'up to 40%', 'siliceous walled autotrophs')]],
#  'NOUN,pobj,prep,relcl,appos': [1,
#   [('S0012821X13002185-994', 'up to 40%', 'siliceous walled autotrophs')]],
#  'NUM,nummod,appos': [1, [('S0012821X13002185-994', '0.6‰', 'rise')]],
#  'PROPN,pobj,prep,pobj,prep,appos': [1,
#   [('S0012821X13002185-1231', '∼−1‰', '30ε')]],
#  'NOUN,dep,punct,nsubj': [1,
#   [('S0012821X13002185-1231', 'r2=0.92,', 'correlation')]],
#  'NUM,nummod,conj,pobj,prep,acl,npadvmod': [1,
#   [('S0012821X13002185-1217', '95%', 'm/Δm∼3500')]],
#  'NOUN,conj,pobj,prep,acl,npadvmod': [1,
#   [('S0012821X13002185-1217', '95%', 'm/Δm∼3500')]],
#  'NUM,nummod,pobj,prep,acl,npadvmod': [1,
#   [('S0012821X13002185-1217', '5%', 'm/Δm∼3500')]],
#  'NOUN,pobj,prep,acl,npadvmod': [1,
#   [('S0012821X13002185-1217', '5%', 'm/Δm∼3500')]],
#  'PROPN,dep,dep,dep,punct,nsubj': [1,
#   [('S0012821X13002185-1217', '1.26±0.2‰,', 'external diatomite standard')]],
#  'PUNCT,punct,dep,dep,dep,punct,nsubj': [1,
#   [('S0012821X13002185-1217', '1.26±0.2‰,', 'external diatomite standard')]],
#  'PROPN,compound,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061', '∼400 ka,', 'emplacement of an ice volume')]],
#  'PUNCT,punct,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061', '∼400 ka,', 'emplacement of an ice volume')]],
#  'NUM,compound,dobj,relcl': [1,
#   [('S0012821X13002185-1061', '∼2 Ma', 'began')]],
#  'PROPN,dobj,relcl': [1, [('S0012821X13002185-1061', '∼2 Ma', 'began')]],
#  'ADP,prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'NUM,pobj,prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'NOUN,quantmod,conj,pobj,prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'CCONJ,cc,pobj,prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'NUM,conj,pobj,prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'SYM,det,pobj,prep,pobj,prep,appos,conj,appos,ROOT,punct': [1,
#   [('S0012821X12004384-952', '>30%', 'wood/plant tissue.')]],
#  'NUM,nummod,nmod,pobj,prep,pobj,prep,appos,conj,appos,ROOT,punct': [1,
#   [('S0012821X12004384-952', '>30%', 'wood/plant tissue.')]],
#  'NOUN,nmod,pobj,prep,pobj,prep,appos,conj,appos,ROOT,punct': [1,
#   [('S0012821X12004384-952', '>30%', 'wood/plant tissue.')]],
#  'PROPN,nmod,pobj': [1,
#   [('S0012821X12004384-952', '<30%', 'wood/plant tissue')]],
#  'NUM,pobj,prep,nsubjpass': [1,
#   [('S0012821X12004384-1640', '5‰', 'negative carbon isotope excursion')]],
#  'ADP,prep,nsubj': [1,
#   [('S0012821X12004384-1640', '54 oN)', 'paleolatitude')]],
#  'ADP,prep,acomp,acl,prep': [1,
#   [('S0012821X12004384-1599', 'from 103 yrs', 'before')]],
#  'NUM,nummod,pobj,prep,acomp,acl,prep': [1,
#   [('S0012821X12004384-1599', 'from 103 yrs', 'before')]],
#  'NOUN,pobj,prep,acomp,acl,prep': [1,
#   [('S0012821X12004384-1599', 'from 103 yrs', 'before')]],
#  'ADP,prep,pobj,prep': [1,
#   [('S0012821X12004384-1599', 'above 2618 m,', 'before')]],
#  'NUM,nummod,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1599', 'above 2618 m,', 'before')]],
#  'NOUN,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1599', 'above 2618 m,', 'before')]],
#  'PUNCT,punct,pobj,prep': [1,
#   [('S0012821X12004384-1599', 'above 2618 m,', 'before')]],
#  'NUM,nummod,compound,attr,parataxis,nsubj': [1,
#   [('S0012821X12004384-1594', '40°N', 'southern boundary')]],
#  'NOUN,compound,attr,parataxis,nsubj': [1,
#   [('S0012821X12004384-1594', '40°N', 'southern boundary')]],
#  'PROPN,attr,parataxis,nsubj': [1,
#   [('S0012821X12004384-1594', '40°N', 'southern boundary')]],
#  'PROPN,dep,punct,ROOT,dobj': [1,
#   [('S0012821X12004384-1284', '±<0.1.', 'precision')]],
#  'X,quantmod,nummod,pobj': [1,
#   [('S0012821X12004384-1284', '>250 μm', 'size fractions')]],
#  'NOUN,pobj,prep': [1,
#   [('S0012821X12004384-1284', '24 h', 'were refluxed for')]],
#  'X,nmod,ROOT,punct': [1,
#   [('S0012821X12004384-1265', '>250 μm', 'fractions,')]],
#  'NUM,nummod,ROOT,punct': [1,
#   [('S0012821X12004384-1265', '>250 μm', 'fractions,')]],
#  'NOUN,compound,ROOT,punct': [1,
#   [('S0012821X12004384-1265', '>250 μm', 'fractions,')]],
#  'NUM,nummod,attr,relcl,nsubj': [1,
#   [('S0012821X12004384-1265', '5 g', 'initial weight')]],
#  'NOUN,attr,relcl,nsubj': [1,
#   [('S0012821X12004384-1265', '5 g', 'initial weight')]],
#  'ADP,prep,pobj,appos': [1,
#   [('S0012821X12004384-1249', 'from 2605 m to 2634 m', 'core depth')]],
#  'NUM,compound,pobj,appos': [1,
#   [('S0012821X12004384-1249', 'from 2605 m to 2634 m', 'core depth')]],
#  'NOUN,pobj,prep,prep,pobj,appos': [1,
#   [('S0012821X12004384-1249', 'from 2605 m to 2634 m', 'core depth')]],
#  'PROPN,pobj,appos': [1,
#   [('S0012821X12004384-1249', 'from 2605 m to 2634 m', 'core depth')]],
#  'NUM,nummod,pobj,prep,ROOT,acomp': [1,
#   [('S0012821X12004384-1249', '2609–2613 m', 'becomes finely laminated')]],
#  'NOUN,pobj,prep,ROOT,acomp': [1,
#   [('S0012821X12004384-1249', '2609–2613 m', 'becomes finely laminated')]],
#  'ADP,prep,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1232', 'in the order of 100 m', 'fall in')]],
#  'DET,det,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1232', 'in the order of 100 m', 'fall in')]],
#  'NOUN,pobj,prep,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1232', 'in the order of 100 m', 'fall in')]],
#  'NUM,compound,pobj,prep,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1232', 'in the order of 100 m', 'fall in')]],
#  'PUNCT,punct,attr,advcl,prep,pobj': [1,
#   [('S0012821X12004384-1232', '>0.5 km)', 'deep')]],
#  'NUM,nummod,npadvmod,advcl,prep,pobj': [1,
#   [('S0012821X12004384-1232', '>0.5 km)', 'deep')]],
#  'X,nmod,appos,pobj,amod': [1, [('S0012821X12004384-1232', '<10 cm', 'thin')]],
#  'NUM,nummod,appos,pobj,amod': [1,
#   [('S0012821X12004384-1232', '<10 cm', 'thin')]],
#  'NOUN,appos,pobj,amod': [1, [('S0012821X12004384-1232', '<10 cm', 'thin')]],
#  'CCONJ,cc,nummod,pobj': [1,
#   [('S0012821X12004384-1221', 'between 200 and >1000 m', 'depth')]],
#  'PUNCT,conj,nummod,pobj': [1,
#   [('S0012821X12004384-1221', 'between 200 and >1000 m', 'depth')]],
#  'NUM,compound,pobj': [1,
#   [('S0012821X12004384-1221', 'between 200 and >1000 m', 'depth')]],
#  'SYM,pobj,prep,dobj': [1,
#   [('S0012821X12004384-1221', '>0.5 km', 'paleodepths')]],
#  ...}

# %%
freq
# Out:
# {'pobj,prep,pobj': [38,
#   [('S0012821X13002185-1231', '∼–1‰', 'apparent 30ε'),
#    ('S0016236113008041-3153', '<2 ppm', 'concentrations'),
#    ('S0016236113008041-3269', '0,', 'concentrations'),
#    ('S0016236113008041-3290', '0.63', 'concentrations'),
#    ('S0016236113008041-913', '1000 ppm', 'SO2 concentrations'),
#    ('S0019103511004994-1511', '77.45°', 'points at an angle'),
#    ('S0019103512002801-1342', '8.74Rs', 'distance'),
#    ('S0019103512003533-3348', '2°', 'latitude'),
#    ('S0019103512003533-5072', 'around 1300 m s−1', 'peak velocities'),
#    ('S0019103512003995-1807', '300–800 nm.', 'wavelengths'),
#    ('S0019103513005058-3094', '∼2 m', 'depth'),
#    ('S0019103513005058-4210', '2 m', 'depth'),
#    ('S0006322312001096-1177', '73%,', 'response'),
#    ('S0006322312001096-1253', '65 years.', 'before the age'),
#    ('S0006322312001096-1278', '65,', 'age'),
#    ('S0019103511004994-1399', '3.95 Saturn radii RS', 'distance'),
#    ('S0019103513005058-4158', '0.51–0.85 m.', '1/e mixing depth'),
#    ('S0032386113009889-2123', 'about 70 MPa,', 'applied uniaxial stress'),
#    ('S0032386113009889-2123', '210 MPa', 'applied hydrostatic stress'),
#    ('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters'),
#    ('S0921818113002245-1571', '8 m', 'depth'),
#    ('S0921818113002245-1571', 'approximately 11.8 m', 'depth'),
#    ('S0921818113002245-1571', 'between 11.8 m and 11.5 m', 'depth'),
#    ('S0925443913003037-654', '2.5 years', 'age'),
#    ('S0927024813002420-1032', '80 vol%', 'C60'),
#    ('S0927024813002420-975', '300±15 °C.', 'temperature'),
#    ('S0927024813002961-1334', '650–750 W/m2', 'irradiance range'),
#    ('S0960148113002048-3775', '0.01–0.03 Hz,', 'frequencies'),
#    ('S1359645413009816-2243', '1.5 nm', 'nominal resolution'),
#    ('S1359645413009816-2243', '5 K/min,', 'heating rate'),
#    ('S1359645413009816-2243',
#     'about 30 K/min',
#     'rapid cooling to ambient temperature at a rate'),
#    ('S1388248113001951-339', '12 mA g− 1', 'rate'),
#    ('S175058361300203X-1542', '±70 m/s', 'Vp'),
#    ('S1873506113001116-1369', 'After 8 days', 'spinner flask'),
#    ('S1873506113001116-1369',
#     '4 days',
#     'gelatin-coated tissue culture plates in differentiation medium,'),
#    ('S2211124712002884-1110',
#     '5–6 days',
#     'grown as embryoid bodies (EBs) in suspension'),
#    ('S2213671113000738-430', '3 months', 'after transplantation'),
#    ('S2213671113001306-1520', '30 degrees', 'visual field')]],
#  'nummod,pobj,prep,pobj': [29,
#   [('S0016236113008041-913', '1000 ppm', 'SO2 concentrations'),
#    ('S0019103511004994-1511', '77.45°', 'points at an angle'),
#    ('S0019103512003533-3348', '2°', 'latitude'),
#    ('S0019103512003533-5072', 'around 1300 m s−1', 'peak velocities'),
#    ('S0019103512003995-1807', '300–800 nm.', 'wavelengths'),
#    ('S0006322312001096-1177', '73%,', 'response'),
#    ('S0006322312001096-1253', '65 years.', 'before the age'),
#    ('S0019103511004994-1399', '3.95 Saturn radii RS', 'distance'),
#    ('S0032386113009889-2123', 'about 70 MPa,', 'applied uniaxial stress'),
#    ('S0032386113009889-2123', '210 MPa', 'applied hydrostatic stress'),
#    ('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters'),
#    ('S0921818113002245-1571', '8 m', 'depth'),
#    ('S0921818113002245-1571', 'approximately 11.8 m', 'depth'),
#    ('S0921818113002245-1571', 'between 11.8 m and 11.5 m', 'depth'),
#    ('S0921818113002245-1752', '5.16 m.', 'depth'),
#    ('S0925443913003037-654', '2.5 years', 'age'),
#    ('S0927024813002420-1032', '80 vol%', 'C60'),
#    ('S0927024813002420-975', '300±15 °C.', 'temperature'),
#    ('S0927024813002961-1334', '650–750 W/m2', 'irradiance range'),
#    ('S0960148113002048-3775', '0.01–0.03 Hz,', 'frequencies'),
#    ('S1359645413009816-2243', '1.5 nm', 'nominal resolution'),
#    ('S1359645413009816-2243', '5 K/min,', 'heating rate'),
#    ('S1359645413009816-2243',
#     'about 30 K/min',
#     'rapid cooling to ambient temperature at a rate'),
#    ('S1388248113001951-339', '12 mA g− 1', 'rate'),
#    ('S1873506113001116-1369', 'After 8 days', 'spinner flask'),
#    ('S2211124712002884-1110',
#     '5–6 days',
#     'grown as embryoid bodies (EBs) in suspension'),
#    ('S2213158213000582-1327', '5 mm per side', 'voxels'),
#    ('S2213671113000738-430', '3 months', 'after transplantation'),
#    ('S2213671113001306-1520', '30 degrees', 'visual field')]],
#  'pobj,prep,dobj': [15,
#   [('S0019103512002801-1927', '0.1–0.2 s−1', 'linear growth rate'),
#    ('S0019103512002801-1927', '5–10 s,', 'growth time'),
#    ('S0019103512003995-3548', 'about 8250 K', 'temperature'),
#    ('S0019103512004009-4007',
#     '93%',
#     'constant photoelectron heating efficiency'),
#    ('S0019103512004009-5019', '20 eV', 'energy'),
#    ('S0012821X12004384-1221', '>0.5 km', 'paleodepths'),
#    ('S0012821X12004384-1221', '>0.5 km', 'paleodepths'),
#    ('S0019103512003533-3306', 'above ∼500 K.', 'temperatures'),
#    ('S0019103513005058-3917', '0.02 cm s−1', 'deposition velocity'),
#    ('S0167819113001051-1247',
#     'from 50% to around 80%.',
#     'improve the usability'),
#    ('S0168945213001805-4775', '−8 °C', 'stable tolerance'),
#    ('S0168945213001805-4775', '−8 °C', 'stable tolerance'),
#    ('S0927024813001955-679', '3.4+0.1 cm2/Vs,', 'electron mobility'),
#    ('S0927775713009606-1216', '0.1°', 'step size'),
#    ('S0927775713009606-1361', '0.097 nm', 'ionic radius')]],
#  'compound,pobj': [15,
#   [('S0012821X12004384-1415', 'on average 5%', 'peridinoid cysts'),
#    ('S0012821X13002185-1217', '0.2 M', 'NaOH'),
#    ('S0006322312001096-1194', '10%', 'increment'),
#    ('S0006322312001096-1221', '10%', 'increase'),
#    ('S0012821X12004384-1221', 'between 200 and >1000 m', 'depth'),
#    ('S0012821X12004384-1284', '>250 μm', 'size fractions'),
#    ('S0019103512003995-1767', '1083 nm', 'line'),
#    ('S0019103512004009-5033', '30 nbar', 'level'),
#    ('S0025322712001600-2406', 'better than 5%', 'weight'),
#    ('S0025322712001600-2406', '95%', 'confidence level'),
#    ('S0167577X14001256-389', '4 nm', 'width'),
#    ('S0167880913001229-1225', '0–10 cm', 'depth'),
#    ('S0167880913001229-1304', '0–10 cm', 'depth'),
#    ('S0167880913001229-1304', '0–40 cm', 'depth'),
#    ('S0169433213008933-689', '0.06–0.07 mBar', 'pressure')]],
#  'pobj,prep,ROOT': [14,
#   [('S0021979713004438-1907', '10 min', 'interrupted'),
#    ('S0006322312001096-1190', '−4°C', 'refrigerated'),
#    ('S0012821X12004384-1265', '1/100th', 'Each slide was produced'),
#    ('S0012821X13002185-994', '∼31.5 Ma,', 'peaked'),
#    ('S0032386113005454-2008', 'about −100 °C', 'toughened'),
#    ('S0038071712001010-1044', '84 days', 'lasted'),
#    ('S0169433213008933-689', '240 s', 'processed'),
#    ('S0927024813001955-679', 'after 200 days', 'maintained'),
#    ('S0927775713009606-1074', '5–40 nm range', 'characterised'),
#    ('S1388248113001951-339', '4.0 V', 'charged'),
#    ('S1750583613004192-714', '1999,', 'first appeared'),
#    ('S1873506114000075-1132', '48 h', 'changed'),
#    ('S2211124712002884-1110', 'after 3–4 weeks,', 'dissociated'),
#    ('S2211124712002884-1110', 'after 2-4 weeks', 'used')]],
#  'attr,ROOT,nsubj': [13,
#   [('S0016236113008041-3171', '<0.1 ppm', 'flue gas concentrations'),
#    ('S0021979713004438-1969', '3.91 nm', 'Rq value'),
#    ('S0006322312001096-1194', '1.34', 'odds ratios'),
#    ('S0006322312001096-1197', '80%', 'sensitivity'),
#    ('S0006322312001096-1221', '1.40', 'odds ratios'),
#    ('S0021979713004438-1401', '69 ± 3°,', 'contact angle'),
#    ('S0032063312003054-1990', '12 min,', 'time interval'),
#    ('S0032063312003054-2264', 'around 100 km,', 'gyroradius'),
#    ('S0167610513001001-739', '7.83 m s−1', 'speed'),
#    ('S030881461301604X-1002', '100 mg/L', 'concentrations'),
#    ('S0378383912000130-3601', '1:10.', 'slope'),
#    ('S0927024813003036-2011', '≤1.5×1012 cm−3', 'bulk iron concentrations'),
#    ('S2213671113000921-1279', 'greater than 70%.', 'gene targeting rates')]],
#  'compound,pobj,prep,pobj': [12,
#   [('S0016236113008041-3153', '<2 ppm', 'concentrations'),
#    ('S0019103512002801-1849', '1%', 'level of Erk'),
#    ('S0019103512003533-5072', 'around 1300 m s−1', 'peak velocities'),
#    ('S0019103513005058-3094', '∼2 m', 'depth'),
#    ('S0019103513005058-4210', '2 m', 'depth'),
#    ('S0019103511004994-1399', '3.95 Saturn radii RS', 'distance'),
#    ('S0019103511004994-1399', '3.95 Saturn radii RS', 'distance'),
#    ('S0019103513005058-4158', '0.51–0.85 m.', '1/e mixing depth'),
#    ('S0031405612000728-1621', '7 month', 'course'),
#    ('S0927024813002420-975', '300±15 °C.', 'temperature'),
#    ('S095741741101342X-726', '85/15%', 'good/bad observations'),
#    ('S1388248113001951-339', '12 mA g− 1', 'rate')]],
#  'punct,ROOT,nsubj': [12,
#   [('S0016236113008041-3031', 'from ∼50 ppm to ∼150 ppm.', 'Ti'),
#    ('S0006322312001096-1221', '1.24,', 'odds ratios'),
#    ('S0019103512004009-3976',
#     'increases from 2.6 km s−1 to 25 km s−1.',
#     'velocity'),
#    ('S0019103512004009-5033', 'near 1.4Rp.', 'transition'),
#    ('S0019103512004009-5033', '2–3Rp.', 'transition'),
#    ('S0019103512004009-5033', '3.4Rp,', 'transition'),
#    ('S0021979713004438-1401', '69 ± 3°,', 'contact angle'),
#    ('S0032063312003054-1990', '12 min,', 'time interval'),
#    ('S016412121300188X-4545', 'range from 11.4% to 2.4%.', 'sizes'),
#    ('S0378383912000130-3601', '1:10.', 'slope'),
#    ('S1750583613004192-1267', '40%,', 'lower limit'),
#    ('S2213671113000921-1279', 'greater than 70%.', 'gene targeting rates')]],
#  'nummod,pobj': [10,
#   [('S0012821X13002185-1217', '0.2 M', 'NaOH'),
#    ('S0019103512003995-1910', 'one', 'solar rotation'),
#    ('S0012821X12004384-1284', '>250 μm', 'size fractions'),
#    ('S0019103513005058-3917', 'zero', 'deposition velocity'),
#    ('S0032063312003054-2501', '689', 'events'),
#    ('S0167880913001229-1225', '0–10 cm', 'depth'),
#    ('S0167880913001229-1304', '0–10 cm', 'depth'),
#    ('S0378383911001669-1634', '1:10', 'slope'),
#    ('S2213158213000582-1327', '96', 'cortical gray-matter regions'),
#    ('S2213671113001306-1520', '30-degrees', 'visual-field setting')]],
#  'nummod,pobj,prep,ROOT': [9,
#   [('S0021979713004438-1907', '10 min', 'interrupted'),
#    ('S0038071712001010-1044', '84 days', 'lasted'),
#    ('S0169433213008933-689', '240 s', 'processed'),
#    ('S0927024813001955-679', 'after 200 days', 'maintained'),
#    ('S1388248113001951-339', '4.0 V', 'charged'),
#    ('S1873506113001116-710', 'after 48 h', 'Light microscope image'),
#    ('S1873506114000075-1132', '48 h', 'changed'),
#    ('S2211124712002884-1110', 'after 3–4 weeks,', 'dissociated'),
#    ('S2211124712002884-1110', 'after 2-4 weeks', 'used')]],
#  'pobj,prep,conj': [9,
#   [('S0019103512003533-3299', '50%,', 'heating efficiencies'),
#    ('S0019103512003533-3348', '0.4 scale heights.', 'vertical resolution'),
#    ('S0006322312001096-1190', 'within 72 hours.', 'assayed'),
#    ('S0019103512001388-3081', 'December 16', 'declined'),
#    ('S0019103513005058-4098', 'from 211 K to 284 K', 'increased'),
#    ('S0019103513005058-4098', 'from 211 K to 284 K', 'increased'),
#    ('S0167577X14001256-517', '55 K.', 'specimen temperature'),
#    ('S0378383912000130-3601', '62 mm', 'level'),
#    ('S2213671113000738-738', '6 months', 'withdrawn')]],
#  'nummod,pobj,prep,dobj': [9,
#   [('S0019103512002801-1927', '0.1–0.2 s−1', 'linear growth rate'),
#    ('S0019103512003995-3548', 'about 8250 K', 'temperature'),
#    ('S0019103512004009-4007',
#     '93%',
#     'constant photoelectron heating efficiency'),
#    ('S0019103512004009-5019', '20 eV', 'energy'),
#    ('S0012821X12004384-1221', '>0.5 km', 'paleodepths'),
#    ('S0019103513005058-4349', 'six orders of magnitude', 'deposition rate'),
#    ('S0167819113001051-1247',
#     'from 50% to around 80%.',
#     'improve the usability'),
#    ('S0927775713009606-1216', '0.1°', 'step size'),
#    ('S0927775713009606-1361', '0.097 nm', 'ionic radius')]],
#  'nummod,attr,ROOT,nsubj': [9,
#   [('S0016236113008041-3171', '<0.1 ppm', 'flue gas concentrations'),
#    ('S0021979713004438-1969', '3.91 nm', 'Rq value'),
#    ('S0006322312001096-1197', '80%', 'sensitivity'),
#    ('S0021979713004438-1401', '69 ± 3°,', 'contact angle'),
#    ('S0032063312003054-1990', '12 min,', 'time interval'),
#    ('S0032063312003054-2264', 'around 100 km,', 'gyroradius'),
#    ('S0167610513001001-739', '7.83 m s−1', 'speed'),
#    ('S030881461301604X-1002', '100 mg/L', 'concentrations'),
#    ('S2213671113000921-1279', 'greater than 70%.', 'gene targeting rates')]],
#  'nummod,compound,pobj': [9,
#   [('S0012821X12004384-1415', 'on average 5%', 'peridinoid cysts'),
#    ('S0006322312001096-1194', '10%', 'increment'),
#    ('S0006322312001096-1221', '10%', 'increase'),
#    ('S0019103512003995-1767', '1083 nm', 'line'),
#    ('S0019103512004009-5033', '30 nbar', 'level'),
#    ('S0025322712001600-2406', 'better than 5%', 'weight'),
#    ('S0025322712001600-2406', '95%', 'confidence level'),
#    ('S0167577X14001256-389', '4 nm', 'width'),
#    ('S0167880913001229-1304', '0–40 cm', 'depth')]],
#  'punct,pobj,prep,pobj': [8,
#   [('S0016236113008041-3269', '0,', 'concentrations'),
#    ('S0016236113008041-913', '2000 ppm,', 'SO2 concentrations'),
#    ('S0032386113009889-2123', 'about 70 MPa,', 'applied uniaxial stress'),
#    ('S0927024813002961-1334', '650–750 W/m2', 'irradiance range'),
#    ('S1359645413009816-2243', '5 K/min,', 'heating rate'),
#    ('S1359645413009816-2243', '5 K/min,', 'heating rate'),
#    ('S1359645413009816-2243',
#     'about 30 K/min',
#     'rapid cooling to ambient temperature at a rate'),
#    ('S175058361300203X-1542', '±70 m/s', 'Vp')]],
#  'appos,pobj': [8,
#   [('S0012821X13007309-1989', '25%)', 'from the LIP'),
#    ('S0019103512002801-1496', '∼5.7 s', 'rate channel time resolution'),
#    ('S0019103512002801-1849', 'keV', 'level of Erk'),
#    ('S0019103513005058-3094', '0.1%', 'time-average volcanic flux'),
#    ('S0022000014000026-17824', 'μs)', 'skew'),
#    ('S0006322312001096-1197', '73%)', 'sensitivity'),
#    ('S0927024813002420-975',
#     '20–25 monomer units,',
#     'effective conjugation length'),
#    ('S0927775713009606-1361', '0.19–0.21 nm)', 'distances')]],
#  'compound,pobj,prep,ROOT': [8,
#   [('S0006322312001096-1190', '−4°C', 'refrigerated'),
#    ('S0006322312001096-1190', '−4°C', 'refrigerated'),
#    ('S0012821X13002185-994', '∼31.5 Ma,', 'peaked'),
#    ('S0019103512003995-2737', '109–1010 kg s−1', 'loss rates'),
#    ('S0032386113005454-2008', 'about −100 °C', 'toughened'),
#    ('S0032386113005454-2008', 'about −100 °C', 'toughened'),
#    ('S0927775713009606-1074', '5–40 nm range', 'characterised'),
#    ('S1873506113001116-710', 'after 48 h', 'Light microscope image')]],
#  'nummod,pobj,prep,conj': [7,
#   [('S0019103512003533-3299', '50%,', 'heating efficiencies'),
#    ('S0006322312001096-1190', 'within 72 hours.', 'assayed'),
#    ('S0019103512001388-3081', 'December 16', 'declined'),
#    ('S0019103513005058-4098', 'from 211 K to 284 K', 'increased'),
#    ('S0167577X14001256-517', '55 K.', 'specimen temperature'),
#    ('S0378383912000130-3601', '62 mm', 'level'),
#    ('S2213671113000738-738', '6 months', 'withdrawn')]],
#  'pobj,prep,appos': [7,
#   [('S0012821X13007309-1989', '0.13', '187Os/188Os'),
#    ('S0019103513005058-1737', '1 g cm−3,', 'soil density'),
#    ('S0006322312001096-1221', '1.14', 'odds ratio'),
#    ('S0019103513005058-4098', '∼35%', 'increase'),
#    ('S0167577X14001256-517', '0.5–0.6 nJ,', 'laser energy'),
#    ('S0167577X14001256-517', '250 kHz,', 'laser-pulse repetition rate'),
#    ('S0167577X14001256-517', '4–7 kV,', 'DC bias voltage')]],
#  'nmod,pobj,prep,pobj': [6,
#   [('S0016236113008041-3153', '<2 ppm', 'concentrations'),
#    ('S0016236113008041-913', '0 ppm,', 'SO2 concentrations'),
#    ('S0927024813002961-1334', '650–750 W/m2', 'irradiance range'),
#    ('S1359645413009816-2243', '5 K/min,', 'heating rate'),
#    ('S1359645413009816-2243',
#     'about 30 K/min',
#     'rapid cooling to ambient temperature at a rate'),
#    ('S175058361300203X-1542', '±70 m/s', 'Vp')]],
#  'pobj,prep,pobj,prep,pobj': [6,
#   [('S0012821X13002185-1061', '∼400 ka,', 'emplacement of an ice volume'),
#    ('S0032063312003054-2264', '400 km.', 'horizontal size'),
#    ('S0927024813001955-576', '1 h.', 'post-annealed'),
#    ('S0960148113002048-3775', 'above 0.003 Hz,', 'frequencies'),
#    ('S175058361300203X-1542', 'range of 34–38 °C', 'temperatures'),
#    ('S2213158213000582-1327', '5 mm per side', 'voxels')]],
#  'pobj,prep,nsubjpass': [6,
#   [('S0012821X12004384-1640', '5‰', 'negative carbon isotope excursion'),
#    ('S0032386113005454-2308', '3.19 ± 0.10 GPa', 'tensile modulus'),
#    ('S0167610512002292-3305', '35 m/s', 'wind speed'),
#    ('S0378383912000130-3601', '62 mm', 'level'),
#    ('S0921818113002245-859', 'approximately 19 m', 'deepest point'),
#    ('S1873506113001116-978', '10 passages', 'cultured')]],
#  'nummod,pobj,prep,nsubjpass': [5,
#   [('S0032386113005454-2308', '3.19 ± 0.10 GPa', 'tensile modulus'),
#    ('S0167610512002292-3305', '35 m/s', 'wind speed'),
#    ('S0378383912000130-3601', '62 mm', 'level'),
#    ('S0921818113002245-859', 'approximately 19 m', 'deepest point'),
#    ('S1873506113001116-978', '10 passages', 'cultured')]],
#  'prep,ROOT': [5,
#   [('S0019103512001388-1070', 'two days before', 'taken'),
#    ('S0927024813001955-679', 'after 200 days', 'maintained'),
#    ('S1873506113001116-710', 'after 48 h', 'Light microscope image'),
#    ('S2211124712002884-1110', 'after 3–4 weeks,', 'dissociated'),
#    ('S2211124712002884-1110', 'after 2-4 weeks', 'used')]],
#  'conj,pobj,prep,pobj': [5,
#   [('S0016236113008041-3269', '1000', 'concentrations'),
#    ('S0016236113008041-3290', '0.51 ppm', 'concentrations'),
#    ('S0016236113008041-913', '2000 ppm,', 'SO2 concentrations'),
#    ('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters'),
#    ('S0921818113002245-1571', 'between 11.8 m and 11.5 m', 'depth')]],
#  'pobj,prep,pobj,prep,dobj': [5,
#   [('S0012821X13007309-1989', '30 ppt', 'Os abundance'),
#    ('S0019103512004009-2821',
#     '7000 K',
#     'mean (pressure averaged) temperature'),
#    ('S0019103513005058-4349', 'six orders of magnitude', 'deposition rate'),
#    ('S0032063312003054-2483',
#     'between ∼01:25:00 UT and 01:25:40 UT,',
#     'acceleration'),
#    ('S175058361300203X-1483', '20–25%', 'effective porosities')]],
#  'punct,ROOT,prep,pobj': [5,
#   [('S0006322312001096-1177', '73%,', 'response'),
#    ('S0006322312001096-1275', 'range 66% to 88%)', 'response'),
#    ('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters'),
#    ('S0927024813002420-975', '300±15 °C.', 'temperature'),
#    ('S0927775713009606-1074', '1 (w/w),', 'ratio')]],
#  'prep,pobj,prep,pobj': [4,
#   [('S0960148113002048-3775', 'above 0.003 Hz,', 'frequencies'),
#    ('S175058361300203X-1542', 'range of 34–38 °C', 'temperatures'),
#    ('S1873506113001116-1369', 'After 8 days', 'spinner flask'),
#    ('S2213158213000582-1327', '5 mm per side', 'voxels')]],
#  'nummod,pobj,prep,appos': [4,
#   [('S0019103513005058-1737', '1 g cm−3,', 'soil density'),
#    ('S0167577X14001256-517', '0.5–0.6 nJ,', 'laser energy'),
#    ('S0167577X14001256-517', '250 kHz,', 'laser-pulse repetition rate'),
#    ('S0167577X14001256-517', '4–7 kV,', 'DC bias voltage')]],
#  'pobj,prep,ROOT,nsubj': [4,
#   [('S0019103512004009-3976',
#     'increases from 2.6 km s−1 to 25 km s−1.',
#     'velocity'),
#    ('S0019103512004009-4350', '∼1000 K', 'maximum temperature'),
#    ('S0019103512004009-5033', 'near 1.4Rp.', 'transition'),
#    ('S0019103512004009-5033', '2–3Rp.', 'transition')]],
#  'nummod,compound,pobj,prep,pobj': [4,
#   [('S0019103512002801-1849', '1%', 'level of Erk'),
#    ('S0031405612000728-1621', '7 month', 'course'),
#    ('S095741741101342X-726', '85/15%', 'good/bad observations'),
#    ('S1388248113001951-339', '12 mA g− 1', 'rate')]],
#  'nummod,dobj,ROOT': [4,
#   [('S0019103512001388-1070', '6 November 2011 UT,', 'taken'),
#    ('S016412121300188X-4069', '9438 lines of code', 'contains'),
#    ('S0378383912000130-3601', 'two beach materials', 'involved'),
#    ('S2213671113000908-979', '12 hr', 'visually inspected')]],
#  'dobj,ROOT': [4,
#   [('S0019103512001388-1070', '6 November 2011 UT,', 'taken'),
#    ('S016412121300188X-4069', '9438 lines of code', 'contains'),
#    ('S0378383912000130-3601', 'two beach materials', 'involved'),
#    ('S2213671113000908-979', '12 hr', 'visually inspected')]],
#  'punct,pobj': [4,
#   [('S0012821X13007309-1989', '25%)', 'from the LIP'),
#    ('S0022000014000026-17824', 'μs)', 'skew'),
#    ('S0006322312001096-1197', '73%)', 'sensitivity'),
#    ('S0927775713009606-1361', '0.19–0.21 nm)', 'distances')]],
#  'nummod,appos,pobj': [4,
#   [('S0012821X13007309-1989', '25%)', 'from the LIP'),
#    ('S0019103513005058-3094', '0.1%', 'time-average volcanic flux'),
#    ('S0006322312001096-1197', '73%)', 'sensitivity'),
#    ('S0927775713009606-1361', '0.19–0.21 nm)', 'distances')]],
#  'prep,pobj': [4,
#   [('S0012821X12004384-1415', 'on average 5%', 'peridinoid cysts'),
#    ('S0012821X12004384-1221', 'between 200 and >1000 m', 'depth'),
#    ('S0031405612000728-1621', 'over a 7-month', 'period'),
#    ('S0921818113002245-1571', 'between 11.8 m and 11.5 m', 'depth')]],
#  'pobj,prep,ccomp': [4,
#   [('S0012821X12004384-1178', '5–8 °C', 'rise'),
#    ('S0167577X13006393-787', 'before 1200 °C', 'occurs'),
#    ('S0167880913001229-1021', '12.4%', 'decreased'),
#    ('S1750583613004192-714', '3 years.', 'migrated')]],
#  'compound,pobj,prep,ROOT,punct': [4,
#   [('S0006322312001096-626', '10%', 'Increase)'),
#    ('S0019103513005058-4158', '∼2 m.', 'depth,'),
#    ('S0032386113005454-2865', '−109 °C,', 'cavitated,'),
#    ('S0169433213008933-689', '30 mA', 'current.')]],
#  'dobj,acl': [4,
#   [('S0006322312001096-1197', '58 to 70', 'aged'),
#    ('S0006322312001096-1202', '≥16', 'scoring'),
#    ('S0012821X12004384-1178', '170 ka', 'lasting'),
#    ('S0019103513005058-4302', 'over 3 byr', 'accumulated')]],
#  'pobj,prep,nsubj': [4,
#   [('S0006322312001096-1197', '5 or more', 'score'),
#    ('S016412121300188X-4392', '1.00', 'precision'),
#    ('S1387700313001822-661', '215–225 nm', 'negative band'),
#    ('S2213671113000738-445', '48 hr', 'Incubation')]],
#  'pobj,prep,advcl': [4,
#   [('S0006322312001096-1197', '1 or 0', 'scored'),
#    ('S0950705113001895-23699', 'from 10% to 100%', 'increases'),
#    ('S1389128612002496-6138', 'from 0.25 Mbps to 0.01 Mbps', 'decreases'),
#    ('S2213671113000908-640', '25 days', 'differentiated')]],
#  'amod,amod': [3,
#   [('S2211124712002884-903', '67-year-', 'old'),
#    ('S2211124712002884-903', '64-year-', 'old'),
#    ('S2211124712002884-903', '64-year', 'old')]],
#  'pobj,punct,dep': [3,
#   [('S0378383911001669-1088', '0.072 m', 'x'),
#    ('S0378383912000130-3745', '1980 mm,', 'x'),
#    ('S0378383912000130-3745', '2780 mm', 'x')]],
#  'punct,pobj,appos': [3,
#   [('S0167577X14001256-517', '250 kHz,', 'laser-pulse repetition rate'),
#    ('S0167577X14001256-517', '4–7 kV,', 'DC bias voltage'),
#    ('S0927775713009606-1074', '> 10 nm;', 'pore diameters')]],
#  'nummod,pobj,prep,ROOT,prep,pobj': [3,
#   [('S0165587612003680-953',
#     'more than 90%',
#     'biofilms have been identified on human middle ear mucosa'),
#    ('S0925443913001385-1638',
#     '30%',
#     "steady state level of MRPL12 in the subject's fibroblasts"),
#    ('S0927024813001955-576', 'one week', 'storage in the dark')]],
#  'pobj,prep,ROOT,prep,pobj': [3,
#   [('S0165587612003680-953',
#     'more than 90%',
#     'biofilms have been identified on human middle ear mucosa'),
#    ('S0925443913001385-1638',
#     '30%',
#     "steady state level of MRPL12 in the subject's fibroblasts"),
#    ('S0927024813001955-576', 'one week', 'storage in the dark')]],
#  'punct,ROOT': [3,
#   [('S016412121300188X-5066', 'from 78% to 95%,', 'improves'),
#    ('S1750583613004192-714', '1999,', 'first appeared'),
#    ('S2211124712002884-1110', 'after 3–4 weeks,', 'dissociated')]],
#  'nummod,pobj,prep,nsubj': [3,
#   [('S016412121300188X-4392', '1/', 'precision'),
#    ('S1387700313001822-661', '215–225 nm', 'negative band'),
#    ('S2213671113000738-445', '48 hr', 'Incubation')]],
#  'nummod,pobj,prep,pobj,prep,pobj': [3,
#   [('S0032063312003054-2264', '400 km.', 'horizontal size'),
#    ('S0927024813001955-576', '1 h.', 'post-annealed'),
#    ('S0960148113002048-3775', 'above 0.003 Hz,', 'frequencies')]],
#  'punct,ROOT,nsubjpass': [3,
#   [('S0021979713004438-1415', '25 ± 0.02 °C,', 'temperature'),
#    ('S0032386113005454-2865', '0.296 μm.', 'mean diameter'),
#    ('S2213671113001306-1520', '4.2 mm.', 'corneal curvature settings')]],
#  'pobj,prep,ROOT,nsubjpass': [3,
#   [('S0021979713004438-1415', '25 ± 0.02 °C,', 'temperature'),
#    ('S0019103513005058-3917', 'zero', 'deposition velocities'),
#    ('S2213671113001306-1520', '4.2 mm.', 'corneal curvature settings')]],
#  'compound,dobj': [3,
#   [('S0019103513005058-3154', '⩽1.6%', 'perchlorate'),
#    ('S0927024813002961-1051', 'up to 25%', 'variation'),
#    ('S2213671113001306-910', '0.2 μm', 'distance')]],
#  'attr,conj,nsubj': [3,
#   [('S0019103512004009-5507', '8250 K,', 'mean temperature'),
#    ('S0019103512004009-3976', '30 km s−1.', 'velocity'),
#    ('S0021979713004438-1401', '−0.72 V,', 'open circuit potential')]],
#  'prep,ROOT,nsubj': [3,
#   [('S0019103512004009-3976',
#     'increases from 2.6 km s−1 to 25 km s−1.',
#     'velocity'),
#    ('S0019103512004009-5033', 'near 1.4Rp.', 'transition'),
#    ('S016412121300188X-4545', 'range from 11.4% to 2.4%.', 'sizes')]],
#  'attr,xcomp,ROOT,nsubjpass': [3,
#   [('S0019103512003995-1910', '∼10–11 days', 'rotation period'),
#    ('S0032386113005454-2601', '63 MPa', 'lowest value'),
#    ('S0032386113005454-2865', '0.296 μm.', 'mean diameter')]],
#  'nummod,compound,pobj,prep,conj': [3,
#   [('S0019103512003533-3348', '0.4 scale heights.', 'vertical resolution'),
#    ('S0006322312001096-1190', '2 hours', 'taken'),
#    ('S0927024813002420-1032', '70 nm', 'thickness')]],
#  'compound,pobj,prep,conj': [3,
#   [('S0019103512003533-3348', '0.4 scale heights.', 'vertical resolution'),
#    ('S0006322312001096-1190', '2 hours', 'taken'),
#    ('S0927024813002420-1032', '70 nm', 'thickness')]],
#  'compound,pobj,prep,dobj': [3,
#   [('S0019103512002801-1927', '5–10 s,', 'growth time'),
#    ('S0019103513005058-3917', '0.02 cm s−1', 'deposition velocity'),
#    ('S0168945213001805-4775', '−8 °C', 'stable tolerance')]],
#  'punct,pobj,prep,nsubjpass': [3,
#   [('S0019103511004994-1565',
#     '56–100 keV)',
#     'measured differential intensity'),
#    ('S0167610512002292-3305', '35 m/s', 'wind speed'),
#    ('S0167610512002292-3305', '126 km/h)', 'wind speed')]],
#  'pobj,prep': [3,
#   [('S0019103511004994-1511',
#     '86 s, nominally.',
#     'rotates about the −y-axis of the spacecraft within'),
#    ('S0019103512004009-4492', '7.2Rp', 'located at'),
#    ('S0012821X12004384-1284', '24 h', 'were refluxed for')]],
#  'nummod,pobj,prep': [3,
#   [('S0019103511004994-1511',
#     '86 s, nominally.',
#     'rotates about the −y-axis of the spacecraft within'),
#    ('S0012821X12004384-1284', '24 h', 'were refluxed for'),
#    ('S2213671113001306-1520', '60 μm', 'distance between')]],
#  'npadvmod,ROOT,prep,pobj': [3,
#   [('S0019103511004994-1382', '14 times,', 'flew close by the moon'),
#    ('S0019103511004994-1399', '14 times', 'flown by Enceladus'),
#    ('S0927775713009606-1074', '1 (w/w),', 'ratio')]],
#  'nummod,conj,pobj,prep,pobj': [3,
#   [('S0016236113008041-3290', '0.51 ppm', 'concentrations'),
#    ('S0016236113008041-913', '2000 ppm,', 'SO2 concentrations'),
#    ('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters')]],
#  'punct,dobj': [3,
#   [('S0012821X13007309-1989', 'to 600 ppt;', 'Os abundances'),
#    ('S0012821X13007309-1989', '100 ppt)', 'Os abundances'),
#    ('S0019103512002801-1927', '5–10 s,', 'growth time')]],
#  'nummod,pobj,prep,pobj,prep,dobj': [3,
#   [('S0012821X13007309-1989', '30 ppt', 'Os abundance'),
#    ('S0019103512004009-2821',
#     '7000 K',
#     'mean (pressure averaged) temperature'),
#    ('S175058361300203X-1483', '20–25%', 'effective porosities')]],
#  'npadvmod,amod': [3,
#   [('S0012821X13007309-1482', '17.7 m', 'thick'),
#    ('S0927024813001955-576', '125 nm', 'thick'),
#    ('S2211124712002884-1110', 'Ten-day', 'old')]],
#  'amod,pobj': [3,
#   [('S0012821X12004384-1415', 'on average 5%', 'peridinoid cysts'),
#    ('S0016236113008041-3186', 'greater than 0.1 ppm.', 'concentrations'),
#    ('S0031405612000728-1621', 'over a 7-month', 'period')]],
#  'quantmod,nummod,dobj,ROOT,prep,pobj': [3,
#   [('S0006322312001096-1275', 'range 66% to 88%)', 'response'),
#    ('S0006322312001096-1275', 'range 66% to 88%)', 'response'),
#    ('S0006322312001096-1275', 'range 66% to 88%)', 'response')]],
#  'nummod,dobj': [3,
#   [('S0006322312001096-1260', '2-year', 'incidence'),
#    ('S2213158213000582-1340', '30–130 ms', 'examined activity'),
#    ('S2213671113001306-910', '0.2 μm', 'distance')]],
#  'nmod,pobj': [3,
#   [('S0006322312001096-1221', '10%', 'absolute increase'),
#    ('S0012821X12004384-952', '<30%', 'wood/plant tissue'),
#    ('S0012821X12004384-952', '<30%', 'wood/plant tissue')]],
#  'conj,attr,ROOT,nsubj': [3,
#   [('S0006322312001096-1194', '2.14', 'odds ratios'),
#    ('S0006322312001096-1221', '1.24,', 'odds ratios'),
#    ('S030881461301604X-1002', '1 mg/L', 'concentrations')]],
#  'punct,ROOT,dobj': [3,
#   [('S0006322312001096-1177', 'approximately every 5 years:', 'taken place'),
#    ('S0012821X12004384-1284', '±<0.1.', 'precision'),
#    ('S0032063312003054-2483',
#     'between ∼01:25:00 UT and 01:25:40 UT,',
#     'acceleration')]],
#  'nummod,appos,appos': [3,
#   [('S0006322312001096-1177', '6967', 'n'),
#    ('S0927775713009606-1074', '> 0.5 cm3 g−1)', 'Vmeso'),
#    ('S0927775713009606-1074', '> 170 m2 g−1', 'SBET')]],
#  'nummod,attr,conj,ROOT': [2,
#   [('S2213158213000582-1340', '95.81%', 'average percent variance explained'),
#    ('S2213158213000582-1340',
#     '96.24%',
#     'average percent variance explained')]],
#  'attr,conj,ROOT': [2,
#   [('S2213158213000582-1340', '95.81%', 'average percent variance explained'),
#    ('S2213158213000582-1340',
#     '96.24%',
#     'average percent variance explained')]],
#  'nummod,conj,attr,conj,ROOT': [2,
#   [('S2213158213000582-1340', '94.38%', 'average percent variance explained'),
#    ('S2213158213000582-1340',
#     '93.17%',
#     'average percent variance explained')]],
#  'conj,attr,conj,ROOT': [2,
#   [('S2213158213000582-1340', '94.38%', 'average percent variance explained'),
#    ('S2213158213000582-1340',
#     '93.17%',
#     'average percent variance explained')]],
#  'punct,amod': [2,
#   [('S2211124712002884-903', '67-year-', 'old'),
#    ('S2211124712002884-903', '64-year-', 'old')]],
#  'advmod,nummod,nsubj,conj,acomp,prep,pobj': [2,
#   [('S1873506114000075-1242',
#     'approximately 88 ± 1.1%',
#     'AFP-positive on D13'),
#    ('S1873506114000075-1242',
#     'approximately 88 ± 1.1%',
#     'AFP-positive on D13')]],
#  'nummod,nsubj,conj,acomp,prep,pobj': [2,
#   [('S1873506114000075-1242',
#     'approximately 88 ± 1.1%',
#     'AFP-positive on D13'),
#    ('S1873506114000075-1242',
#     'approximately 29 ± 0.9%',
#     'ALB-positive on D20')]],
#  'nsubj,conj,acomp,prep,pobj': [2,
#   [('S1873506114000075-1242',
#     'approximately 88 ± 1.1%',
#     'AFP-positive on D13'),
#    ('S1873506114000075-1242',
#     'approximately 29 ± 0.9%',
#     'ALB-positive on D20')]],
#  'conj,nummod,appos,pobj,compound': [2,
#   [('S175058361300203X-1542', '34 and 38 °C', 'temperature'),
#    ('S175058361300203X-1542', '34 and 38 °C', 'temperature')]],
#  'punct,pobj,prep,amod,npadvmod': [2,
#   [('S0960896612001022-1223',
#     'greater than 0.1 g/L;',
#     'protein concentration'),
#    ('S0960896612001022-1223',
#     'greater than 0.1 g/L;',
#     'protein concentration')]],
#  'nummod,pobj,prep,ROOT,nsubj,acl': [2,
#   [('S0960148113004989-3327', '22%', 'averaged power extracted'),
#    ('S0960148113004989-3327',
#     '48.4 MW to 59.0 MW',
#     'averaged power extracted')]],
#  'pobj,prep,ROOT,nsubj,acl': [2,
#   [('S0960148113004989-3327', '22%', 'averaged power extracted'),
#    ('S0960148113004989-3327',
#     '48.4 MW to 59.0 MW',
#     'averaged power extracted')]],
#  'nummod,pobj,prep,advcl': [2,
#   [('S0950705113001895-23699', 'from 10% to 100%', 'increases'),
#    ('S2213671113000908-640', '25 days', 'differentiated')]],
#  'prep,advcl': [2,
#   [('S0950705113001895-23699', 'from 10% to 100%', 'increases'),
#    ('S1389128612002496-6138', 'from 0.25 Mbps to 0.01 Mbps', 'decreases')]],
#  'quantmod,nummod,pobj,prep,advcl': [2,
#   [('S0950705113001895-23699', 'from 10% to 100%', 'increases'),
#    ('S0950705113001895-23699', 'from 10% to 100%', 'increases')]],
#  'appos,appos': [2,
#   [('S0927775713009606-1074', '> 0.5 cm3 g−1)', 'Vmeso'),
#    ('S0927775713009606-1074', '> 170 m2 g−1', 'SBET')]],
#  'punct,appos,npadvmod,ROOT,prep,pobj': [2,
#   [('S0927775713009606-1074', '1 (w/w),', 'ratio'),
#    ('S0927775713009606-1074', '1 (w/w),', 'ratio')]],
#  'quantmod,nummod,compound,dobj': [2,
#   [('S0927024813002961-1051', 'up to 25%', 'variation'),
#    ('S0927024813002961-1051', 'up to 25%', 'variation')]],
#  'quantmod,nummod,compound,dobj,dep,punct': [2,
#   [('S0927024813001955-679', 'up to 100%', 'transmittance to visible light,'),
#    ('S0927024813001955-679',
#     'up to 100%',
#     'transmittance to visible light,')]],
#  'nummod,npadvmod,amod': [2,
#   [('S0927024813001955-576', '125 nm', 'thick'),
#    ('S2211124712002884-1110', 'Ten-day', 'old')]],
#  'quantmod,nummod,npadvmod,amod,dobj,punct': [2,
#   [('S0927024813001955-1005', 'up to 100%', 'visible light transmittance,'),
#    ('S0927024813001955-1005', 'up to 100%', 'visible light transmittance,')]],
#  'pobj,prep,pobj,amod': [2,
#   [('S0927024813001955-1005', '150 °C.', 'post-annealing'),
#    ('S1750583613004192-714', '5 Mt', 'injected')]],
#  'cc,pobj,prep,pobj': [2,
#   [('S0378383912000130-3601',
#     '1.5 mm and 8.5 mm.',
#     'nominal sediment diameters'),
#    ('S0921818113002245-1571', 'between 11.8 m and 11.5 m', 'depth')]],
#  'nummod,pobj,punct,dep': [2,
#   [('S0378383911001669-1088', '0.072 m', 'x'),
#    ('S0378383912000130-3745', '1980 mm,', 'x')]],
#  'punct,parataxis': [2,
#   [('S0378112713005288-2062', '1 kg)', 'weigh'),
#    ('S0378112713005288-2062', '1 kg)', 'weigh')]],
#  'quantmod,conj,nummod,pobj,prep,pobj,prep,ROOT,nsubj,prep': [2,
#   [('S027737911400050X-2401',
#     'several hundred or even more than a thousand years',
#     'offset from'),
#    ('S027737911400050X-2401',
#     'several hundred or even more than a thousand years',
#     'offset from')]],
#  'nmod,compound': [2,
#   [('S0167880913001229-1304', '< 0.01', 'p'),
#    ('S095741741101342X-2624', '15%', 'bad class')]],
#  'nummod,pobj,prep,ccomp': [2,
#   [('S0167880913001229-1021', '12.4%', 'decreased'),
#    ('S1750583613004192-714', '3 years.', 'migrated')]],
#  'compound,attr,ROOT,nsubj': [2,
#   [('S0167610513001001-739', '7.83 m s−1', 'speed'),
#    ('S0927024813003036-2011', '≤1.5×1012 cm−3', 'bulk iron concentrations')]],
#  'pobj,compound': [2,
#   [('S0167577X14001256-517', 'range of 2–4 kV.', 'DC voltage'),
#    ('S0927024813002420-975', '∼1×10−5 Torr', 'vacuum')]],
#  'advmod,nummod,pobj,prep,pobj': [2,
#   [('S0032386113009889-2123', 'about 70 MPa,', 'applied uniaxial stress'),
#    ('S1359645413009816-2243',
#     'about 30 K/min',
#     'rapid cooling to ambient temperature at a rate')]],
#  'nummod,attr,xcomp,ROOT,nsubjpass': [2,
#   [('S0032386113005454-2601', '63 MPa', 'lowest value'),
#    ('S0032386113005454-2865', '0.296 μm.', 'mean diameter')]],
#  'punct,attr,ROOT,nsubj': [2,
#   [('S0032063312003054-2264', 'around 100 km,', 'gyroradius'),
#    ('S030881461301604X-1002', '100 mg/L', 'concentrations')]],
#  'nummod,nsubjpass': [2,
#   [('S0022459611006116-1160', '1:1', 'ratios'),
#    ('S0032063312003054-2501', '37', 'events')]],
#  'nummod,appos,prep,pobj': [2,
#   [('S0022399913003358-943', '50%', 'with chronic tinnitus'),
#    ('S2213158213000582-1327', '48', 'regions in each hemisphere')]],
#  'appos,prep,pobj': [2,
#   [('S0022399913003358-943', '50%', 'with chronic tinnitus'),
#    ('S0032386113005454-2055', '60 × 10 × 3 mm3', 'size.')]],
#  'quantmod,nummod,pobj,prep,acl,pobj': [2,
#   [('S0022399913003358-931', '7 to 20%', 'prevalence'),
#    ('S0022399913003358-931', '7 to 20%', 'prevalence')]],
#  'nummod,pobj,prep,ROOT,nsubjpass': [2,
#   [('S0021979713004438-1415', '25 ± 0.02 °C,', 'temperature'),
#    ('S2213671113001306-1520', '4.2 mm.', 'corneal curvature settings')]],
#  'advmod,nummod,attr,ROOT,nsubj': [2,
#   [('S0021979713004438-1401', '69 ± 3°,', 'contact angle'),
#    ('S0032063312003054-2264', 'around 100 km,', 'gyroradius')]],
#  'prep,pobj,prep,dobj': [2,
#   [('S0019103513005058-4349', 'six orders of magnitude', 'deposition rate'),
#    ('S0032063312003054-2483',
#     'between ∼01:25:00 UT and 01:25:40 UT,',
#     'acceleration')]],
#  'pobj,prep,ROOT,punct': [2,
#   [('S0019103513005058-4158', '∼2 m.', 'depth,'),
#    ('S0032386113005454-2865', '−109 °C,', 'cavitated,')]],
#  'punct,appos': [2,
#   [('S0019103513005058-1737', '1 g cm−3,', 'soil density'),
#    ('S0927775713009606-1074', '> 170 m2 g−1', 'SBET')]],
#  'nummod,pobj,prep,advcl,nsubj': [2,
#   [('S0019103512004009-5507', 'near 1 μbar,', 'base'),
#    ('S0016236113008041-3161', '<2 ppm,', 'concentrations')]],
#  'pobj,prep,advcl,nsubj': [2,
#   [('S0019103512004009-5507', 'near 1 μbar,', 'base'),
#    ('S0016236113008041-3161', '<2 ppm,', 'concentrations')]],
#  'punct,conj,nsubj': [2,
#   [('S0019103512004009-5507', '8250 K,', 'mean temperature'),
#    ('S0019103512004009-3976', '30 km s−1.', 'velocity')]],
#  'ROOT,nsubj': [2,
#   [('S0019103512004009-3976',
#     'increases from 2.6 km s−1 to 25 km s−1.',
#     'velocity'),
#    ('S016412121300188X-4545', 'range from 11.4% to 2.4%.', 'sizes')]],
#  'prep,prep,ROOT,nsubj': [2,
#   [('S0019103512004009-3976',
#     'increases from 2.6 km s−1 to 25 km s−1.',
#     'velocity'),
#    ('S016412121300188X-4545', 'range from 11.4% to 2.4%.', 'sizes')]],
#  'pobj,prep,prep,ROOT,nsubj': [2,
#   [('S0019103512004009-3976',
#     'increases from 2.6 km s−1 to 25 km s−1.',
#     'velocity'),
#    ('S016412121300188X-4545', 'range from 11.4% to 2.4%.', 'sizes')]],
#  'compound,attr,conj,nsubj': [2,
#   [('S0019103512004009-3976', '30 km s−1.', 'velocity'),
#    ('S0021979713004438-1401', '−0.72 V,', 'open circuit potential')]],
#  'npadvmod,acomp': [2,
#   [('S0019103512003995-2737', '5–10', 'stronger'),
#    ('S016412121300188X-4392', '100%', 'accurate')]],
#  'pobj,prep,conj,dobj': [2,
#   [('S0019103512003995-1910', 'within a month and a half.', 'took place'),
#    ('S0019103512003995-2737', 'less than ∼10 times', 'energy inputs')]],
#  'compound,compound': [2,
#   [('S0019103512003995-1807', '589.3 nm', 'resonance'),
#    ('S0021979713004438-1401', '10 wt.%', 'NaOH')]],
#  'quantmod,nummod,nsubj,ROOT,nsubj': [2,
#   [('S0019103512003533-5251', 'up to around 650 K', 'auroral temperatures'),
#    ('S0019103512003533-5251', 'up to around 650 K', 'auroral temperatures')]],
#  'advmod,pobj,prep,pobj': [2,
#   [('S0019103512003533-5072', 'around 1300 m s−1', 'peak velocities'),
#    ('S0921818113002245-1571', 'approximately 11.8 m', 'depth')]],
#  'appos,nmod': [2,
#   [('S0019103512003533-4685', '0°', 'latitude'),
#    ('S0169433213008933-689', '(80/20)', 'gold/palladium')]],
#  'punct,ROOT,conj': [2,
#   [('S0019103512003533-3348', '0.4 scale heights.', 'vertical resolution'),
#    ('S0006322312001096-1190', 'within 72 hours.', 'assayed')]],
#  'prep,dobj': [2,
#   [('S0019103512003533-3306', 'above ∼500 K.', 'temperatures'),
#    ('S0167819113001051-1247',
#     'from 50% to around 80%.',
#     'improve the usability')]],
#  'appos,pobj,prep,nsubjpass': [2,
#   [('S0019103511004994-1565',
#     '56–100 keV)',
#     'measured differential intensity'),
#    ('S0167610512002292-3305', '126 km/h)', 'wind speed')]],
#  'nummod,pobj,prep,conj,prep,pobj': [2,
#   [('S0019103511004994-1511',
#     'between about 20 keV and several tens of MeV.',
#     'energy range'),
#    ('S1550413113004920-1509',
#     'before 9 months',
#     'diagnosed with permanent diabetes')]],
#  'pobj,prep,conj,prep,pobj': [2,
#   [('S0019103511004994-1511',
#     'between about 20 keV and several tens of MeV.',
#     'energy range'),
#    ('S1550413113004920-1509',
#     'before 9 months',
#     'diagnosed with permanent diabetes')]],
#  'pobj,prep,nsubj,prep,pobj,prep,pobj': [2,
#   [('S0019103511004994-1399', 'since July 2004,', 'orbit around Saturn'),
#    ('S0032063312003054-2264', '∼10eV', 'energies')]],
#  'nummod,appos,pobj,compound': [2,
#   [('S0019103511004994-1382', '27 keV to 21 MeV', 'energy'),
#    ('S175058361300203X-1542', '34 and 38 °C', 'temperature')]],
#  'appos,pobj,compound': [2,
#   [('S0019103511004994-1382', '27 keV to 21 MeV', 'energy'),
#    ('S175058361300203X-1542', '34 and 38 °C', 'temperature')]],
#  'punct,npadvmod,ROOT,prep,pobj': [2,
#   [('S0019103511004994-1382', '14 times,', 'flew close by the moon'),
#    ('S0927775713009606-1074', '1 (w/w),', 'ratio')]],
#  'nummod,npadvmod,ROOT,prep,pobj': [2,
#   [('S0019103511004994-1382', '14 times,', 'flew close by the moon'),
#    ('S0019103511004994-1399', '14 times', 'flown by Enceladus')]],
#  'pobj,appos': [2,
#   [('S0016236113008041-913', '13 kg', 'CaCO3'),
#    ('S0012821X12004384-1249', 'from 2605 m to 2634 m', 'core depth')]],
#  'quantmod,nummod,appos,pobj,prep,prep,ROOT,prep,pcomp,dobj': [2,
#   [('S0016236113008041-3269', 'close to 10 ppm', 'concentrations'),
#    ('S0016236113008041-3269', 'close to 10 ppm', 'concentrations')]],
#  'npadvmod,advcl,prep,pobj': [2,
#   [('S0016236113008041-3269', '2000 ppm', 'concentrations'),
#    ('S0012821X12004384-1232', '>0.5 km)', 'deep')]],
#  'nummod,pobj,prep,pobj,prep,ROOT,nsubjpass': [2,
#   [('S0016236113008041-3186', '<0.1 ppm', 'flue gas concentrations'),
#    ('S0378383911001669-1634', 'approximately 0.1 mg/l', 'Fluorescent dye')]],
#  'pobj,prep,pobj,prep,ROOT,nsubjpass': [2,
#   [('S0016236113008041-3186', '<0.1 ppm', 'flue gas concentrations'),
#    ('S0378383911001669-1634', 'approximately 0.1 mg/l', 'Fluorescent dye')]],
#  'pobj,prep,prep,pcomp,nsubj': [2,
#   [('S0016236113008041-3186', '0.42', 'concentration'),
#    ('S0016236113008041-3186', '0.74 ppm', 'concentration')]],
#  'punct,ccomp,nsubj': [2,
#   [('S0012821X13007309-1989', '∼0.8,', '187Os/188Os'),
#    ('S0960148113005727-904', '5–13% per year,', 'load factors')]],
#  'nummod,appos,dobj': [2,
#   [('S0012821X13007309-1989', 'to 600 ppt;', 'Os abundances'),
#    ('S0012821X13007309-1989', '100 ppt)', 'Os abundances')]],
#  'appos,dobj': [2,
#   [('S0012821X13007309-1989', 'to 600 ppt;', 'Os abundances'),
#    ('S0012821X13007309-1989', '100 ppt)', 'Os abundances')]],
#  'pobj,prep,pobj,prep,conj,dobj': [2,
#   [('S0012821X13007309-1989', '10 ppq', 'Os abundance'),
#    ('S0019103512003995-2737', 'less than ∼10 times', 'energy inputs')]],
#  'quantmod,nummod,pobj,prep,ROOT,ccomp,dobj': [2,
#   [('S0012821X13007309-1989', '1 to 30 ppt', 'Os abundances'),
#    ('S0012821X13007309-1989', '1 to 30 ppt', 'Os abundances')]],
#  'npadvmod,prep,pobj': [2,
#   [('S0012821X13007309-1509', '4.3 m', 'below the CTB'),
#    ('S2211124713006475-841', 'weeks', 'after transplantation')]],
#  'quantmod,nummod,pobj,prep,relcl,appos': [2,
#   [('S0012821X13002185-994', 'up to 40%', 'siliceous walled autotrophs'),
#    ('S0012821X13002185-994', 'up to 40%', 'siliceous walled autotrophs')]],
#  'punct,nsubj': [2,
#   [('S0012821X13002185-1231', 'r2=0.92,', 'correlation'),
#    ('S0012821X12004384-1640', '54 oN)', 'paleolatitude')]],
#  'nummod,compound,dobj,prep,pobj': [2,
#   [('S0012821X13002185-1231', '40%', 'differences in the abundance'),
#    ('S0925443913003037-1397', 'approximately 54%', 'level')]],
#  'compound,dobj,prep,pobj': [2,
#   [('S0012821X13002185-1231', '40%', 'differences in the abundance'),
#    ('S0925443913003037-1397', 'approximately 54%', 'level')]],
#  'compound,pobj,prep,pobj,prep,pobj': [2,
#   [('S0012821X13002185-1061', '∼400 ka,', 'emplacement of an ice volume'),
#    ('S175058361300203X-1542', 'range of 34–38 °C', 'temperatures')]],
#  'nummod,nsubj': [2,
#   [('S0012821X12004384-1640', '54 oN)', 'paleolatitude'),
#    ('S0012821X13002185-994', '1.5‰', 'decline')]],
#  'attr,relcl,nsubj': [2,
#   [('S0012821X12004384-1265', '5 g', 'initial weight'),
#    ('S0032063312002437-627', '15 or less', 'mass channel number')]],
#  'nummod,compound,pobj,prep,ccomp': [2,
#   [('S0012821X12004384-1178', '5–8 °C', 'rise'),
#    ('S0167577X13006393-787', 'before 1200 °C', 'occurs')]],
#  'compound,pobj,prep,ccomp': [2,
#   [('S0012821X12004384-1178', '5–8 °C', 'rise'),
#    ('S0167577X13006393-787', 'before 1200 °C', 'occurs')]],
#  'nummod,dobj,acl': [2,
#   [('S0012821X12004384-1178', '170 ka', 'lasting'),
#    ('S0019103513005058-4302', 'over 3 byr', 'accumulated')]],
#  'nummod,nsubj,ROOT,punct': [2,
#   [('S0006322312001096-1230', '5.4%', 'used antidepressant medication,'),
#    ('S0378112713005288-1948',
#     '20%',
#     'variation between the different site types.')]],
#  'nsubj,ROOT,punct': [2,
#   [('S0006322312001096-1230', '5.4%', 'used antidepressant medication,'),
#    ('S0378112713005288-1948',
#     '20%',
#     'variation between the different site types.')]],
#  'nummod,nsubj,ROOT,dobj': [2,
#   [('S0006322312001096-1230', '47.4%', 'also had CES-D depressive symptoms'),
#    ('S0006322312001096-1230', '59.9%', 'also had GHQ symptoms')]],
#  'nsubj,ROOT,dobj': [2,
#   [('S0006322312001096-1230', '47.4%', 'also had CES-D depressive symptoms'),
#    ('S0006322312001096-1230', '59.9%', 'also had GHQ symptoms')]],
#  'nummod,nmod,pobj': [2,
#   [('S0006322312001096-1221', '10%', 'absolute increase'),
#    ('S0012821X12004384-952', '<30%', 'wood/plant tissue')]],
#  'pobj,prep,ccomp,dobj': [2,
#   [('S0006322312001096-1205', 'past 14 days', 'taken any medication'),
#    ('S0168945213001805-4454', '42–48%', 'increased net photosynthesis')]],
#  'nummod,appos,nummod': [2,
#   [('S0006322312001096-1202', '1–2 days,', '1'),
#    ('S0006322312001096-1202', '3–4 days,', '2')]],
#  'appos,nummod': [2,
#   [('S0006322312001096-1202', '1–2 days,', '1'),
#    ('S0006322312001096-1202', '3–4 days,', '2')]],
#  'quantmod,dobj,acl': [2,
#   [('S0006322312001096-1197', '58 to 70', 'aged'),
#    ('S0006322312001096-1197', '58 to 70', 'aged')]],
#  'conj,attr,ROOT,nsubj,conj': [2,
#   [('S0006322312001096-1194', '2.25', 'Age- and sex-adjusted odds ratio'),
#    ('S0006322312001096-1197', '81%,', 'specificity')]],
#  'prep,conj': [2,
#   [('S0006322312001096-1190', 'within 72 hours.', 'assayed'),
#    ('S0019103513005058-4098', 'from 211 K to 284 K', 'increased')]],
#  'nummod,npadvmod,prep,ROOT': [2,
#   [('S0006322312001096-1190', 'at least 5 hours', 'taken'),
#    ('S0019103512001388-1070', 'two days before', 'taken')]],
#  'npadvmod,prep,ROOT': [2,
#   [('S0006322312001096-1190', 'at least 5 hours', 'taken'),
#    ('S0019103512001388-1070', 'two days before', 'taken')]],
#  'nummod,dep,dep': [2,
#   [('S0006322312001096-1177', '8815', 'n'),
#    ('S0006322312001096-1177', '6761', 'n')]],
#  'pobj,prep,acl,prep,pobj': [2,
#   [('S0006322312001096-1177', '1985 to 1988', 'recruitment'),
#    ('S1873506113001116-710',
#     '13 passages',
#     'expanded in static suspension culture')]],
#  'prep,acl,prep,pobj': [2,
#   [('S0006322312001096-1177', '1985 to 1988', 'recruitment'),
#    ('S0960896612001022-1223', 'before the age of 20 years', 'onset')]],
#  'pobj,prep,acl': [2,
#   [('S0006322312001096-1177', '1985', 'established'),
#    ('S0165587612003680-1078', 'three occasions,', 'isolated')]],
#  'pobj,prep,ccomp,punct': [1,
#   [('S2213671113001306-910', '25,000×;', 'magnification;')]],
#  'punct,ROOT,ccomp,punct': [1,
#   [('S2213671113001306-910', '25,000×;', 'magnification;')]],
#  'nummod,nmod,dobj': [1, [('S2213671113001306-910', '2 μm', 'distance')]],
#  'nmod,nmod,dobj': [1, [('S2213671113001306-910', '2 μm', 'distance')]],
#  'nummod,pobj,prep,acl,conj,ccomp,ccomp,punct': [1,
#   [('S2213671113001306-910', '10,500×', 'magnification;')]],
#  'compound,pobj,prep': [1,
#   [('S2213671113001306-1520', '60 μm', 'distance between')]],
#  'nummod,prep,pobj': [1,
#   [('S2213671113001306-1520', '30-degrees', 'visual-field setting')]],
#  'nummod,pobj,prep,acl,pobj,prep,pobj,prep,ROOT,dobj,prep,pobj': [1,
#   [('S2213671113001306-1520', '20 × 20 degrees', 'visual field')]],
#  'dobj,prep,pobj': [1,
#   [('S2213671113001306-1520', '20 × 20 degrees', 'visual field')]],
#  'nummod,dobj,prep,pobj': [1,
#   [('S2213671113001306-1520', '20 × 20 degrees', 'visual field')]],
#  'prep,ROOT,nsubj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     'over more than 20 passages.',
#     'percentage of GFP-positive (GFP+) cells')]],
#  'amod,nummod,pobj,prep,ROOT,nsubj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     'over more than 20 passages.',
#     'percentage of GFP-positive (GFP+) cells')]],
#  'quantmod,nummod,pobj,prep,ROOT,nsubj,prep,pobj': [1,
#   [('S2213671113000921-994',
#     'over more than 20 passages.',
# ...
#   [('S0012821X13007309-1691',
#     '∼−25.9 to −26.5‰.',
#     'narrow variation in background values prior to OAE 2,')]],
#  'prep,prep,dobj,advmod,prep,pobj,punct': [1,
#   [('S0012821X13007309-1691',
#     '∼−25.9 to −26.5‰.',
#     'narrow variation in background values prior to OAE 2,')]],
#  'pobj,prep,prep,dobj,advmod,prep,pobj,punct': [1,
#   [('S0012821X13007309-1691',
#     '∼−25.9 to −26.5‰.',
#     'narrow variation in background values prior to OAE 2,')]],
#  'conj,attr,punct': [1,
#   [('S0012821X13007309-1691', '−27.2 to −23.1‰,', 'shift,')]],
#  'aux,relcl,conj,attr,punct': [1,
#   [('S0012821X13007309-1691', '−27.2 to −23.1‰,', 'shift,')]],
#  'relcl,conj,attr,punct': [1,
#   [('S0012821X13007309-1691', '−27.2 to −23.1‰,', 'shift,')]],
#  'punct,attr,punct': [1,
#   [('S0012821X13007309-1691', '−27.2 to −23.1‰,', 'shift,')]],
#  'prep,advcl,ROOT,attr,punct': [1,
#   [('S0012821X13007309-1691', 'within <0.5 m', 'shift,')]],
#  'quantmod,pobj,prep,advcl,ROOT,attr,punct': [1,
#   [('S0012821X13007309-1691', 'within <0.5 m', 'shift,')]],
#  'compound,pobj,prep,advcl,ROOT,attr,punct': [1,
#   [('S0012821X13007309-1691', 'within <0.5 m', 'shift,')]],
#  'pobj,prep,advcl,ROOT,attr,punct': [1,
#   [('S0012821X13007309-1691', 'within <0.5 m', 'shift,')]],
#  'advmod,npadvmod,prep,pobj,compound': [1,
#   [('S0012821X13007309-1691', 'Up to 20 m', 'beneath the Bonarelli')]],
#  'quantmod,npadvmod,prep,pobj,compound': [1,
#   [('S0012821X13007309-1691', 'Up to 20 m', 'beneath the Bonarelli')]],
#  'compound,npadvmod,prep,pobj,compound': [1,
#   [('S0012821X13007309-1691', 'Up to 20 m', 'beneath the Bonarelli')]],
#  'npadvmod,prep,pobj,compound': [1,
#   [('S0012821X13007309-1691', 'Up to 20 m', 'beneath the Bonarelli')]],
#  'compound,attr,punct': [1, [('S0012821X13007309-1691', '4‰', 'shift,')]],
#  'compound,nummod,attr,amod': [1,
#   [('S0012821X13007309-1691', '1 m', 'thick')]],
#  'nummod,attr,amod': [1, [('S0012821X13007309-1691', '1 m', 'thick')]],
#  'dep,nmod,nsubj,amod': [1, [('S0012821X13007309-1605', '∼20 m', 'thick')]],
#  'nmod,nsubj,amod': [1, [('S0012821X13007309-1605', '∼20 m', 'thick')]],
#  'appos,pobj,prep,nsubj,advcl,prep,pobj': [1,
#   [('S0012821X13007309-1605', 'n=4)', 'came from Vergons')]],
#  'punct,pobj,prep,nsubj,advcl,prep,pobj': [1,
#   [('S0012821X13007309-1605', 'n=4)', 'came from Vergons')]],
#  'pobj,prep,advmod,pobj': [1,
#   [('S0012821X13007309-1509', '∼−27‰', 'gradual fall')]],
#  'pobj,prep,pobj,prep,pobj,nmod': [1,
#   [('S0012821X13007309-1509', '∼−27‰', 'VPDB δ13Corg')]],
#  'nummod,npadvmod,prep,pobj': [1,
#   [('S0012821X13007309-1509', '4.3 m', 'below the CTB')]],
#  'nummod,pobj,det,pobj': [1,
#   [('S0012821X13007309-1509', '2–3‰', 'positive shift')]],
#  'nummod,pobj,amod': [1, [('S0012821X13007309-1482', '17.7 m', 'thick')]],
#  'punct,pobj,prep,ROOT': [1,
#   [('S0012821X13002185-994', '∼31.5 Ma,', 'peaked')]],
#  'nummod,pobj,prep,relcl,appos': [1,
#   [('S0012821X13002185-994', 'up to 40%', 'siliceous walled autotrophs')]],
#  'pobj,prep,relcl,appos': [1,
#   [('S0012821X13002185-994', 'up to 40%', 'siliceous walled autotrophs')]],
#  'nummod,appos': [1, [('S0012821X13002185-994', '0.6‰', 'rise')]],
#  'pobj,prep,pobj,prep,appos': [1, [('S0012821X13002185-1231', '∼−1‰', '30ε')]],
#  'dep,punct,nsubj': [1,
#   [('S0012821X13002185-1231', 'r2=0.92,', 'correlation')]],
#  'nummod,conj,pobj,prep,acl,npadvmod': [1,
#   [('S0012821X13002185-1217', '95%', 'm/Δm∼3500')]],
#  'conj,pobj,prep,acl,npadvmod': [1,
#   [('S0012821X13002185-1217', '95%', 'm/Δm∼3500')]],
#  'nummod,pobj,prep,acl,npadvmod': [1,
#   [('S0012821X13002185-1217', '5%', 'm/Δm∼3500')]],
#  'pobj,prep,acl,npadvmod': [1,
#   [('S0012821X13002185-1217', '5%', 'm/Δm∼3500')]],
#  'dep,dep,dep,punct,nsubj': [1,
#   [('S0012821X13002185-1217', '1.26±0.2‰,', 'external diatomite standard')]],
#  'punct,dep,dep,dep,punct,nsubj': [1,
#   [('S0012821X13002185-1217', '1.26±0.2‰,', 'external diatomite standard')]],
#  'punct,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061', '∼400 ka,', 'emplacement of an ice volume')]],
#  'compound,dobj,relcl': [1, [('S0012821X13002185-1061', '∼2 Ma', 'began')]],
#  'dobj,relcl': [1, [('S0012821X13002185-1061', '∼2 Ma', 'began')]],
#  'prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'pobj,prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'quantmod,pobj,prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'cc,pobj,prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'conj,pobj,prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'quantmod,conj,pobj,prep,pobj,prep,pobj,prep,pobj': [1,
#   [('S0012821X13002185-1061',
#     'between 60% and 100%',
#     'present today on Antarctica')]],
#  'det,pobj,prep,pobj,prep,appos,conj,appos,ROOT,punct': [1,
#   [('S0012821X12004384-952', '>30%', 'wood/plant tissue.')]],
#  'nummod,nmod,pobj,prep,pobj,prep,appos,conj,appos,ROOT,punct': [1,
#   [('S0012821X12004384-952', '>30%', 'wood/plant tissue.')]],
#  'nmod,pobj,prep,pobj,prep,appos,conj,appos,ROOT,punct': [1,
#   [('S0012821X12004384-952', '>30%', 'wood/plant tissue.')]],
#  'prep,nsubj': [1, [('S0012821X12004384-1640', '54 oN)', 'paleolatitude')]],
#  'prep,acomp,acl,prep': [1,
#   [('S0012821X12004384-1599', 'from 103 yrs', 'before')]],
#  'nummod,pobj,prep,acomp,acl,prep': [1,
#   [('S0012821X12004384-1599', 'from 103 yrs', 'before')]],
#  'pobj,prep,acomp,acl,prep': [1,
#   [('S0012821X12004384-1599', 'from 103 yrs', 'before')]],
#  'prep,pobj,prep': [1,
#   [('S0012821X12004384-1599', 'above 2618 m,', 'before')]],
#  'nummod,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1599', 'above 2618 m,', 'before')]],
#  'pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1599', 'above 2618 m,', 'before')]],
#  'punct,pobj,prep': [1,
#   [('S0012821X12004384-1599', 'above 2618 m,', 'before')]],
#  'nummod,compound,attr,parataxis,nsubj': [1,
#   [('S0012821X12004384-1594', '40°N', 'southern boundary')]],
#  'compound,attr,parataxis,nsubj': [1,
#   [('S0012821X12004384-1594', '40°N', 'southern boundary')]],
#  'attr,parataxis,nsubj': [1,
#   [('S0012821X12004384-1594', '40°N', 'southern boundary')]],
#  'dep,punct,ROOT,dobj': [1,
#   [('S0012821X12004384-1284', '±<0.1.', 'precision')]],
#  'quantmod,nummod,pobj': [1,
#   [('S0012821X12004384-1284', '>250 μm', 'size fractions')]],
#  'nmod,ROOT,punct': [1, [('S0012821X12004384-1265', '>250 μm', 'fractions,')]],
#  'nummod,ROOT,punct': [1,
#   [('S0012821X12004384-1265', '>250 μm', 'fractions,')]],
#  'compound,ROOT,punct': [1,
#   [('S0012821X12004384-1265', '>250 μm', 'fractions,')]],
#  'nummod,attr,relcl,nsubj': [1,
#   [('S0012821X12004384-1265', '5 g', 'initial weight')]],
#  'prep,prep,pobj,appos': [1,
#   [('S0012821X12004384-1249', 'from 2605 m to 2634 m', 'core depth')]],
#  'compound,pobj,appos': [1,
#   [('S0012821X12004384-1249', 'from 2605 m to 2634 m', 'core depth')]],
#  'pobj,prep,prep,pobj,appos': [1,
#   [('S0012821X12004384-1249', 'from 2605 m to 2634 m', 'core depth')]],
#  'prep,pobj,appos': [1,
#   [('S0012821X12004384-1249', 'from 2605 m to 2634 m', 'core depth')]],
#  'nummod,pobj,prep,ROOT,acomp': [1,
#   [('S0012821X12004384-1249', '2609–2613 m', 'becomes finely laminated')]],
#  'pobj,prep,ROOT,acomp': [1,
#   [('S0012821X12004384-1249', '2609–2613 m', 'becomes finely laminated')]],
#  'prep,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1232', 'in the order of 100 m', 'fall in')]],
#  'det,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1232', 'in the order of 100 m', 'fall in')]],
#  'pobj,prep,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1232', 'in the order of 100 m', 'fall in')]],
#  'compound,pobj,prep,pobj,prep,pobj,prep': [1,
#   [('S0012821X12004384-1232', 'in the order of 100 m', 'fall in')]],
#  'punct,npadvmod,advcl,prep,pobj': [1,
#   [('S0012821X12004384-1232', '>0.5 km)', 'deep')]],
#  'nummod,npadvmod,advcl,prep,pobj': [1,
#   [('S0012821X12004384-1232', '>0.5 km)', 'deep')]],
#  'punct,attr,advcl,prep,pobj': [1,
#   [('S0012821X12004384-1232', '>0.5 km)', 'deep')]],
#  'nmod,appos,pobj,amod': [1, [('S0012821X12004384-1232', '<10 cm', 'thin')]],
#  'nummod,appos,pobj,amod': [1, [('S0012821X12004384-1232', '<10 cm', 'thin')]],
#  'appos,pobj,amod': [1, [('S0012821X12004384-1232', '<10 cm', 'thin')]],
#  'cc,nummod,pobj': [1,
#   [('S0012821X12004384-1221', 'between 200 and >1000 m', 'depth')]],
#  'conj,nummod,pobj': [1,
#   [('S0012821X12004384-1221', 'between 200 and >1000 m', 'depth')]],
#  'compound,compound,pobj': [1,
#   [('S0012821X12004384-1221', 'between 200 and >1000 m', 'depth')]],
#  'prep,parataxis,ROOT,prep,pobj': [1,
#   [('S0012821X12004384-1178', 'over <20 ka', 'substantial injection')]],
#  'nmod,pobj,prep,parataxis,ROOT,prep,pobj': [1,
#   [('S0012821X12004384-1178', 'over <20 ka', 'substantial injection')]],
#  'nummod,pobj,prep,parataxis,ROOT,prep,pobj': [1,
#   [('S0012821X12004384-1178', 'over <20 ka', 'substantial injection')]],
#  'pobj,prep,parataxis,ROOT,prep,pobj': [1,
#   [('S0012821X12004384-1178', 'over <20 ka', 'substantial injection')]],
#  'prep,dobj,compound': [1,
#   [('S0012821X12004384-1178',
#     'between −2 and −7‰',
#     'negative carbon isotope')]],
#  'pobj,prep,dobj,compound': [1,
#   [('S0012821X12004384-1178',
#     'between −2 and −7‰',
#     'negative carbon isotope')]],
#  'cc,dobj,compound': [1,
#   [('S0012821X12004384-1178',
#     'between −2 and −7‰',
#     'negative carbon isotope')]],
#  'conj,dobj,compound': [1,
#   [('S0012821X12004384-1178',
#     'between −2 and −7‰',
#     'negative carbon isotope')]],
#  'nummod,npadvmod,auxpass': [1,
#   [('S0012821X12004384-1148', '54 °N)', 'paleolatitude')]],
#  'npadvmod,auxpass': [1,
#   [('S0012821X12004384-1148', '54 °N)', 'paleolatitude')]],
#  'npadvmod,npadvmod,auxpass': [1,
#   [('S0012821X12004384-1148', '54 °N)', 'paleolatitude')]],
#  'punct,auxpass': [1, [('S0012821X12004384-1148', '54 °N)', 'paleolatitude')]],
#  'nummod,compound,pobj,prep,ROOT,punct': [1,
#   [('S0006322312001096-626', '10%', 'Increase)')]],
#  'punct,ROOT,advcl,prep,pobj,prep,pobj': [1,
#   [('S0006322312001096-1278', '65,', 'age')]],
#  'ROOT,prep,pobj': [1,
#   [('S0006322312001096-1275', 'range 66% to 88%)', 'response')]],
#  'nummod,dobj,ROOT,prep,pobj': [1,
#   [('S0006322312001096-1275', 'range 66% to 88%)', 'response')]],
#  'dobj,ROOT,prep,pobj': [1,
#   [('S0006322312001096-1275', 'range 66% to 88%)', 'response')]],
#  'advmod,nummod,conj,pobj,meta,pobj,prep,pobj,prep,pobj,conj,conj': [1,
#   [('S0006322312001096-1271',
#     'approximately 80%',
#     'sensitivity and specificity')]],
#  'nummod,conj,pobj,meta,pobj,prep,pobj,prep,pobj,conj,conj': [1,
#   [('S0006322312001096-1271',
#     'approximately 80%',
#     'sensitivity and specificity')]],
#  'conj,pobj,meta,pobj,prep,pobj,prep,pobj,conj,conj': [1,
#   [('S0006322312001096-1271',
#     'approximately 80%',
#     'sensitivity and specificity')]],
#  'advmod,nummod,pobj,meta,pobj,prep,pobj,prep,pobj,conj,conj': [1,
#   [('S0006322312001096-1271', 'almost 90%', 'sensitivity and specificity')]],
#  'nummod,pobj,meta,pobj,prep,pobj,prep,pobj,conj,conj': [1,
#   [('S0006322312001096-1271', 'almost 90%', 'sensitivity and specificity')]],
#  'pobj,meta,pobj,prep,pobj,prep,pobj,conj,conj': [1,
#   [('S0006322312001096-1271', 'almost 90%', 'sensitivity and specificity')]],
#  'prep,ccomp,prt': [1,
#   [('S0006322312001096-1260', 'for 6 years', 'followed up')]],
#  'nummod,pobj,prep,ccomp,prt': [1,
#   [('S0006322312001096-1260', 'for 6 years', 'followed up')]],
#  'pobj,prep,ccomp,prt': [1,
#   [('S0006322312001096-1260', 'for 6 years', 'followed up')]],
#  'punct,ROOT,attr,relcl,dobj,prep,pobj': [1,
#   [('S0006322312001096-1253', '65 years.', 'before the age')]],
#  'nummod,attr,advcl,ROOT,punct': [1,
#   [('S0006322312001096-1230', '9.2%', 'used antidepressant medication,')]],
#  'attr,advcl,ROOT,punct': [1,
#   [('S0006322312001096-1230', '9.2%', 'used antidepressant medication,')]],
#  'nummod,nsubj,conj,punct': [1,
#   [('S0006322312001096-1230', '4.6%', 'had such symptoms at follow-up,')]],
#  'nsubj,conj,punct': [1,
#   [('S0006322312001096-1230', '4.6%', 'had such symptoms at follow-up,')]],
#  'nummod,nsubj,conj,conj,punct': [1,
#   [('S0006322312001096-1230', '2.1%', 'started such medication.')]],
#  'nsubj,conj,conj,punct': [1,
#   [('S0006322312001096-1230', '2.1%', 'started such medication.')]],
#  'nummod,nsubj,ROOT,dobj,punct': [1,
#   [('S0006322312001096-1230', '12.1%', 'developed such symptoms,')]],
#  'nsubj,ROOT,dobj,punct': [1,
#   [('S0006322312001096-1230', '12.1%', 'developed such symptoms,')]],
#  'amod,pobj,prep,ccomp,dobj': [1,
#   [('S0006322312001096-1205', 'past 14 days', 'taken any medication')]],
#  'nummod,pobj,prep,ccomp,dobj': [1,
#   [('S0006322312001096-1205', 'past 14 days', 'taken any medication')]],
#  'nummod,attr,ROOT,prep,pobj,prep,pobj,conj': [1,
#   [('S0006322312001096-1202', '89%', 'sensitivity')]],
#  'attr,ROOT,prep,pobj,prep,pobj,conj': [1,
#   [('S0006322312001096-1202', '89%', 'sensitivity')]],
#  'nummod,conj,attr,ROOT,prep,pobj,prep,pobj,conj,conj': [1,
#   [('S0006322312001096-1202', '86%,', 'specificity')]],
#  'conj,attr,ROOT,prep,pobj,prep,pobj,conj,conj': [1,
#   [('S0006322312001096-1202', '86%,', 'specificity')]],
#  'punct,attr,ROOT,prep,pobj,prep,pobj,conj,conj': [1,
#   [('S0006322312001096-1202', '86%,', 'specificity')]],
#  'nummod,conj,nummod': [1, [('S0006322312001096-1202', '5–7 days', '3')]],
#  'conj,nummod': [1, [('S0006322312001096-1202', '5–7 days', '3')]],
#  'punct,appos,appos,nummod': [1,
#   [('S0006322312001096-1202', '3–4 days,', '2')]],
#  'punct,appos,nummod': [1, [('S0006322312001096-1202', '1–2 days,', '1')]],
#  'nummod,conj,amod': [1, [('S0006322312001096-1197', '84%)', 'specific')]],
#  'conj,amod': [1, [('S0006322312001096-1197', '84%)', 'specific')]],
#  'punct,conj,amod': [1, [('S0006322312001096-1197', '84%)', 'specific')]],
#  'nummod,npadvmod,ccomp,acomp': [1,
#   [('S0006322312001096-1197', '84%)', 'sensitive')]],
#  'npadvmod,ccomp,acomp': [1,
#   [('S0006322312001096-1197', '84%)', 'sensitive')]],
#  'punct,npadvmod,ccomp,acomp': [1,
#   [('S0006322312001096-1197', '84%)', 'sensitive')]],
#  'nummod,conj,attr,ROOT,nsubj,conj': [1,
#   [('S0006322312001096-1197', '81%,', 'specificity')]],
#  'punct,ROOT,nsubj,conj': [1,
#   [('S0006322312001096-1197', '81%,', 'specificity')]],
#  'nummod,appos,conj': [1, [('S0006322312001096-1197', '78%)', 'specificity')]],
#  'appos,conj': [1, [('S0006322312001096-1197', '78%)', 'specificity')]],
#  'punct,conj': [1, [('S0006322312001096-1197', '78%)', 'specificity')]],
#  'cc,pobj,prep,nsubj': [1, [('S0006322312001096-1197', '5 or more', 'score')]],
#  'conj,pobj,prep,nsubj': [1,
#   [('S0006322312001096-1197', '5 or more', 'score')]],
#  'cc,pobj,prep,advcl': [1, [('S0006322312001096-1197', '1 or 0', 'scored')]],
#  'conj,pobj,prep,advcl': [1, [('S0006322312001096-1197', '1 or 0', 'scored')]],
#  'npadvmod,ROOT,prep,pobj,acl,prep,pobj,conj': [1,
#   [('S0006322312001096-1197', '0 to 4', 'scores')]],
#  'quantmod,npadvmod,ROOT,prep,pobj,acl,prep,pobj,conj': [1,
#   [('S0006322312001096-1197', '0 to 4', 'scores')]],
#  'nummod,attr,ROOT,nsubj,conj': [1,
#   [('S0006322312001096-1194', '2.84', 'Age- and sex-adjusted odds ratio')]],
#  'appos,appos,conj,attr,ROOT,nsubj,conj': [1,
#   [('S0006322312001096-1194',
#     '1.92–2.65)',
#     'Age- and sex-adjusted odds ratio')]],
#  'punct,conj,attr,ROOT,nsubj,conj': [1,
#   [('S0006322312001096-1194',
#     '1.92–2.65)',
#     'Age- and sex-adjusted odds ratio')]],
#  'appos,conj,attr,ROOT,nsubj': [1,
#   [('S0006322312001096-1194', '1.85–2.48', 'odds ratios')]],
#  'appos,attr,ROOT,nsubj,conj': [1,
#   [('S0006322312001096-1194',
#     '1.66–4.88)',
#     'Age- and sex-adjusted odds ratio')]],
#  'punct,attr,ROOT,nsubj,conj': [1,
#   [('S0006322312001096-1194',
#     '1.66–4.88)',
#     'Age- and sex-adjusted odds ratio')]],
#  'appos,npadvmod,attr,ROOT,nsubj': [1,
#   [('S0006322312001096-1194', '1.11–1.62)', 'odds ratios')]],
#  'punct,npadvmod,attr,ROOT,nsubj': [1,
#   [('S0006322312001096-1194', '1.11–1.62)', 'odds ratios')]],
#  ...}

# %%
json.dump(freqPos,
           open(f"FrequenciesWithPOS.json","w", encoding = 'utf-8'),
           indent = 3)

# %%
json.dump(freq,
           open(f"FrequenciesWithoutPOS.json","w", encoding = 'utf-8'),
           indent = 3)

# %%
json.dump({k: v for k, v in sorted(d.items(), key=lambda item: item[1],reverse=True)},
           open(f"{prop}_{tp}_shortest_path.json","w", encoding = 'utf-8'),
           indent = 1)

# %%
import networkx as nx
edges = []
for sent in data['S0012821X13007309-1605'].doc.sents:
    for token in sent:
        for child in token.children:
            edges.append(((token.text,token.i,token.dep_),
                          (child.text,child.i,child.dep_)))
#             edges.append(('{0}'.format(token.text+str(token.i)),
#                           '{0}'.format(child.text+str(child.i))))
    break
    
    
print(edges)
# Out:
# [(('Basin', 2, 'nsubj'), ('The', 0, 'det')), (('Basin', 2, 'nsubj'), ('Vocontian', 1, 'compound')), (('was', 3, 'ROOT'), ('Basin', 2, 'nsubj')), (('was', 3, 'ROOT'), ('part', 4, 'attr')), (('part', 4, 'attr'), ('of', 5, 'prep')), (('of', 5, 'prep'), ('gulf', 8, 'pobj')), (('gulf', 8, 'pobj'), ('the', 6, 'det')), (('gulf', 8, 'pobj'), ('western', 7, 'amod')), (('gulf', 8, 'pobj'), ('in', 9, 'prep')), (('in', 9, 'prep'), ('region', 13, 'pobj')), (('Alpine', 12, 'compound'), ('European', 11, 'compound')), (('region', 13, 'pobj'), ('the', 10, 'det')), (('region', 13, 'pobj'), ('Alpine', 12, 'compound')), (('region', 13, 'pobj'), ('of', 14, 'prep')), (('of', 14, 'prep'), ('N', 21, 'pobj')), (('Ocean', 18, 'nmod'), ('NW', 16, 'compound')), (('Ocean', 18, 'nmod'), ('Tethys', 17, 'compound')), (('°', 20, 'compound'), ('Ocean', 18, 'nmod')), (('°', 20, 'compound'), ('∼30', 19, 'dep')), (('N', 21, 'pobj'), ('the', 15, 'det')), (('N', 21, 'pobj'), ('°', 20, 'compound'))]

# %%
graph = nx.Graph(edges)
# Get the length and path
src = ('Basin', 2, 'nsubj')
trg = ('The', 0, 'det')
print(nx.shortest_path_length(graph, source=src, target=trg))
print(nx.shortest_path(graph, source=src, target=trg))
# Out:
# 1
# [('Basin', 2, 'nsubj'), ('The', 0, 'det')]

# %% [markdown]
# The following for loop converts the current spaCy and human annotation format into a gate readable one using text/x-json-twitter format

# %%
import math
for doc in data.values():

    testjson  = doc.doc.to_json()


    twitjson = {"full_text": testjson["text"],"entities":{}}


    for tok in testjson["tokens"]:
        tempToken = {}
        tempToken["indices"] = [tok["start"],tok["end"]] 
        tempToken["category"] = tok["tag"]
        tempToken["kind"] = tok["dep"]
        tempToken["id"] = tok["id"]
        tempToken["head"] = tok["head"]
        try:
            twitjson["entities"]["Token"].append(tempToken)
        except KeyError:
            twitjson["entities"]["Token"] = [tempToken] 

    for ent in testjson["ents"]:
        tempEnt = {}
        tempEnt["indices"] = [ent["start"],ent["end"]] 
        try:
            twitjson["entities"][ent["label"]].append(tempEnt)
        except KeyError:
            twitjson["entities"][ent["label"]] = [tempEnt]
            
    for unit in doc.doc._.unit:
        tempUnit = {}
        tempUnit["indices"] = [int(unit["start"]),int(unit["end"])]
        tempUnit["text"]= unit["text"].text
        try:
            twitjson["entities"]["unit"].append(tempUnit)
        except KeyError:
            twitjson["entities"]["unit"] = [tempUnit]

            
    for sent in testjson["sents"]:
        tempSent = {}
        tempSent["indices"] = [sent["start"],sent["end"]] 
        try:
            twitjson["entities"]["sentence"].append(tempSent)
        except KeyError:
            twitjson["entities"]["sentence"] = [tempSent] 
            
    for index, row in doc.tsv.iterrows():
        tempAnnot = {}
        tempAnnot["indices"] = [row["startOffset"],row["endOffset"]] 
        tempAnnot["annotSet"] = row["annotSet"]
        tempAnnot["annotId"] = row["annotId"]
        tempAnnot["text"] = row["text"]
        if(type(row["other"]) == str):
            tempAnnot["other"] = row["other"]
        else:
            tempAnnot["other"] = "nothing"
            
        try:
            twitjson["entities"]["MEval-"+row["annotType"]].append(tempAnnot)
        except KeyError:
            twitjson["entities"]["MEval-"+row["annotType"]] = [tempAnnot] 

    json.dump(twitjson, open(f'jsondocs/{doc.name}.json',"w"), indent=3)
