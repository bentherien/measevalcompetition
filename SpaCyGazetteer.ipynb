# %% [markdown]
# This notebook contains code for loading in all competition texts and annotations, and converting these to gate readable format

# %%
#imports
import pandas as pd
import os.path
from nltk.tokenize import word_tokenize
import nltk
import json

TRIALPATH = "data/trial"
TRAINPATH = "data/train"
#setup SpaCy
import spacy
import en_core_web_lg
spacy.prefer_gpu()
nlp = en_core_web_lg.load()

# %%
#add pipeline component 
from spacy.matcher import Matcher
from spacy.tokens import Doc
Doc.set_extension("unit", default = "def", force = True)

def customMatcher(nlp):
    matchList = open("measure_units.lst").read().split("\n")
    matcher = Matcher(nlp.vocab)
    pattern = []
    for word in matchList: 
        pattern.append([{"TAG": {"REGEX": "^[CD]"}},{"LOWER": word.lower(),"TAG": {"REGEX": "^[NN|NNP|NNPS|NNS]"}}])
        #pattern.append([{"LOWER": word.lower(),"TAG": {"REGEX": "^[NN|NNP|NNPS|NNS]"}}])
        
    matcher.add("Unit", None, *pattern)
        
    return matcher
    

def gazetteer(doc):
    matcher = customMatcher(nlp)
    matches = matcher(doc)
    doc._.unit = []
    for match_id, start, end in matches:
        tempSpan = doc[start:end]
        doc._.unit.append({'start': tempSpan.start_char, 'end': tempSpan.end_char, 'label': 'UNIT', 'text' : doc[start:end]})
    return doc
        
        
        
nlp.add_pipe(gazetteer, last=True)

# %%
class exerpt:
    """
    Class exerpt
    Description: a simple class to contain data for the measeval competition

    self.name : the measeval given name associated to the document
    self.txt : the raw text of the document
    self.ann : the brat annotations of the document(deprecated)
    self.tsv : a pandas dataframe containing all the tab seperated value data
    self.grobid : grobid quantities json output for quantity detection
    self.doc : The spacy doc generated from processing on this particular document
    """
    
    def __init__(self, name, txt, ann, tsv, grobid):
        self.name = name
        self.txt = txt
        self.ann = ann
        self.tsv = tsv
        self.grobid = grobid
        self.context = False
        self.posTag = False
        self.doc = nlp(self.txt)
        
    def getContext(self, count = 3):
        if self.context == False: 
            beforeContext = []
            afterContext = []
            self.context = True
            for start,end in zip(self.tsv["startOffset"].values, self.tsv["endOffset"].values ):#self.tsv.iterrows():
                a = getIndexSeperated(exerpt.txt[0],end,count = count)
                b = getIndexSeperated(exerpt.txt[0],start,count = count,forward = False)
                beforeContext.append(self.txt[0][b:start])
                afterContext.append(self.txt[0][end:a])
            self.tsv.insert(3,"beforeContext", beforeContext)
            self.tsv.insert(3,"afterContext", afterContext)
            
    def getPosTag(self):
        if self.context and self.posTag == False: 
            bTag = []
            aTag = []
            self.posTag = True
            for before, after in zip(self.tsv["beforeContext"].values,self.tsv["afterContext"].values):
                bTag.append(nltk.pos_tag(word_tokenize(before)))
                aTag.append(nltk.pos_tag(word_tokenize(after)))
            self.tsv.insert(3,"beforeTag", bTag)
            self.tsv.insert(3,"afterTag", aTag)

# %%
def readTXTByLine(filepath):
    ftemp = open(filepath, "r", encoding = "utf-8")
    raw = str(ftemp.read())
    ftemp.close()
    return raw

data = {}

#load all trial data
for fn in os.listdir(os.path.join(TRIALPATH,"txt")):
        if fn.endswith('.txt'):
            data[fn[:-4]] = exerpt(
                fn[:-4],
                readTXTByLine(os.path.join(TRIALPATH, "txt", fn[:-4] + ".txt")),
                readTXTByLine(os.path.join(TRIALPATH, "ann", fn[:-4] + ".ann")),
                pd.read_csv(os.path.join(TRIALPATH, "tsv", fn[:-4] + ".tsv"), "\t", header = 0 ),
                json.load(open(os.path.join(TRIALPATH, "grobid", fn[:-4] + ".grobid")))
            )

#load all train data
for fn in [x for x in os.listdir(os.path.join(TRAINPATH,"text")) if x[:-4]+".tsv" in os.listdir(os.path.join(TRAINPATH,"tsv"))]:
        if fn.endswith('.txt'):
            data[fn[:-4]] = exerpt(
                fn[:-4],
                readTXTByLine(os.path.join(TRAINPATH, "text", fn[:-4] + ".txt")),
                "none",
                pd.read_csv(os.path.join(TRAINPATH, "tsv", fn[:-4] + ".tsv"), "\t", header = 0 ),
                json.load(open(os.path.join(TRAINPATH, "grobid", fn[:-4] + ".grobid"))))

# %%
count = 0 
for doc in data.values():
    for unit in doc.doc._.unit:
        print(unit)
        count+=1
print(count)
# Out:
# {'start': 628, 'end': 637, 'label': 'UNIT', 'text': 2614.71 m}
# {'start': 791, 'end': 800, 'label': 'UNIT', 'text': 2614.71 m}
# {'start': 52, 'end': 58, 'label': 'UNIT', 'text': 2618 m}
# {'start': 162, 'end': 168, 'label': 'UNIT', 'text': 2618 m}
# {'start': 117, 'end': 123, 'label': 'UNIT', 'text': 2618 m}
# {'start': 123, 'end': 128, 'label': 'UNIT', 'text': 0.2 M}
# {'start': 148, 'end': 154, 'label': 'UNIT', 'text': 40 min}
# {'start': 174, 'end': 180, 'label': 'UNIT', 'text': 1 week}
# {'start': 240, 'end': 245, 'label': 'UNIT', 'text': 0.2 M}
# {'start': 1084, 'end': 1092, 'label': 'UNIT', 'text': and text}
# {'start': 160, 'end': 165, 'label': 'UNIT', 'text': 100 m}
# {'start': 92, 'end': 98, 'label': 'UNIT', 'text': 17.7 m}
# {'start': 451, 'end': 456, 'label': 'UNIT', 'text': 20 cm}
# {'start': 129, 'end': 134, 'label': 'UNIT', 'text': 4.3 m}
# {'start': 1001, 'end': 1005, 'label': 'UNIT', 'text': 24 m}
# {'start': 974, 'end': 981, 'label': 'UNIT', 'text': 600 ppt}
# {'start': 1053, 'end': 1059, 'label': 'UNIT', 'text': 30 ppt}
# {'start': 1172, 'end': 1178, 'label': 'UNIT', 'text': 30 ppt}
# {'start': 1392, 'end': 1399, 'label': 'UNIT', 'text': 100 ppt}
# {'start': 62, 'end': 73, 'label': 'UNIT', 'text': the calcium}
# {'start': 456, 'end': 462, 'label': 'UNIT', 'text': and Ti}
# {'start': 495, 'end': 500, 'label': 'UNIT', 'text': and K}
# {'start': 880, 'end': 886, 'label': 'UNIT', 'text': 40 ppm}
# {'start': 1283, 'end': 1290, 'label': 'UNIT', 'text': 400 ppm}
# {'start': 1720, 'end': 1731, 'label': 'UNIT', 'text': the calcium}
# {'start': 581, 'end': 591, 'label': 'UNIT', 'text': the volume}
# {'start': 141, 'end': 149, 'label': 'UNIT', 'text': the mass}
# {'start': 256, 'end': 261, 'label': 'UNIT', 'text': 13 kg}
# {'start': 384, 'end': 389, 'label': 'UNIT', 'text': 2 ppm}
# {'start': 283, 'end': 289, 'label': 'UNIT', 'text': 4.5 kg}
# {'start': 332, 'end': 340, 'label': 'UNIT', 'text': 0.22 ppm}
# {'start': 358, 'end': 363, 'label': 'UNIT', 'text': 13 kg}
# {'start': 387, 'end': 392, 'label': 'UNIT', 'text': and U}
# {'start': 494, 'end': 499, 'label': 'UNIT', 'text': 1 ppm}
# {'start': 626, 'end': 630, 'label': 'UNIT', 'text': 6 kg}
# {'start': 636, 'end': 642, 'label': 'UNIT', 'text': 4.5 kg}
# {'start': 669, 'end': 673, 'label': 'UNIT', 'text': 6 kg}
# {'start': 677, 'end': 682, 'label': 'UNIT', 'text': 13 kg}
# {'start': 732, 'end': 739, 'label': 'UNIT', 'text': 0.1 ppm}
# {'start': 74, 'end': 79, 'label': 'UNIT', 'text': and W}
# {'start': 122, 'end': 129, 'label': 'UNIT', 'text': 0.1 ppm}
# {'start': 212, 'end': 220, 'label': 'UNIT', 'text': 0.74 ppm}
# {'start': 248, 'end': 253, 'label': 'UNIT', 'text': 13 kg}
# {'start': 344, 'end': 351, 'label': 'UNIT', 'text': 0.1 ppm}
# {'start': 164, 'end': 170, 'label': 'UNIT', 'text': and Sr}
# {'start': 296, 'end': 304, 'label': 'UNIT', 'text': 2000 ppm}
# {'start': 359, 'end': 367, 'label': 'UNIT', 'text': 1000 ppm}
# {'start': 446, 'end': 454, 'label': 'UNIT', 'text': 1000 ppm}
# {'start': 490, 'end': 498, 'label': 'UNIT', 'text': 2000 ppm}
# {'start': 714, 'end': 722, 'label': 'UNIT', 'text': 1000 ppm}
# {'start': 764, 'end': 771, 'label': 'UNIT', 'text': 135 ppm}
# {'start': 791, 'end': 798, 'label': 'UNIT', 'text': 407 ppm}
# {'start': 835, 'end': 843, 'label': 'UNIT', 'text': 2000 ppm}
# {'start': 867, 'end': 873, 'label': 'UNIT', 'text': 10 ppm}
# {'start': 1004, 'end': 1012, 'label': 'UNIT', 'text': 66.8 ppm}
# {'start': 1051, 'end': 1059, 'label': 'UNIT', 'text': 2000 ppm}
# {'start': 140, 'end': 145, 'label': 'UNIT', 'text': 1 ppm}
# {'start': 212, 'end': 220, 'label': 'UNIT', 'text': 0.51 ppm}
# {'start': 257, 'end': 265, 'label': 'UNIT', 'text': 1000 ppm}
# {'start': 430, 'end': 438, 'label': 'UNIT', 'text': 2000 ppm}
# {'start': 97, 'end': 103, 'label': 'UNIT', 'text': 4.5 kg}
# {'start': 105, 'end': 109, 'label': 'UNIT', 'text': 6 kg}
# {'start': 114, 'end': 119, 'label': 'UNIT', 'text': 13 kg}
# {'start': 96, 'end': 101, 'label': 'UNIT', 'text': 0 ppm}
# {'start': 103, 'end': 111, 'label': 'UNIT', 'text': 1000 ppm}
# {'start': 116, 'end': 124, 'label': 'UNIT', 'text': 2000 ppm}
# {'start': 147, 'end': 152, 'label': 'UNIT', 'text': 13 kg}
# {'start': 40, 'end': 46, 'label': 'UNIT', 'text': 4.5 kg}
# {'start': 48, 'end': 52, 'label': 'UNIT', 'text': 6 kg}
# {'start': 57, 'end': 62, 'label': 'UNIT', 'text': 13 kg}
# {'start': 273, 'end': 278, 'label': 'UNIT', 'text': the E}
# {'start': 354, 'end': 362, 'label': 'UNIT', 'text': the time}
# {'start': 456, 'end': 461, 'label': 'UNIT', 'text': 25 km}
# {'start': 649, 'end': 658, 'label': 'UNIT', 'text': this work}
# {'start': 722, 'end': 732, 'label': 'UNIT', 'text': the energy}
# {'start': 296, 'end': 306, 'label': 'UNIT', 'text': the energy}
# {'start': 631, 'end': 636, 'label': 'UNIT', 'text': and F}
# {'start': 741, 'end': 751, 'label': 'UNIT', 'text': and energy}
# {'start': 978, 'end': 982, 'label': 'UNIT', 'text': 86 s}
# {'start': 1530, 'end': 1538, 'label': 'UNIT', 'text': an angle}
# {'start': 1658, 'end': 1666, 'label': 'UNIT', 'text': the time}
# {'start': 1748, 'end': 1754, 'label': 'UNIT', 'text': 5.65 s}
# {'start': 1781, 'end': 1787, 'label': 'UNIT', 'text': 0.66 s}
# {'start': 1825, 'end': 1829, 'label': 'UNIT', 'text': 86 s}
# {'start': 215, 'end': 223, 'label': 'UNIT', 'text': The time}
# {'start': 50, 'end': 56, 'label': 'UNIT', 'text': 764 km}
# {'start': 169, 'end': 178, 'label': 'UNIT', 'text': 60,268 km}
# {'start': 269, 'end': 279, 'label': 'UNIT', 'text': and carbon}
# {'start': 18, 'end': 27, 'label': 'UNIT', 'text': this time}
# {'start': 90, 'end': 94, 'label': 'UNIT', 'text': 5 km}
# {'start': 510, 'end': 518, 'label': 'UNIT', 'text': the time}
# {'start': 234, 'end': 242, 'label': 'UNIT', 'text': the time}
# {'start': 463, 'end': 475, 'label': 'UNIT', 'text': and pressure}
# {'start': 399, 'end': 409, 'label': 'UNIT', 'text': and energy}
# {'start': 587, 'end': 597, 'label': 'UNIT', 'text': The energy}
# {'start': 869, 'end': 880, 'label': 'UNIT', 'text': the Lambert}
# {'start': 1261, 'end': 1271, 'label': 'UNIT', 'text': the energy}
# {'start': 430, 'end': 433, 'label': 'UNIT', 'text': 5 s}
# {'start': 593, 'end': 600, 'label': 'UNIT', 'text': 1000 km}
# {'start': 252, 'end': 255, 'label': 'UNIT', 'text': 6 K}
# {'start': 136, 'end': 141, 'label': 'UNIT', 'text': 450 K}
# {'start': 166, 'end': 171, 'label': 'UNIT', 'text': 180 K}
# {'start': 271, 'end': 275, 'label': 'UNIT', 'text': 30 K}
# {'start': 382, 'end': 386, 'label': 'UNIT', 'text': 14 K}
# {'start': 528, 'end': 533, 'label': 'UNIT', 'text': 450 K}
# {'start': 109, 'end': 115, 'label': 'UNIT', 'text': 1300 m}
# {'start': 246, 'end': 256, 'label': 'UNIT', 'text': the degree}
# {'start': 610, 'end': 624, 'label': 'UNIT', 'text': the atmosphere}
# {'start': 541, 'end': 545, 'label': 'UNIT', 'text': 30 K}
# {'start': 664, 'end': 669, 'label': 'UNIT', 'text': 650 K}
# {'start': 762, 'end': 767, 'label': 'UNIT', 'text': 650 K}
# {'start': 876, 'end': 881, 'label': 'UNIT', 'text': 650 K}
# {'start': 934, 'end': 939, 'label': 'UNIT', 'text': 650 K}
# {'start': 505, 'end': 514, 'label': 'UNIT', 'text': the Joule}
# {'start': 884, 'end': 889, 'label': 'UNIT', 'text': 490 K}
# {'start': 1014, 'end': 1018, 'label': 'UNIT', 'text': 60 K}
# {'start': 58, 'end': 72, 'label': 'UNIT', 'text': the atmosphere}
# {'start': 809, 'end': 823, 'label': 'UNIT', 'text': the atmosphere}
# {'start': 604, 'end': 611, 'label': 'UNIT', 'text': a month}
# {'start': 616, 'end': 622, 'label': 'UNIT', 'text': a half}
# {'start': 663, 'end': 666, 'label': 'UNIT', 'text': 2 h}
# {'start': 944, 'end': 952, 'label': 'UNIT', 'text': the time}
# {'start': 37, 'end': 49, 'label': 'UNIT', 'text': the velocity}
# {'start': 324, 'end': 329, 'label': 'UNIT', 'text': 11 km}
# {'start': 342, 'end': 354, 'label': 'UNIT', 'text': The velocity}
# {'start': 38, 'end': 43, 'label': 'UNIT', 'text': the H}
# {'start': 270, 'end': 282, 'label': 'UNIT', 'text': the pressure}
# {'start': 300, 'end': 305, 'label': 'UNIT', 'text': the H}
# {'start': 427, 'end': 439, 'label': 'UNIT', 'text': the pressure}
# {'start': 857, 'end': 863, 'label': 'UNIT', 'text': 8250 K}
# {'start': 1022, 'end': 1028, 'label': 'UNIT', 'text': 6000 K}
# {'start': 1033, 'end': 1041, 'label': 'UNIT', 'text': 11,000 K}
# {'start': 550, 'end': 556, 'label': 'UNIT', 'text': 1300 K}
# {'start': 560, 'end': 566, 'label': 'UNIT', 'text': 3500 K}
# {'start': 650, 'end': 661, 'label': 'UNIT', 'text': the density}
# {'start': 859, 'end': 870, 'label': 'UNIT', 'text': the density}
# {'start': 929, 'end': 943, 'label': 'UNIT', 'text': the atmosphere}
# {'start': 263, 'end': 271, 'label': 'UNIT', 'text': 11,500 K}
# {'start': 463, 'end': 471, 'label': 'UNIT', 'text': 10,000 K}
# {'start': 55, 'end': 61, 'label': 'UNIT', 'text': 8250 K}
# {'start': 556, 'end': 563, 'label': 'UNIT', 'text': the Sun}
# {'start': 803, 'end': 815, 'label': 'UNIT', 'text': the pressure}
# {'start': 607, 'end': 619, 'label': 'UNIT', 'text': and velocity}
# {'start': 894, 'end': 899, 'label': 'UNIT', 'text': 50 eV}
# {'start': 1366, 'end': 1377, 'label': 'UNIT', 'text': and density}
# {'start': 286, 'end': 292, 'label': 'UNIT', 'text': 7.2 km}
# {'start': 298, 'end': 308, 'label': 'UNIT', 'text': The volume}
# {'start': 352, 'end': 362, 'label': 'UNIT', 'text': this point}
# {'start': 416, 'end': 422, 'label': 'UNIT', 'text': 7100 K}
# {'start': 424, 'end': 429, 'label': 'UNIT', 'text': and m}
# {'start': 594, 'end': 608, 'label': 'UNIT', 'text': the atmosphere}
# {'start': 340, 'end': 346, 'label': 'UNIT', 'text': 1000 K}
# {'start': 680, 'end': 685, 'label': 'UNIT', 'text': 20 eV}
# {'start': 710, 'end': 716, 'label': 'UNIT', 'text': 0.45 W}
# {'start': 773, 'end': 784, 'label': 'UNIT', 'text': the density}
# {'start': 42, 'end': 47, 'label': 'UNIT', 'text': the H}
# {'start': 257, 'end': 263, 'label': 'UNIT', 'text': 8250 K}
# {'start': 269, 'end': 283, 'label': 'UNIT', 'text': the atmosphere}
# {'start': 415, 'end': 426, 'label': 'UNIT', 'text': The density}
# {'start': 779, 'end': 784, 'label': 'UNIT', 'text': the H}
# {'start': 97, 'end': 100, 'label': 'UNIT', 'text': 1 g}
# {'start': 111, 'end': 125, 'label': 'UNIT', 'text': the atmosphere}
# {'start': 284, 'end': 298, 'label': 'UNIT', 'text': the atmosphere}
# {'start': 546, 'end': 558, 'label': 'UNIT', 'text': and chlorine}
# {'start': 880, 'end': 889, 'label': 'UNIT', 'text': this time}
# {'start': 897, 'end': 903, 'label': 'UNIT', 'text': a time}
# {'start': 143, 'end': 146, 'label': 'UNIT', 'text': 2 m}
# {'start': 240, 'end': 243, 'label': 'UNIT', 'text': a Q}
# {'start': 412, 'end': 422, 'label': 'UNIT', 'text': the energy}
# {'start': 164, 'end': 172, 'label': 'UNIT', 'text': the mass}
# {'start': 262, 'end': 271, 'label': 'UNIT', 'text': This mass}
# {'start': 815, 'end': 821, 'label': 'UNIT', 'text': 10 min}
# {'start': 49, 'end': 56, 'label': 'UNIT', 'text': an iron}
# {'start': 314, 'end': 322, 'label': 'UNIT', 'text': the iron}
# {'start': 555, 'end': 563, 'label': 'UNIT', 'text': the iron}
# {'start': 642, 'end': 647, 'label': 'UNIT', 'text': and c}
# {'start': 817, 'end': 822, 'label': 'UNIT', 'text': the Z}
# {'start': 1173, 'end': 1178, 'label': 'UNIT', 'text': the Z}
# {'start': 193, 'end': 199, 'label': 'UNIT', 'text': 15 min}
# {'start': 1123, 'end': 1131, 'label': 'UNIT', 'text': the area}
# {'start': 4747, 'end': 4756, 'label': 'UNIT', 'text': this work}
# {'start': 125, 'end': 135, 'label': 'UNIT', 'text': 55–74 year}
# {'start': 237, 'end': 248, 'label': 'UNIT', 'text': some degree}
# {'start': 240, 'end': 248, 'label': 'UNIT', 'text': or argon}
# {'start': 230, 'end': 236, 'label': 'UNIT', 'text': 50 min}
# {'start': 696, 'end': 703, 'label': 'UNIT', 'text': a light}
# {'start': 1248, 'end': 1252, 'label': 'UNIT', 'text': 75 g}
# {'start': 319, 'end': 332, 'label': 'UNIT', 'text': the frequency}
# {'start': 398, 'end': 408, 'label': 'UNIT', 'text': four point}
# {'start': 430, 'end': 437, 'label': 'UNIT', 'text': one day}
# {'start': 822, 'end': 825, 'label': 'UNIT', 'text': 7 r}
# {'start': 655, 'end': 665, 'label': 'UNIT', 'text': two survey}
# {'start': 678, 'end': 693, 'label': 'UNIT', 'text': and information}
# {'start': 247, 'end': 254, 'label': 'UNIT', 'text': a score}
# {'start': 161, 'end': 176, 'label': 'UNIT', 'text': and information}
# {'start': 27, 'end': 37, 'label': 'UNIT', 'text': the survey}
# {'start': 1070, 'end': 1076, 'label': 'UNIT', 'text': 0.5 km}
# {'start': 29, 'end': 35, 'label': 'UNIT', 'text': 0.5 km}
# {'start': 339, 'end': 344, 'label': 'UNIT', 'text': 10 cm}
# {'start': 531, 'end': 536, 'label': 'UNIT', 'text': 100 m}
# {'start': 507, 'end': 513, 'label': 'UNIT', 'text': 2605 m}
# {'start': 517, 'end': 523, 'label': 'UNIT', 'text': 2634 m}
# {'start': 698, 'end': 709, 'label': 'UNIT', 'text': 2609–2613 m}
# {'start': 50, 'end': 61, 'label': 'UNIT', 'text': the British}
# {'start': 594, 'end': 597, 'label': 'UNIT', 'text': 5 g}
# {'start': 689, 'end': 695, 'label': 'UNIT', 'text': 0.05 g}
# {'start': 1298, 'end': 1302, 'label': 'UNIT', 'text': 60 g}
# {'start': 748, 'end': 752, 'label': 'UNIT', 'text': 24 h}
# {'start': 483, 'end': 486, 'label': 'UNIT', 'text': 4 m}
# {'start': 669, 'end': 677, 'label': 'UNIT', 'text': 2619.6 m}
# {'start': 1491, 'end': 1499, 'label': 'UNIT', 'text': the spin}
# {'start': 147, 'end': 150, 'label': 'UNIT', 'text': 1 m}
# {'start': 339, 'end': 343, 'label': 'UNIT', 'text': 20 m}
# {'start': 654, 'end': 659, 'label': 'UNIT', 'text': 0.5 m}
# {'start': 255, 'end': 260, 'label': 'UNIT', 'text': 13 kg}
# {'start': 50, 'end': 56, 'label': 'UNIT', 'text': 4.5 kg}
# {'start': 439, 'end': 445, 'label': 'UNIT', 'text': 4.5 kg}
# {'start': 450, 'end': 455, 'label': 'UNIT', 'text': 13 kg}
# {'start': 484, 'end': 488, 'label': 'UNIT', 'text': 6 kg}
# {'start': 537, 'end': 545, 'label': 'UNIT', 'text': 0.01 ppm}
# {'start': 668, 'end': 673, 'label': 'UNIT', 'text': 2 ppm}
# {'start': 99, 'end': 105, 'label': 'UNIT', 'text': 4.5 kg}
# {'start': 107, 'end': 111, 'label': 'UNIT', 'text': 6 kg}
# {'start': 116, 'end': 121, 'label': 'UNIT', 'text': 13 kg}
# {'start': 120, 'end': 129, 'label': 'UNIT', 'text': 60,268 km}
# {'start': 241, 'end': 247, 'label': 'UNIT', 'text': 252 km}
# {'start': 1245, 'end': 1250, 'label': 'UNIT', 'text': the E}
# {'start': 188, 'end': 193, 'label': 'UNIT', 'text': and y}
# {'start': 220, 'end': 230, 'label': 'UNIT', 'text': The energy}
# {'start': 596, 'end': 602, 'label': 'UNIT', 'text': 30 min}
# {'start': 81, 'end': 86, 'label': 'UNIT', 'text': the H}
# {'start': 1408, 'end': 1416, 'label': 'UNIT', 'text': the time}
# {'start': 214, 'end': 223, 'label': 'UNIT', 'text': 320–500 K}
# {'start': 603, 'end': 612, 'label': 'UNIT', 'text': + density}
# {'start': 19, 'end': 24, 'label': 'UNIT', 'text': and H}
# {'start': 61, 'end': 72, 'label': 'UNIT', 'text': the density}
# {'start': 265, 'end': 270, 'label': 'UNIT', 'text': the C}
# {'start': 534, 'end': 544, 'label': 'UNIT', 'text': the energy}
# {'start': 740, 'end': 745, 'label': 'UNIT', 'text': the H}
# {'start': 812, 'end': 823, 'label': 'UNIT', 'text': 109–1010 kg}
# {'start': 824, 'end': 832, 'label': 'UNIT', 'text': s−1 lead}
# {'start': 151, 'end': 162, 'label': 'UNIT', 'text': and density}
# {'start': 515, 'end': 527, 'label': 'UNIT', 'text': and velocity}
# {'start': 731, 'end': 741, 'label': 'UNIT', 'text': and helium}
# {'start': 1417, 'end': 1423, 'label': 'UNIT', 'text': both C}
# {'start': 1516, 'end': 1528, 'label': 'UNIT', 'text': and velocity}
# {'start': 1691, 'end': 1697, 'label': 'UNIT', 'text': 8000 K}
# {'start': 1778, 'end': 1784, 'label': 'UNIT', 'text': 7000 K}
# {'start': 1824, 'end': 1832, 'label': 'UNIT', 'text': 0.047 AU}
# {'start': 49, 'end': 61, 'label': 'UNIT', 'text': the velocity}
# {'start': 149, 'end': 161, 'label': 'UNIT', 'text': the velocity}
# {'start': 199, 'end': 205, 'label': 'UNIT', 'text': 2.6 km}
# {'start': 213, 'end': 218, 'label': 'UNIT', 'text': 25 km}
# {'start': 233, 'end': 245, 'label': 'UNIT', 'text': the velocity}
# {'start': 329, 'end': 341, 'label': 'UNIT', 'text': the velocity}
# {'start': 372, 'end': 377, 'label': 'UNIT', 'text': 30 km}
# {'start': 584, 'end': 596, 'label': 'UNIT', 'text': The velocity}
# {'start': 0, 'end': 5, 'label': 'UNIT', 'text': The H}
# {'start': 138, 'end': 143, 'label': 'UNIT', 'text': the H}
# {'start': 262, 'end': 276, 'label': 'UNIT', 'text': the atmosphere}
# {'start': 413, 'end': 419, 'label': 'UNIT', 'text': 3800 K}
# {'start': 567, 'end': 573, 'label': 'UNIT', 'text': 1300 K}
# {'start': 665, 'end': 670, 'label': 'UNIT', 'text': the H}
# {'start': 984, 'end': 987, 'label': 'UNIT', 'text': a H}
# {'start': 298, 'end': 304, 'label': 'UNIT', 'text': 106 kg}
# {'start': 265, 'end': 278, 'label': 'UNIT', 'text': and magnesium}
# {'start': 958, 'end': 964, 'label': 'UNIT', 'text': a mass}
# {'start': 990, 'end': 998, 'label': 'UNIT', 'text': the mass}
# {'start': 1914, 'end': 1919, 'label': 'UNIT', 'text': 1 ppm}
# {'start': 28, 'end': 42, 'label': 'UNIT', 'text': the atmosphere}
# {'start': 409, 'end': 416, 'label': 'UNIT', 'text': 0.02 cm}
# {'start': 423, 'end': 428, 'label': 'UNIT', 'text': 211 K}
# {'start': 432, 'end': 437, 'label': 'UNIT', 'text': 284 K}
# {'start': 418, 'end': 432, 'label': 'UNIT', 'text': and atmosphere}
# {'start': 724, 'end': 731, 'label': 'UNIT', 'text': three e}
# {'start': 858, 'end': 861, 'label': 'UNIT', 'text': 1 g}
# {'start': 642, 'end': 651, 'label': 'UNIT', 'text': 1.5–2.6 m}
# {'start': 65, 'end': 73, 'label': 'UNIT', 'text': all iron}
# {'start': 314, 'end': 322, 'label': 'UNIT', 'text': the iron}
# {'start': 529, 'end': 536, 'label': 'UNIT', 'text': 10 year}
# {'start': 610, 'end': 613, 'label': 'UNIT', 'text': 9 m}
# {'start': 656, 'end': 663, 'label': 'UNIT', 'text': 7 month}
# {'start': 343, 'end': 348, 'label': 'UNIT', 'text': 192 s}
# {'start': 78, 'end': 86, 'label': 'UNIT', 'text': The time}
# {'start': 122, 'end': 128, 'label': 'UNIT', 'text': 12 min}
# {'start': 296, 'end': 306, 'label': 'UNIT', 'text': the energy}
# {'start': 403, 'end': 413, 'label': 'UNIT', 'text': the energy}
# {'start': 478, 'end': 488, 'label': 'UNIT', 'text': the energy}
# {'start': 443, 'end': 458, 'label': 'UNIT', 'text': an acceleration}
# {'start': 587, 'end': 593, 'label': 'UNIT', 'text': 100 km}
# {'start': 697, 'end': 703, 'label': 'UNIT', 'text': 400 km}
# {'start': 763, 'end': 779, 'label': 'UNIT', 'text': the acceleration}
# {'start': 18, 'end': 33, 'label': 'UNIT', 'text': an acceleration}
# {'start': 557, 'end': 567, 'label': 'UNIT', 'text': the energy}
# {'start': 193, 'end': 197, 'label': 'UNIT', 'text': 1 Hz}
# {'start': 633, 'end': 644, 'label': 'UNIT', 'text': the density}
# {'start': 722, 'end': 727, 'label': 'UNIT', 'text': and q}
# {'start': 752, 'end': 763, 'label': 'UNIT', 'text': the density}
# {'start': 899, 'end': 910, 'label': 'UNIT', 'text': The density}
# {'start': 1008, 'end': 1014, 'label': 'UNIT', 'text': 1.20 g}
# {'start': 46, 'end': 51, 'label': 'UNIT', 'text': the S}
# {'start': 714, 'end': 719, 'label': 'UNIT', 'text': the S}
# {'start': 889, 'end': 894, 'label': 'UNIT', 'text': the S}
# {'start': 1481, 'end': 1486, 'label': 'UNIT', 'text': the S}
# {'start': 1716, 'end': 1721, 'label': 'UNIT', 'text': the S}
# {'start': 0, 'end': 9, 'label': 'UNIT', 'text': An energy}
# {'start': 205, 'end': 215, 'label': 'UNIT', 'text': the energy}
# {'start': 287, 'end': 298, 'label': 'UNIT', 'text': this energy}
# {'start': 559, 'end': 564, 'label': 'UNIT', 'text': 20 cm}
# {'start': 2628, 'end': 2637, 'label': 'UNIT', 'text': this time}
# {'start': 107, 'end': 112, 'label': 'UNIT', 'text': The B}
# {'start': 1083, 'end': 1089, 'label': 'UNIT', 'text': a Gram}
# {'start': 266, 'end': 275, 'label': 'UNIT', 'text': and argon}
# {'start': 75, 'end': 80, 'label': 'UNIT', 'text': and P}
# {'start': 87, 'end': 94, 'label': 'UNIT', 'text': 0.563 m}
# {'start': 130, 'end': 141, 'label': 'UNIT', 'text': The density}
# {'start': 532, 'end': 537, 'label': 'UNIT', 'text': the Z}
# {'start': 75, 'end': 81, 'label': 'UNIT', 'text': 1.0 kg}
# {'start': 89, 'end': 97, 'label': 'UNIT', 'text': a second}
# {'start': 105, 'end': 112, 'label': 'UNIT', 'text': 6.35 kg}
# {'start': 172, 'end': 177, 'label': 'UNIT', 'text': 12 kg}
# {'start': 358, 'end': 362, 'label': 'UNIT', 'text': 35 m}
# {'start': 366, 'end': 372, 'label': 'UNIT', 'text': 126 km}
# {'start': 161, 'end': 164, 'label': 'UNIT', 'text': 1 m}
# {'start': 369, 'end': 374, 'label': 'UNIT', 'text': 0.5 m}
# {'start': 408, 'end': 412, 'label': 'UNIT', 'text': 20 m}
# {'start': 81, 'end': 87, 'label': 'UNIT', 'text': 7.83 m}
# {'start': 224, 'end': 229, 'label': 'UNIT', 'text': the y}
# {'start': 360, 'end': 368, 'label': 'UNIT', 'text': the area}
# {'start': 135, 'end': 140, 'label': 'UNIT', 'text': 10 cm}
# {'start': 238, 'end': 245, 'label': 'UNIT', 'text': 0–10 cm}
# {'start': 48, 'end': 55, 'label': 'UNIT', 'text': 0–10 cm}
# {'start': 288, 'end': 295, 'label': 'UNIT', 'text': 0–10 cm}
# {'start': 495, 'end': 503, 'label': 'UNIT', 'text': 20–40 cm}
# {'start': 117, 'end': 125, 'label': 'UNIT', 'text': 11.25 Mg}
# {'start': 386, 'end': 394, 'label': 'UNIT', 'text': the mass}
# {'start': 439, 'end': 446, 'label': 'UNIT', 'text': 0–10 cm}
# {'start': 670, 'end': 677, 'label': 'UNIT', 'text': 0–40 cm}
# {'start': 803, 'end': 811, 'label': 'UNIT', 'text': a stress}
# {'start': 323, 'end': 328, 'label': 'UNIT', 'text': 240 s}
# {'start': 347, 'end': 356, 'label': 'UNIT', 'text': A silicon}
# {'start': 44, 'end': 51, 'label': 'UNIT', 'text': a Milli}
# {'start': 285, 'end': 296, 'label': 'UNIT', 'text': the arsenic}
# {'start': 110, 'end': 116, 'label': 'UNIT', 'text': 100 mg}
# {'start': 123, 'end': 127, 'label': 'UNIT', 'text': 1 mg}
# {'start': 168, 'end': 173, 'label': 'UNIT', 'text': 10 mg}
# {'start': 180, 'end': 186, 'label': 'UNIT', 'text': 0.1 mg}
# {'start': 374, 'end': 379, 'label': 'UNIT', 'text': 120 m}
# {'start': 383, 'end': 388, 'label': 'UNIT', 'text': 380 m}
# {'start': 85, 'end': 95, 'label': 'UNIT', 'text': the amount}
# {'start': 394, 'end': 398, 'label': 'UNIT', 'text': 1 kg}
# {'start': 78, 'end': 85, 'label': 'UNIT', 'text': 0.072 m}
# {'start': 94, 'end': 100, 'label': 'UNIT', 'text': 1.3 mm}
# {'start': 163, 'end': 169, 'label': 'UNIT', 'text': 0.1 mg}
# {'start': 330, 'end': 335, 'label': 'UNIT', 'text': 50 mm}
# {'start': 377, 'end': 383, 'label': 'UNIT', 'text': 1.3 mm}
# {'start': 388, 'end': 394, 'label': 'UNIT', 'text': 8.4 mm}
# {'start': 846, 'end': 853, 'label': 'UNIT', 'text': 0.072 m}
# {'start': 1006, 'end': 1013, 'label': 'UNIT', 'text': 2.377 m}
# {'start': 1063, 'end': 1069, 'label': 'UNIT', 'text': 8.4 mm}
# {'start': 1544, 'end': 1550, 'label': 'UNIT', 'text': 8.4 mm}
# {'start': 1588, 'end': 1594, 'label': 'UNIT', 'text': 1.3 mm}
# {'start': 1633, 'end': 1639, 'label': 'UNIT', 'text': 1.3 mm}
# {'start': 135, 'end': 141, 'label': 'UNIT', 'text': 1.5 mm}
# {'start': 135, 'end': 141, 'label': 'UNIT', 'text': 8.5 mm}
# {'start': 119, 'end': 125, 'label': 'UNIT', 'text': 8.5 mm}
# {'start': 148, 'end': 155, 'label': 'UNIT', 'text': 1980 mm}
# {'start': 201, 'end': 206, 'label': 'UNIT', 'text': and z}
# {'start': 410, 'end': 416, 'label': 'UNIT', 'text': 1.5 mm}
# {'start': 421, 'end': 427, 'label': 'UNIT', 'text': 8.5 mm}
# {'start': 579, 'end': 585, 'label': 'UNIT', 'text': 1.5 mm}
# {'start': 633, 'end': 639, 'label': 'UNIT', 'text': 8.5 mm}
# {'start': 673, 'end': 678, 'label': 'UNIT', 'text': 62 mm}
# {'start': 742, 'end': 747, 'label': 'UNIT', 'text': 62 mm}
# {'start': 45, 'end': 51, 'label': 'UNIT', 'text': 8.5 mm}
# {'start': 375, 'end': 381, 'label': 'UNIT', 'text': 1.5 mm}
# {'start': 246, 'end': 252, 'label': 'UNIT', 'text': 1.5 mm}
# {'start': 8, 'end': 14, 'label': 'UNIT', 'text': 8.5 mm}
# {'start': 79, 'end': 86, 'label': 'UNIT', 'text': 1980 mm}
# {'start': 101, 'end': 108, 'label': 'UNIT', 'text': 2780 mm}
# {'start': 8, 'end': 16, 'label': 'UNIT', 'text': the time}
# {'start': 81, 'end': 89, 'label': 'UNIT', 'text': the time}
# {'start': 363, 'end': 369, 'label': 'UNIT', 'text': 1.5 mm}
# {'start': 404, 'end': 417, 'label': 'UNIT', 'text': This pressure}
# {'start': 19, 'end': 25, 'label': 'UNIT', 'text': 1.5 mm}
# {'start': 44, 'end': 50, 'label': 'UNIT', 'text': 8.5 mm}
# {'start': 255, 'end': 261, 'label': 'UNIT', 'text': 8.5 mm}
# {'start': 117, 'end': 123, 'label': 'UNIT', 'text': 1.5 mm}
# {'start': 68, 'end': 74, 'label': 'UNIT', 'text': 0.5 Hz}
# {'start': 75, 'end': 81, 'label': 'UNIT', 'text': and Hp}
# {'start': 84, 'end': 90, 'label': 'UNIT', 'text': 1.8 cm}
# {'start': 215, 'end': 219, 'label': 'UNIT', 'text': 1 cm}
# {'start': 632, 'end': 637, 'label': 'UNIT', 'text': 4.8 m}
# {'start': 690, 'end': 695, 'label': 'UNIT', 'text': 63 mm}
# {'start': 891, 'end': 894, 'label': 'UNIT', 'text': 8 m}
# {'start': 1117, 'end': 1123, 'label': 'UNIT', 'text': 11.8 m}
# {'start': 1232, 'end': 1238, 'label': 'UNIT', 'text': 11.8 m}
# {'start': 1243, 'end': 1249, 'label': 'UNIT', 'text': 11.5 m}
# {'start': 263, 'end': 267, 'label': 'UNIT', 'text': 1 mm}
# {'start': 187, 'end': 191, 'label': 'UNIT', 'text': 19 m}
# {'start': 700, 'end': 706, 'label': 'UNIT', 'text': 10.5 m}
# {'start': 107, 'end': 112, 'label': 'UNIT', 'text': and B}
# {'start': 589, 'end': 594, 'label': 'UNIT', 'text': and B}
# {'start': 303, 'end': 311, 'label': 'UNIT', 'text': one week}
# {'start': 217, 'end': 225, 'label': 'UNIT', 'text': and time}
# {'start': 344, 'end': 352, 'label': 'UNIT', 'text': and time}
# {'start': 0, 'end': 10, 'label': 'UNIT', 'text': The energy}
# {'start': 1232, 'end': 1238, 'label': 'UNIT', 'text': a year}
# {'start': 1350, 'end': 1359, 'label': 'UNIT', 'text': the power}
# {'start': 461, 'end': 469, 'label': 'UNIT', 'text': the time}
# {'start': 816, 'end': 825, 'label': 'UNIT', 'text': 650–750 W}
# {'start': 866, 'end': 871, 'label': 'UNIT', 'text': 700 W}
# {'start': 916, 'end': 927, 'label': 'UNIT', 'text': These power}
# {'start': 1067, 'end': 1077, 'label': 'UNIT', 'text': each month}
# {'start': 1081, 'end': 1089, 'label': 'UNIT', 'text': the year}
# {'start': 1199, 'end': 1209, 'label': 'UNIT', 'text': and energy}
# {'start': 555, 'end': 561, 'label': 'UNIT', 'text': 10 min}
# {'start': 884, 'end': 892, 'label': 'UNIT', 'text': the iron}
# {'start': 1061, 'end': 1065, 'label': 'UNIT', 'text': 24 h}
# {'start': 1441, 'end': 1448, 'label': 'UNIT', 'text': or iron}
# {'start': 1370, 'end': 1382, 'label': 'UNIT', 'text': the hydrogen}
# {'start': 141, 'end': 146, 'label': 'UNIT', 'text': the y}
# {'start': 991, 'end': 999, 'label': 'UNIT', 'text': 0.003 Hz}
# {'start': 438, 'end': 444, 'label': 'UNIT', 'text': 10 min}
# {'start': 546, 'end': 552, 'label': 'UNIT', 'text': a time}
# {'start': 572, 'end': 579, 'label': 'UNIT', 'text': No spin}
# {'start': 122, 'end': 127, 'label': 'UNIT', 'text': one P}
# {'start': 130, 'end': 134, 'label': 'UNIT', 'text': 12 h}
# {'start': 158, 'end': 164, 'label': 'UNIT', 'text': a time}
# {'start': 185, 'end': 192, 'label': 'UNIT', 'text': No spin}
# {'start': 244, 'end': 250, 'label': 'UNIT', 'text': the UK}
# {'start': 243, 'end': 248, 'label': 'UNIT', 'text': 0.1 g}
# {'start': 960, 'end': 965, 'label': 'UNIT', 'text': and P}
# {'start': 1063, 'end': 1073, 'label': 'UNIT', 'text': the amount}
# {'start': 1750, 'end': 1758, 'label': 'UNIT', 'text': the year}
# {'start': 2340, 'end': 2345, 'label': 'UNIT', 'text': and K}
# {'start': 515, 'end': 518, 'label': 'UNIT', 'text': 5 K}
# {'start': 592, 'end': 596, 'label': 'UNIT', 'text': 30 K}
# {'start': 690, 'end': 702, 'label': 'UNIT', 'text': and hydrogen}
# {'start': 110, 'end': 115, 'label': 'UNIT', 'text': 4.0 V}
# {'start': 277, 'end': 283, 'label': 'UNIT', 'text': 2.2 mg}
# {'start': 210, 'end': 215, 'label': 'UNIT', 'text': 10 ms}
# {'start': 219, 'end': 225, 'label': 'UNIT', 'text': 0.1 ms}
# {'start': 327, 'end': 333, 'label': 'UNIT', 'text': 0.5 ms}
# {'start': 99, 'end': 110, 'label': 'UNIT', 'text': and density}
# {'start': 657, 'end': 662, 'label': 'UNIT', 'text': 40 Hz}
# {'start': 748, 'end': 759, 'label': 'UNIT', 'text': and density}
# {'start': 509, 'end': 518, 'label': 'UNIT', 'text': this time}
# {'start': 275, 'end': 283, 'label': 'UNIT', 'text': the time}
# {'start': 469, 'end': 472, 'label': 'UNIT', 'text': 5 m}
# {'start': 516, 'end': 528, 'label': 'UNIT', 'text': the velocity}
# {'start': 436, 'end': 441, 'label': 'UNIT', 'text': 220 m}
# {'start': 109, 'end': 113, 'label': 'UNIT', 'text': 48 h}
# {'start': 488, 'end': 494, 'label': 'UNIT', 'text': a spin}
# {'start': 55, 'end': 59, 'label': 'UNIT', 'text': 48 h}
# {'start': 738, 'end': 743, 'label': 'UNIT', 'text': 100 U}
# {'start': 441, 'end': 447, 'label': 'UNIT', 'text': 0.1 mg}
# {'start': 256, 'end': 264, 'label': 'UNIT', 'text': the time}
# {'start': 663, 'end': 671, 'label': 'UNIT', 'text': One year}
# {'start': 513, 'end': 521, 'label': 'UNIT', 'text': the area}
# {'start': 831, 'end': 835, 'label': 'UNIT', 'text': 5 mm}
# {'start': 1198, 'end': 1206, 'label': 'UNIT', 'text': the time}
# {'start': 1268, 'end': 1273, 'label': 'UNIT', 'text': and D}
# {'start': 28, 'end': 35, 'label': 'UNIT', 'text': 5–55 Hz}
# {'start': 99, 'end': 108, 'label': 'UNIT', 'text': 30–130 ms}
# {'start': 105, 'end': 110, 'label': 'UNIT', 'text': 48 hr}
# {'start': 920, 'end': 922, 'label': 'UNIT', 'text': 1G}
# {'start': 1091, 'end': 1096, 'label': 'UNIT', 'text': 1I–1M}
# {'start': 733, 'end': 735, 'label': 'UNIT', 'text': 3G}
# {'start': 827, 'end': 838, 'label': 'UNIT', 'text': and density}
# {'start': 1234, 'end': 1237, 'label': 'UNIT', 'text': + T}
# {'start': 1295, 'end': 1297, 'label': 'UNIT', 'text': 3K}
# {'start': 398, 'end': 403, 'label': 'UNIT', 'text': 12 hr}
# {'start': 495, 'end': 499, 'label': 'UNIT', 'text': 2 mg}
# {'start': 626, 'end': 632, 'label': 'UNIT', 'text': 4.2 mm}
# {'start': 305, 'end': 310, 'label': 'UNIT', 'text': and J}
# 476

# %% [markdown]
# The following for loop converts the current spaCy and human annotation format into a gate readable one using text/x-json-twitter format

# %%
import math
for doc in data.values():

    testjson  = doc.doc.to_json()


    twitjson = {"full_text": testjson["text"],"entities":{}}


    for tok in testjson["tokens"]:
        tempToken = {}
        tempToken["indices"] = [tok["start"],tok["end"]] 
        tempToken["category"] = tok["tag"]
        tempToken["kind"] = tok["dep"]
        tempToken["id"] = tok["id"]
        tempToken["head"] = tok["head"]
        try:
            twitjson["entities"]["Token"].append(tempToken)
        except KeyError:
            twitjson["entities"]["Token"] = [tempToken] 

    for ent in testjson["ents"]:
        tempEnt = {}
        tempEnt["indices"] = [ent["start"],ent["end"]] 
        try:
            twitjson["entities"][ent["label"]].append(tempEnt)
        except KeyError:
            twitjson["entities"][ent["label"]] = [tempEnt]
            
    for unit in doc.doc._.unit:
        tempUnit = {}
        tempUnit["indices"] = [int(unit["start"]),int(unit["end"])]
        tempUnit["text"]= unit["text"].text
        try:
            twitjson["entities"]["unit"].append(tempUnit)
        except KeyError:
            twitjson["entities"]["unit"] = [tempUnit]

            
    for sent in testjson["sents"]:
        tempSent = {}
        tempSent["indices"] = [sent["start"],sent["end"]] 
        try:
            twitjson["entities"]["sentence"].append(tempSent)
        except KeyError:
            twitjson["entities"]["sentence"] = [tempSent] 
            
    for index, row in doc.tsv.iterrows():
        tempAnnot = {}
        tempAnnot["indices"] = [row["startOffset"],row["endOffset"]] 
        tempAnnot["annotSet"] = row["annotSet"]
        tempAnnot["annotId"] = row["annotId"]
        tempAnnot["text"] = row["text"]
        if(type(row["other"]) == str):
            tempAnnot["other"] = row["other"]
        else:
            tempAnnot["other"] = "nothing"
            
        try:
            twitjson["entities"]["MEval-"+row["annotType"]].append(tempAnnot)
        except KeyError:
            twitjson["entities"]["MEval-"+row["annotType"]] = [tempAnnot] 

    json.dump(twitjson, open(f'jsondocs/{doc.name}.json',"w"), indent=3)
