# %%
from __future__ import unicode_literals, print_function
import pandas as pd
import os.path
from nltk.tokenize import word_tokenize
import nltk
import json
import spacy
import plac
spacy.prefer_gpu()
nlp = spacy.load("en_core_web_sm")

TRIALPATH = "data/trial"
TRAINPATH = "data/train"

class exerpt:
    def __init__(self, name, txt, ann, tsv, grobid):
        self.name = name
        self.txt = txt
        self.ann = ann
        self.tsv = tsv
        self.grobid = grobid
        self.context = False
        self.posTag = False
        self.doc = nlp(self.txt)
        
    def getContext(self, count = 3):
        if self.context == False: 
            beforeContext = []
            afterContext = []
            self.context = True
            for start,end in zip(self.tsv["startOffset"].values, self.tsv["endOffset"].values ):#self.tsv.iterrows():
                a = getIndexSeperated(exerpt.txt[0],end,count = count)
                b = getIndexSeperated(exerpt.txt[0],start,count = count,forward = False)
                beforeContext.append(self.txt[0][b:start])
                afterContext.append(self.txt[0][end:a])
            self.tsv.insert(3,"beforeContext", beforeContext)
            self.tsv.insert(3,"afterContext", afterContext)
            
    def getPosTag(self):
        if self.context and self.posTag == False: 
            bTag = []
            aTag = []
            self.posTag = True
            for before, after in zip(self.tsv["beforeContext"].values,self.tsv["afterContext"].values):
                bTag.append(nltk.pos_tag(word_tokenize(before)))
                aTag.append(nltk.pos_tag(word_tokenize(after)))
            self.tsv.insert(3,"beforeTag", bTag)
            self.tsv.insert(3,"afterTag", aTag)
            


def readTXTByLine(filepath):
    ftemp = open(filepath, "r", encoding = "utf-8")
    raw = str(ftemp.read())
    ftemp.close()
    return raw

data = {}
for fn in os.listdir(os.path.join(TRIALPATH,"txt")):
        if fn.endswith('.txt'):
            data[fn[:-4]] = exerpt(
                fn[:-4],
                readTXTByLine(os.path.join(TRIALPATH, "txt", fn[:-4] + ".txt")),
                readTXTByLine(os.path.join(TRIALPATH, "ann", fn[:-4] + ".ann")),
                pd.read_csv(os.path.join(TRIALPATH, "tsv", fn[:-4] + ".tsv"), "\t", header = 0 ),
                json.load(open(os.path.join(TRIALPATH, "grobid", fn[:-4] + ".grobid")))
            )
            
for fn in [x for x in os.listdir(os.path.join(TRAINPATH,"text")) if x[:-4]+".tsv" in os.listdir(os.path.join(TRAINPATH,"tsv"))]:
        if fn.endswith('.txt'):
            data[fn[:-4]] = exerpt(
                fn[:-4],
                readTXTByLine(os.path.join(TRAINPATH, "text", fn[:-4] + ".txt")),
                "none",
                pd.read_csv(os.path.join(TRAINPATH, "tsv", fn[:-4] + ".tsv"), "\t", header = 0 ),
                json.load(open(os.path.join(TRAINPATH, "grobid", fn[:-4] + ".grobid")))
            )

# %%
list(data.keys())
# Out:
# ['S0012821X12004384-1302',
#  'S0012821X12004384-1405',
#  'S0012821X12004384-1415',
#  'S0012821X12004384-1594',
#  'S0012821X12004384-1599',
#  'S0012821X13002185-1061',
#  'S0012821X13002185-1200',
#  'S0012821X13002185-1217',
#  'S0012821X13002185-1231',
#  'S0012821X13002185-835',
#  'S0012821X13007309-1482',
#  'S0012821X13007309-1509',
#  'S0012821X13007309-1605',
#  'S0012821X13007309-1989',
#  'S0016236113008041-3031',
#  'S0016236113008041-3112',
#  'S0016236113008041-3153',
#  'S0016236113008041-3171',
#  'S0016236113008041-3186',
#  'S0016236113008041-3207',
#  'S0016236113008041-3269',
#  'S0016236113008041-3290',
#  'S0016236113008041-890',
#  'S0016236113008041-913',
#  'S0016236113008041-967',
#  'S0019103511004994-1382',
#  'S0019103511004994-1511',
#  'S0019103511004994-1565',
#  'S0019103512002801-1342',
#  'S0019103512002801-1496',
#  'S0019103512002801-1608',
#  'S0019103512002801-1824',
#  'S0019103512002801-1849',
#  'S0019103512002801-1927',
#  'S0019103512003533-3299',
#  'S0019103512003533-3348',
#  'S0019103512003533-4685',
#  'S0019103512003533-4971',
#  'S0019103512003533-5031',
#  'S0019103512003533-5072',
#  'S0019103512003533-5251',
#  'S0019103512003533-5598',
#  'S0019103512003995-1807',
#  'S0019103512003995-1910',
#  'S0019103512003995-2760',
#  'S0019103512003995-3548',
#  'S0019103512004009-3488',
#  'S0019103512004009-3825',
#  'S0019103512004009-3962',
#  'S0019103512004009-4007',
#  'S0019103512004009-4492',
#  'S0019103512004009-5019',
#  'S0019103512004009-5507',
#  'S0019103513005058-1737',
#  'S0019103513005058-3094',
#  'S0019103513005058-4210',
#  'S0021979713004438-1415',
#  'S0021979713004438-1907',
#  'S0021979713004438-1969',
#  'S0021979713004438-2148',
#  'S0022000014000026-17824',
#  'S0022000014000026-18167',
#  'S0022399913003358-1044',
#  'S0022459611006116-1160',
#  'S0022459611006116-1195',
#  'S0006322312001096-1136',
#  'S0006322312001096-1177',
#  'S0006322312001096-1190',
#  'S0006322312001096-1194',
#  'S0006322312001096-1197',
#  'S0006322312001096-1202',
#  'S0006322312001096-1205',
#  'S0006322312001096-1221',
#  'S0006322312001096-1230',
#  'S0006322312001096-1248',
#  'S0006322312001096-1253',
#  'S0006322312001096-1260',
#  'S0006322312001096-1271',
#  'S0006322312001096-1275',
#  'S0006322312001096-1278',
#  'S0006322312001096-626',
#  'S0012821X12004384-1148',
#  'S0012821X12004384-1178',
#  'S0012821X12004384-1221',
#  'S0012821X12004384-1232',
#  'S0012821X12004384-1249',
#  'S0012821X12004384-1265',
#  'S0012821X12004384-1284',
#  'S0012821X12004384-1640',
#  'S0012821X12004384-952',
#  'S0012821X13002185-994',
#  'S0012821X13007309-1691',
#  'S0016236113008041-2924',
#  'S0016236113008041-3012',
#  'S0016236113008041-3159',
#  'S0016236113008041-3161',
#  'S0016236113008041-872',
#  'S0016236113008041-961',
#  'S0019103511004994-1399',
#  'S0019103511004994-996',
#  'S0019103512001388-1070',
#  'S0019103512001388-3081',
#  'S0019103512002801-1716',
#  'S0019103512002801-2018',
#  'S0019103512003533-3306',
#  'S0019103512003995-1283',
#  'S0019103512003995-1767',
#  'S0019103512003995-2737',
#  'S0019103512004009-2821',
#  'S0019103512004009-3976',
#  'S0019103512004009-4350',
#  'S0019103512004009-5033',
#  'S0019103512004009-5271',
#  'S0019103513005058-3154',
#  'S0019103513005058-3917',
#  'S0019103513005058-4098',
#  'S0019103513005058-4158',
#  'S0019103513005058-4302',
#  'S0019103513005058-4349',
#  'S0021979713004438-1401',
#  'S0022399913003358-931',
#  'S0022399913003358-943',
#  'S0022459611006116-1448',
#  'S0022459611006116-547',
#  'S0025322712001600-2230',
#  'S0025322712001600-2406',
#  'S0031405612000728-1621',
#  'S0031405612000728-769',
#  'S0032063312002437-627',
#  'S0032063312003054-1990',
#  'S0032063312003054-2264',
#  'S0032063312003054-2467',
#  'S0032063312003054-2483',
#  'S0032063312003054-2501',
#  'S0032386113005454-2008',
#  'S0032386113005454-2055',
#  'S0032386113005454-2308',
#  'S0032386113005454-2601',
#  'S0032386113005454-2865',
#  'S0032386113009889-2123',
#  'S0038071711004354-2573',
#  'S0038071712001010-1044',
#  'S0038071712001010-918',
#  'S0038071712001010-944',
#  'S0038071713001971-1388',
#  'S0038071713001971-1427',
#  'S016412121300188X-4069',
#  'S016412121300188X-4392',
#  'S016412121300188X-4436',
#  'S016412121300188X-4545',
#  'S016412121300188X-4617',
#  'S016412121300188X-5038',
#  'S016412121300188X-5066',
#  'S0165587612003680-1078',
#  'S0165587612003680-953',
#  'S0165587612003680-998',
#  'S0167577X13006393-644',
#  'S0167577X13006393-787',
#  'S0167577X14001256-389',
#  'S0167577X14001256-517',
#  'S0167610512002292-3187',
#  'S0167610512002292-3305',
#  'S0167610513001001-1751',
#  'S0167610513001001-739',
#  'S0167610513002729-1062',
#  'S0167610513002729-1127',
#  'S0167819113001051-1247',
#  'S0167819113001051-1550',
#  'S0167880913001229-1021',
#  'S0167880913001229-1033',
#  'S0167880913001229-1225',
#  'S0167880913001229-1304',
#  'S0168945213001805-3964',
#  'S0168945213001805-4454',
#  'S0168945213001805-4536',
#  'S0168945213001805-4775',
#  'S0168945213001805-5026',
#  'S0169433213008933-689',
#  'S027737911400050X-2401',
#  'S030881461301604X-1001',
#  'S030881461301604X-1002',
#  'S0378112713005288-1720',
#  'S0378112713005288-1948',
#  'S0378112713005288-2062',
#  'S0378383911001669-1088',
#  'S0378383911001669-1634',
#  'S0378383911001669-2260',
#  'S0378383912000130-1048',
#  'S0378383912000130-1054',
#  'S0378383912000130-1096',
#  'S0378383912000130-3601',
#  'S0378383912000130-3662',
#  'S0378383912000130-3732',
#  'S0378383912000130-3745',
#  'S0378383912000130-3755',
#  'S0378383912000130-3827',
#  'S0378383912000130-3907',
#  'S0378383913001567-2462',
#  'S0921818113002245-1571',
#  'S0921818113002245-1752',
#  'S0921818113002245-859',
#  'S0921818113002245-882',
#  'S0925443913001385-1638',
#  'S0925443913001385-1646',
#  'S0925443913003037-1397',
#  'S0925443913003037-654',
#  'S0927024813001955-1005',
#  'S0927024813001955-576',
#  'S0927024813001955-679',
#  'S0927024813002420-1032',
#  'S0927024813002420-975',
#  'S0927024813002961-1051',
#  'S0927024813002961-1334',
#  'S0927024813003036-2011',
#  'S0927775713009606-1074',
#  'S0927775713009606-1216',
#  'S0927775713009606-1361',
#  'S0950705113001895-23699',
#  'S095741741101342X-2624',
#  'S095741741101342X-726',
#  'S0960148113002048-3775',
#  'S0960148113004989-3203',
#  'S0960148113004989-3277',
#  'S0960148113004989-3327',
#  'S0960148113005727-1181',
#  'S0960148113005727-1494',
#  'S0960148113005727-904',
#  'S0960896612001022-1223',
#  'S1161030113001950-923',
#  'S1359645413009816-2243',
#  'S1367912013002277-1213',
#  'S1387700313001822-661',
#  'S1388248113001951-339',
#  'S1389128612002496-5994',
#  'S1389128612002496-6119',
#  'S1389128612002496-6138',
#  'S1550413113004920-1509',
#  'S175058361300203X-1280',
#  'S175058361300203X-1483',
#  'S175058361300203X-1542',
#  'S175058361300203X-1556',
#  'S175058361300203X-1638',
#  'S1750583613004192-1267',
#  'S1750583613004192-714',
#  'S1873506113001116-1369',
#  'S1873506113001116-710',
#  'S1873506113001116-978',
#  'S1873506114000075-1132',
#  'S1873506114000075-1242',
#  'S2211124712002884-1060',
#  'S2211124712002884-1110',
#  'S2211124712002884-649',
#  'S2211124712002884-682',
#  'S2211124712002884-903',
#  'S2211124713006475-1195',
#  'S2211124713006475-1205',
#  'S2211124713006475-841',
#  'S2213158213000582-1327',
#  'S2213158213000582-1340',
#  'S2213671113000738-430',
#  'S2213671113000738-435',
#  'S2213671113000738-445',
#  'S2213671113000738-485',
#  'S2213671113000738-647',
#  'S2213671113000738-684',
#  'S2213671113000738-738',
#  'S2213671113000908-640',
#  'S2213671113000908-810',
#  'S2213671113000908-979',
#  'S2213671113000921-1279',
#  'S2213671113000921-994',
#  'S2213671113001306-1286',
#  'S2213671113001306-1398',
#  'S2213671113001306-1520',
#  'S2213671113001306-885',
#  'S2213671113001306-907',
#  'S2213671113001306-908',
#  'S2213671113001306-910']

# %% [markdown]
# The following code will render the dependency visualization inside the jupyter notebook

# %%
from spacy import displacy

exerpt = data["S0019103512001388-3081"]

svg = displacy.render(exerpt.doc, jupyter = True, style = "dep", page=True)
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b5778653fdd642bfa1f871ca4baa3f68-0" class="displacy" width="6175" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">observed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">peak</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">fractional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">integrated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">differential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">brightness</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">BS1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">H</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">filter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">observed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">0.64%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">discovery</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">image</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">26</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">October</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">2011,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentC

# %% [markdown]
# SpaCy gives users the option to format displacy's output. The following options configure displaycy's dependency visualisions look.

# %%
options = {
    "fine_grained" : True,
    "collapse_punct": False,
    "collapse_phrases": False, 
    "compact" : True,
    "word_spacing" : 45,
    "offset_x" : 50,
    "arrow_stroke" : 0.75,
    "arrow_spacing" : 4,
    "distance" : 90,
    "arrow_width": 4.5,
    "font" : "Times"
}

exerpt = data["S0012821X13007309-1605"]

svg = displacy.render(exerpt.doc,jupyter = True, style = "dep", page=True, options=options)
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="26fc9ec7b7784258a09fce5d32cb07f8-0" class="displacy" width="27860" height="1170.75" direction="ltr" style="max-width: none; height: 1170.75px; color: #000000; background: #ffffff; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="140">Vocontian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="230">Basin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="320">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">VBD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="410">part</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="590">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="680">western</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="770">gulf</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="860">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1040">European</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Alpine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1220">region</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1310">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1490">NW</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1580">Tethys</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1670">Ocean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1760">∼30</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1850">°</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">,</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="1940">N</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="2030">(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">-LRB-</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="2120">Jarvis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="2210">et</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">FW</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="2300">al</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="2390">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="2480">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">,</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor" x="2570">2011</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">CD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1080.75">
#     <tspan class="displacy-word" fill="currentColor"

# %%
import spacy
from spacy import displacy
from pathlib import Path

for e in data.values():
    svg = displacy.render(e.doc,jupyter = False, style = "dep", page=True, options=options)
    file_name = e.name + ".svg"
    output_path = Path("data-merged/dep/" + file_name)
    output_path.open("w", encoding="utf-8").write(svg)

# %% [markdown]
# Let's try visualizing this with collasped phrases!

# %%
options = {
    "fine_grained" : True,
    "collapse_punct": False,
    "collapse_phrases": False, 
    "compact" : True,
    "word_spacing" : 25,
    "offset_x" : 50,
    "arrow_stroke" : 1,
    "arrow_spacing" : 6,
    "distance" : 90,
    "arrow_width": 4.5,
    "font" : "Times"
}

exerpt = data["S0012821X13007309-1605"]

svg = displacy.render(exerpt.doc,jupyter = True, style = "dep", page=True, options=options)
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1f77b7f8d76147be8f819f129c29ee5a-0" class="displacy" width="27860" height="1111.0" direction="ltr" style="max-width: none; height: 1111.0px; color: #000000; background: #ffffff; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Vocontian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Basin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">VBD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">part</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">western</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">gulf</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">European</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Alpine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">region</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">DT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">NW</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">Tethys</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">Ocean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">∼30</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">°</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">,</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">N</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">(</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">-LRB-</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">Jarvis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">et</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">FW</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">al</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">,</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">2011</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">CD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1061.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">;</tspan>
#     <tspan c

# %% [markdown]
# Let's try visualizing this with fine grained POS tags!

# %%
options = {
    "fine_grained" : True,
    "collapse_punct": True,
    "collapse_phrases": True, 
    "compact" : True,
    "word_spacing" : 25,
    "offset_x" : 50,
    "arrow_stroke" : 1,
    "arrow_spacing" : 6,
    "distance" : 90,
    "arrow_width": 4.5,
    "font" : "Times"
}

exerpt = data["S0012821X13007309-1605"]

svg = displacy.render(exerpt.doc,jupyter = True, style = "dep", page=True, options=options)
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d3d53ca19f8046d480466fcfab1658fc-0" class="displacy" width="14360" height="661.0" direction="ltr" style="max-width: none; height: 661.0px; color: #000000; background: #ffffff; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The Vocontian Basin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">VBD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">part</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">the western gulf</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">the European Alpine region</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">the NW Tethys Ocean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">∼30</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">°</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">,</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">N (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Jarvis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">et</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">FW</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">al.,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">2011;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">CD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Fig.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">1).</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">CD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">High rates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NNS</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">subsidence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">throughout</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">the mid-Cretaceous provided accommodation space</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">NN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">IN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">thick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">JJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">rhythmically</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">RB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">bedded</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">VBD</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">bioturbated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="611.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">limestone–</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NNP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-an
